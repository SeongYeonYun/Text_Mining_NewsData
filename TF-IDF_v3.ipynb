# %%
import pandas as pd

korean_air_data = pd.read_csv("korean_air_data/korean_air_2020_01.csv")

korean_air_data 

korean_air_data.columns = ["a","title","text","editor","times","date"]

del korean_air_data["a"]

# na값 제거
data = korean_air_data.dropna()

# 불용어 지정
stopwords = ['의','가','이','은','들','는','좀','잘','걍','과','박정환','도','을','것','를','등','으로','자','에','등','와','한','하다''것','\n','로']

# 한글 외의 모든 데이터 제거 : 기업명이 영어로 되어있는 경우를 어떻게 처리 해야할까?
data = data.text.str.replace("[^ㄱ-ㅎㅏ-ㅣ가-힣 ]","")

from konlpy.tag import Okt
from tensorflow.keras.preprocessing.text import Tokenizer

okt = Okt()
X_train = []

for sen in data :
    temp_X = []
    
    # 토큰화
    temp_X = okt.morphs(sen, stem = True) 
    
    # 불용어 제거
    temp_X = [word for word in temp_X if not word in stopwords] 
    
    X_train.append(temp_X)

tokenizer = Tokenizer()
tokenizer.fit_on_texts(X_train)

threshold = 3
total_cnt = len(tokenizer.word_index) # 단어의 수
rare_cnt = 0 # 등장 빈도수가 threshold보다 작은 단어의 개수를 카운트
total_freq = 0 # 훈련 데이터의 전체 단어 빈도수 총 합
rare_freq = 0 # 등장 빈도수가 threshold보다 작은 단어의 등장 빈도수의 총 합

# 단어와 빈도수의 쌍(pair)을 key와 value로 받는다.
for key, value in tokenizer.word_counts.items():
    total_freq = total_freq + value

    # 단어의 등장 빈도수가 threshold보다 작으면
    if(value < threshold):
        rare_cnt = rare_cnt + 1
        rare_freq = rare_freq + value

print('단어 집합(vocabulary)의 크기 :',total_cnt)
print('등장 빈도가 %s번 이하인 희귀 단어의 수: %s'%(threshold - 1, rare_cnt))
print("단어 집합에서 희귀 단어의 비율:", (rare_cnt / total_cnt)*100)
print("전체 등장 빈도에서 희귀 단어 등장 빈도 비율:", (rare_freq / total_freq)*100)

# 전체 단어 개수 중 빈도수 2이하인 단어 개수는 제거.
vocab_size = total_cnt - rare_cnt
print('단어 집합의 크기 :',vocab_size)
# Out:
# 단어 집합(vocabulary)의 크기 : 8648
# 등장 빈도가 2번 이하인 희귀 단어의 수: 4170
# 단어 집합에서 희귀 단어의 비율: 48.21924144310824
# 전체 등장 빈도에서 희귀 단어 등장 빈도 비율: 3.497673817523908
# 단어 집합의 크기 : 4478

# %%
nouns = []
str = ''

for k in range(0,len(X_train)):
    for i in range(0,len(X_train[k])):
        str = str + X_train[k][i] + ' '
    nouns.append(str)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf_df = pd.DataFrame()

tfIdfVectorizer=TfidfVectorizer(use_idf=True)
tfidf = tfIdfVectorizer.fit_transform(nouns)

for i in range(0,len(X_train)):
    df = pd.DataFrame(tfidf[i].T.toarray(), index=tfIdfVectorizer.get_feature_names(), columns=["text{}".format(i)])
    tfidf_df = pd.concat([tfidf_df,df],axis = 1)

# %%
tfidf_df
# Out:
#         text0     text1    text2     text3     text4     text5     text6  \
# 가가   0.000000  0.000000  0.00000  0.000000  0.000000  0.000000  0.000000
# 가게   0.000000  0.000000  0.00000  0.000000  0.000000  0.000000  0.000000
# 가격   0.000000  0.000000  0.00000  0.000000  0.000000  0.000000  0.004429
# 가공   0.000000  0.000000  0.00000  0.000000  0.000000  0.000000  0.000000
# 가구   0.000000  0.000000  0.00000  0.000000  0.000000  0.000000  0.000000
# ..        ...       ...      ...       ...       ...       ...       ...
# 힐링   0.000000  0.000000  0.00000  0.000000  0.000000  0.000000  0.000000
# 힘겹다  0.000000  0.000000  0.00000  0.000000  0.000000  0.000000  0.000000
# 힘드다  0.000000  0.000000  0.00000  0.000000  0.000000  0.005538  0.004419
# 힘들다  0.024992  0.016402  0.02454  0.018793  0.015784  0.010948  0.008736
# 힘쓰다  0.000000  0.000000  0.00000  0.000000  0.000000  0.000000  0.000000
#
#         text7     text8     text9  ...   text422   text423   text424  \
# 가가   0.000000  0.000000  0.000000  ...  0.002120  0.002115  0.002109
# 가게   0.000000  0.000000  0.000000  ...  0.000145  0.000145  0.000144
# 가격   0.003859  0.003508  0.002946  ...  0.008832  0.008809  0.008788
# 가공   0.000000  0.000000  0.000000  ...  0.000465  0.000464  0.000463
# 가구   0.000000  0.000000  0.000000  ...  0.001095  0.001092  0.001089
# ..        ...       ...       ...  ...       ...       ...       ...
# 힐링   0.000000  0.000000  0.000000  ...  0.000354  0.000353  0.000353
# 힘겹다  0.000000  0.000000  0.000000  ...  0.000329  0.000328  0.000327
# 힘드다  0.003850  0.003500  0.002939  ...  0.000953  0.000950  0.000948
# 힘들다  0.007611  0.006920  0.008716  ...  0.001177  0.001174  0.001171
# 힘쓰다  0.000000  0.000000  0.000000  ...  0.000532  0.000531  0.000529
#
#       text425   text426   text427   text428   text429   text430   text431
# 가가   0.002107  0.002104  0.002098  0.002092  0.002090  0.002074  0.002071
# 가게   0.000144  0.000144  0.000144  0.000143  0.000143  0.000142  0.000142
# 가격   0.008778  0.008764  0.008740  0.008717  0.008708  0.008640  0.008628
# 가공   0.000463  0.000462  0.000461  0.000459  0.000459  0.000455  0.000455
# 가구   0.001088  0.001086  0.001083  0.001081  0.001079  0.001071  0.001070
# ..        ...       ...       ...       ...       ...       ...       ...
# 힐링   0.000352  0.000352  0.000351  0.000350  0.000349  0.000347  0.000346
# 힘겹다  0.000327  0.000326  0.000325  0.000325  0.000324  0.000322  0.000321
# 힘드다  0.000947  0.000945  0.000943  0.000940  0.000939  0.000932  0.000931
# 힘들다  0.001170  0.001168  0.001165  0.001162  0.001161  0.001151  0.001150
# 힘쓰다  0.000529  0.000528  0.000877  0.001050  0.001049  0.001041  0.001039
#
# [8142 rows x 432 columns]

# %%
X_train_tfidf = []

for i in range(0,len(X_train)):
    idx = tfidf_df['text{}'.format(i)] > 0.01
    result = tfidf_df[idx].index.tolist()
    X_train_tfidf.append(result)

X_train_tfidf
# Out:
# [['가늠',
#   '가능성',
#   '가능하다',
#   '가다',
#   '가족',
#   '가지',
#   '가치',
#   '감안',
#   '개발',
#   '개선',
#   '거나',
#   '건설',
#   '결단',
#   '결집',
#   '결합',
#   '경영',
#   '경영인',
#   '경영학',
#   '경우',
#   '경쟁',
#   '계기',
#   '계약',
#   '계열',
#   '고가',
#   '고문',
#   '고심',
#   '공감',
#   '공동',
#   '공세',
#   '공시',
#   '과정',
#   '관계자',
#   '교수',
#   '구조',
#   '구현',
#   '국민연금',
#   '그것',
#   '그레이스',
#   '그룹',
#   '기사',
#   '기업',
#   '기자',
#   '기존',
#   '기타',
#   '김경준',
#   '깊다',
#   '까지',
#   '나머지',
#   '나서다',
#   '남매',
#   '남아',
#   '내다',
#   '내다보다',
#   '누나',
#   '늘다',
#   '다녀오다',
#   '다음',
#   '단기',
#   '대목',
#   '대표자',
#   '대한',
#   '대한항공',
#   '대해',
#   '대호',
#   '델타항공',
#   '도입',
#   '동생',
#   '돼다',
#   '되다',
#   '또는',
#   '마치',
#   '만큼은',
#   '명시',
#   '명의',
#   '모범',
#   '목적',
#   '몰리다',
#   '무게',
#   '밖에',
#   '반도',
#   '발생',
#   '발표',
#   '밝히다',
#   '방식',
#   '방어',
#   '배경',
#   '배수',
#   '배제',
#   '법무',
#   '법인',
#   '변수',
#   '보유',
#   '보이다',
#   '본격',
#   '부사',
#   '부회장',
#   '분구',
#   '분명하다',
#   '분쟁',
#   '불가능하다',
#   '비롯',
#   '비율',
#   '빨갛다',
#   '사내',
#   '사다',
#   '사모펀드',
#   '사실',
#   '사인',
#   '사장',
#   '사항',
#   '상황',
#   '서다',
#   '선임',
#   '설명',
#   '성부',
#   '세력',
#   '수준',
#   '시간',
#   '시점',
#   '실어',
#   '심각하다',
#   '아우르다',
#   '않다',
#   '알려지다',
#   '앞서',
#   '어머니',
#   '업계',
#   '없다',
#   '에겐',
#   '에서',
#   '에서는',
#   '에선',
#   '여기',
#   '연합',
#   '열리다',
#   '영진',
#   '예단',
#   '오다',
#   '오르다',
#   '우려',
#   '우한',
#   '우호',
#   '웃다',
#   '위기',
#   '위해',
#   '위협',
#   '유리하다',
#   '으론',
#   '의결권',
#   '의기',
#   '의지',
#   '의하다',
#   '이다',
#   '이라고',
#   '이렇다',
#   '이뤄지다',
#   '이며',
#   '이면',
#   '이명희',
#   '이번',
#   '이사',
#   '이상',
#   '이어지다',
#   '이윤',
#   '이익',
#   '인하다',
#   '일명',
#   '일본항공',
#   '일선',
#   '입장',
#   '있다',
#   '자다',
#   '자명하다',
#   '장담',
#   '장이',
#   '재무',
#   '저지',
#   '전격',
#   '전무',
#   '전세기',
#   '정립',
#   '정석',
#   '정점',
#   '제도',
#   '제시',
#   '조건',
#   '조원태',
#   '조현민',
#   '조현아',
#   '주다',
#   '주식',
#   '주주',
#   '주주총회',
#   '지금',
#   '지배구조',
#   '지속',
#   '지주사',
#   '직후',
#   '처럼',
#   '처분',
#   '체결',
#   '촉발',
#   '총수',
#   '최선',
#   '추구',
#   '취득',
#   '치닫다',
#   '치솟다',
#   '카카오',
#   '켜지다',
#   '키로',
#   '탑승',
#   '태평양',
#   '통해',
#   '투자',
#   '투합',
#   '특히',
#   '파산하다',
#   '파상',
#   '펀드',
#   '포함',
#   '필요하다',
#   '하고',
#   '하다',
#   '하지만',
#   '한국',
#   '한진',
#   '한편',
#   '함께',
#   '합산',
#   '합의',
#   '항공',
#   '항공대',
#   '해석',
#   '행사',
#   '향배',
#   '허다',
#   '혁신',
#   '현재',
#   '현행법',
#   '홀딩스',
#   '확보',
#   '확실하다',
#   '확인',
#   '회사',
#   '회장',
#   '획득',
#   '효율',
#   '훨씬',
#   '희영',
#   '힘들다'],
#  ['가늠',
#   '가능성',
#   '가능하다',
#   '가다',
#   '가르다',
#   '가족',
#   '가지',
#   '가치',
#   '간인',
#   '갈등',
#   '감안',
#   '강화하다',
#   '개발',
#   '개선',
#   '개인',
#   '거나',
#   '건설',
#   '격화할',
#   '결단',
#   '결집',
#   '결합',
#   '경영',
#   '경영인',
#   '경영학',
#   '경우',
#   '경쟁',
#   '계기',
#   '계약',
#   '계열',
#   '고가',
#   '고문',
#   '고민',
#   '고심',
#   '공감',
#   '공동',
#   '공세',
#   '공시',
#   '과정',
#   '관계자',
#   '교수',
#   '구조',
#   '구축',
#   '구현',
#   '국민연금',
#   '그것',
#   '그동안',
#   '그러하다',
#   '그레이스',
#   '그룹',
#   '기사',
#   '기업',
#   '기자',
#   '기존',
#   '기타',
#   '김경준',
#   '깊다',
#   '까지',
#   '꾸준하다',
#   '나머지',
#   '나서다',
#   '남매',
#   '남아',
#   '내다',
#   '내다보다',
#   '노력',
#   '누나',
#   '늘다',
#   '다가오다',
#   '다녀오다',
#   '다음',
#   '단기',
#   '대목',
#   '대표자',
#   '대한',
#   '대한항공',
#   '대해',
#   '대호',
#   '델타항공',
#   '도입',
#   '동생',
#   '돼다',
#   '되다',
#   '들다',
#   '따르다',
#   '또는',
#   '마치',
#   '만큼은',
#   '많다',
#   '명시',
#   '명의',
#   '모든',
#   '모범',
#   '목적',
#   '몰리다',
#   '무게',
#   '밖에',
#   '반도',
#   '발생',
#   '발전',
#   '발표',
#   '밝히다',
#   '방식',
#   '방어',
#   '방향',
#   '배경',
#   '배수',
#   '배제',
#   '법무',
#   '법인',
#   '변수',
#   '보유',
#   '보이다',
#   '본격',
#   '부사',
#   '부회장',
#   '분구',
#   '분명하다',
#   '분쟁',
#   '불가능하다',
#   '불거지다',
#   '비롯',
#   '비율',
#   '빨갛다',
#   '사내',
#   '사다',
#   '사모펀드',
#   '사실',
#   '사인',
#   '사장',
#   '사항',
#   '상황',
#   '새롭다',
#   '서다',
#   '선임',
#   '설명',
#   '성부',
#   '성장',
#   '세력',
#   '소외',
#   '수준',
#   '시간',
#   '시점',
#   '실어',
#   '심각하다',
#   '아우르다',
#   '않다',
#   '알려지다',
#   '앞두다',
#   '앞서',
#   '어느',
#   '어머니',
#   '업계',
#   '없다',
#   '에겐',
#   '에서',
#   '에서는',
#   '에선',
#   '여기',
#   '역시',
#   '연합',
#   '열리다',
#   '영진',
#   '예단',
#   '오다',
#   '오르다',
#   '우려',
#   '우한',
#   '우호',
#   '웃다',
#   '위기',
#   '위해',
#   '위협',
#   '유리하다',
#   '으로써',
#   '으론',
#   '의결권',
#   '의기',
#   '의지',
#   '의하다',
#   '이다',
#   '이라고',
#   '이렇다',
#   '이뤄지다',
#   '이며',
#   '이면',
#   '이명희',
#   '이번',
#   '이사',
#   '이사회',
#   '이상',
#   '이어지다',
#   '이윤',
#   '이익',
#   '인하다',
#   '일명',
#   '일본항공',
#   '일선',
#   '일원',
#   '입장',
#   '있다',
#   '자다',
#   '자명하다',
#   '장담',
#   '장이',
#   '재무',
#   '저지',
#   '적극',
#   '전격',
#   '전무',
#   '전문',
#   '전선',
#   '전세기',
#   '전적',
#   '정립',
#   '정석',
#   '정점',
#   '제기',
#   '제도',
#   '제시',
#   '제안',
#   '조건',
#   '조원태',
#   '조현민',
#   '조현아',
#   '좌우',
#   '주다',
#   '주식',
#   '주주',
#   '주주총회',
#   '중심',
#   '증진',
#   '지금',
#   '지배구조',
#   '지속',
#   '지원',
#   '지주사',
#   '직후',
#   '처럼',
#   '처분',
#   '체결',
#   '체제',
#   '촉발',
#   '총수',
#   '최선',
#   '추구',
#   '취득',
#   '취지',
#   '치닫다',
#   '치솟다',
#   '카카오',
#   '켜지다',
#   '키로',
#   '탑승',
#   '태평양',
#   '통한',
#   '통해',
#   '투자',
#   '투합',
#   '특정',
#   '특히',
#   '파산하다',
#   '파상',
#   '펀드',
#   '포함',
#   '필요하다',
#   '하고',
#   '하다',
#   '하지만',
#   '한국',
#   '한진',
#   '한층',
#   '한편',
#   '함께',
#   '합산',
#   '합의',
#   '항공',
#   '항공대',
#   '해석',
#   '행사',
#   '향배',
#   '허다',
#   '혁신',
#   '현재',
#   '현행법',
#   '협력',
#   '홀딩스',
#   '확보',
#   '확실하다',
#   '확인',
#   '활동',
#   '회사',
#   '회장',
#   '획득',
#   '효율',
#   '훨씬',
#   '희영',
#   '힘들다'],
#  ['가늠',
#   '가능성',
#   '가능하다',
#   '가다',
#   '가르다',
#   '가운데',
#   '가족',
#   '가지',
#   '가치',
#   '간부',
#   '간인',
#   '갈다',
#   '갈등',
#   '감사하다',
#   '감안',
#   '감염',
#   '감염증',
#   '강화하다',
#   '갖다',
#   '같다',
#   '개발',
#   '개선',
#   '개인',
#   '거나',
#   '건설',
#   '격리',
#   '격화할',
#   '결단',
#   '결심',
#   '결정',
#   '결집',
#   '결합',
#   '경영',
#   '경영인',
#   '경영학',
#   '경우',
#   '경쟁',
#   '계기',
#   '계약',
#   '계열',
#   '고가',
#   '고문',
#   '고민',
#   '고심',
#   '공감',
#   '공개',
#   '공동',
#   '공세',
#   '공시',
#   '과정',
#   '관계자',
#   '관리자',
#   '관심',
#   '교민',
#   '교수',
#   '구조',
#   '구축',
#   '구현',
#   '국민',
#   '국민연금',
#   '그것',
#   '그동안',
#   '그래서',
#   '그러하다',
#   '그런데',
#   '그렇다',
#   '그레이스',
#   '그룹',
#   '그리고',
#   '그만큼',
#   '기간',
#   '기다',
#   '기사',
#   '기업',
#   '기자',
#   '기존',
#   '기타',
#   '김경래',
#   '김경준',
#   '김포공항',
#   '깊다',
#   '까지',
#   '까지는',
#   '꾸준하다',
#   '나머지',
#   '나서다',
#   '남매',
#   '남아',
#   '내다',
#   '내다보다',
#   '노동조합',
#   '노력',
#   '노조',
#   '노출',
#   '누나',
#   '늘다',
#   '다가오다',
#   '다녀오다',
#   '다른',
#   '다음',
#   '단기',
#   '당국',
#   '대다',
#   '대목',
#   '대표자',
#   '대한',
#   '대한항공',
#   '대해',
#   '대호',
#   '덧붙이다',
#   '델타항공',
#   '도입',
#   '도착',
#   '동생',
#   '동안',
#   '돼다',
#   '되다',
#   '들다',
#   '따르다',
#   '때문',
#   '또는',
#   '라고는',
#   '라디오',
#   '라며',
#   '마음',
#   '마치',
#   '만큼은',
#   '많다',
#   '명시',
#   '명의',
#   '모든',
#   '모범',
#   '모이',
#   '모집',
#   '목적',
#   '몰리다',
#   '무겁다',
#   '무게',
#   '바로',
#   '박민정',
#   '밖에',
#   '반도',
#   '발생',
#   '발원',
#   '발전',
#   '발표',
#   '밝히다',
#   '방식',
#   '방어',
#   '방향',
#   '배경',
#   '배수',
#   '배정',
#   '배제',
#   '법무',
#   '법인',
#   '변수',
#   '보다',
#   '보유',
#   '보이다',
#   '본격',
#   '부담스럽다',
#   '부사',
#   '부터',
#   '부회장',
#   '분구',
#   '분들',
#   '분명하다',
#   '분쟁',
#   '불가능하다',
#   '불거지다',
#   '불구',
#   '비롯',
#   '비율',
#   '비행',
#   '빨갛다',
#   '사내',
#   '사다',
#   '사모펀드',
#   '사실',
#   '사인',
#   '사장',
#   '사정',
#   '사항',
#   '상황',
#   '새롭다',
#   '서다',
#   '선임',
#   '선화',
#   '설명',
#   '성부',
#   '성장',
#   '세력',
#   '소외',
#   '수당',
#   '수준',
#   '쉬다',
#   '스케줄',
#   '승무원',
#   '시간',
#   '시사',
#   '시점',
#   '신종',
#   '신청',
#   '실어',
#   '심각하다',
#   '아니다',
#   '아마',
#   '아쉬움',
#   '아우르다',
#   '아직',
#   '안전',
#   '않다',
#   '알려지다',
#   '앞두다',
#   '앞서',
#   '어느',
#   '어떻다',
#   '어린이',
#   '어머니',
#   '업계',
#   '없다',
#   '에겐',
#   '에도',
#   '에서',
#   '에서는',
#   '에선',
#   '여기',
#   '여성부',
#   '역시',
#   '연대',
#   '연합',
#   '열리다',
#   '영진',
#   '예단',
#   '예정',
#   '오다',
#   '오르다',
#   '오전',
#   '용기',
#   '우려',
#   '우리',
#   '우한',
#   '우호',
#   '운항',
#   '웃다',
#   '위기',
#   '위해',
#   '위험',
#   '위협',
#   '유리하다',
#   '으로서',
#   '으로써',
#   '으론',
#   '의결권',
#   '의기',
#   '의지',
#   '의하다',
#   '이다',
#   '이라고',
#   '이렇다',
#   '이루어지다',
#   '이뤄지다',
#   '이며',
#   '이면',
#   '이명희',
#   '이번',
#   '이사',
#   '이사회',
#   '이상',
#   '이야기',
#   '이어지다',
#   '이윤',
#   '이익',
#   '이틀',
#   '인근',
#   '인하다',
#   '일명',
#   '일반',
#   '일본항공',
#   '일선',
#   '일원',
#   '입장',
#   '있다',
#   '자가',
#   '자다',
#   '자명하다',
#   '자원',
#   '장담',
#   '장이',
#   '장인',
#   '재무',
#   '저지',
#   '저희',
#   '적극',
#   '전격',
#   '전무',
#   '전문',
#   '전선',
#   '전세기',
#   '전적',
#   '전화',
#   '정립',
#   '정보',
#   '정부',
#   '정석',
#   '정점',
#   '제공',
#   '제기',
#   '제도',
#   '제시',
#   '제안',
#   '조건',
#   '조원태',
#   '조치',
#   '조현민',
#   '조현아',
#   '좌우',
#   '주간',
#   '주다',
#   '주식',
#   '주주',
#   '주주총회',
#   '줄어들다',
#   '중간',
#   '중국',
#   '중심',
#   '중인',
#   '증진',
#   '지금',
#   '지배구조',
#   '지부',
#   '지속',
#   '지역',
#   '지원',
#   '지인',
#   '지주사',
#   '지켜보다',
#   '직원',
#   '직접',
#   '직후',
#   '진행',
#   '짚다',
#   '처럼',
#   '처분',
#   '처우',
#   '처음',
#   '체결',
#   '체류',
#   '체제',
#   '촉발',
#   '총수',
#   '최강',
#   '최선',
#   '추가',
#   '추구',
#   '출발',
#   '취득',
#   '취지',
#   '치닫다',
#   '치솟다',
#   '카카오',
#   '켜지다',
#   '코로나바이러스',
#   '키로',
#   '탑승',
#   '태우다',
#   '태운',
#   '태평양',
#   '텐데',
#   '톈허공항',
#   '통한',
#   '통해',
#   '투자',
#   '투합',
#   '특정',
#   '특히',
#   '파산하다',
#   '파상',
#   '펀드',
#   '포함',
#   '필요하다',
#   '하고',
#   '하다',
#   '하지만',
#   '한국',
#   '한국인',
#   '한진',
#   '한층',
#   '한테',
#   '한편',
#   '함께',
#   '합산',
#   '합의',
#   '항공',
#   '항공대',
#   '해석',
#   '행사',
#   '향배',
#   '허다',
#   '혁신',
#   '현재',
#   '현행법',
#   '협력',
#   '협의',
#   '홀딩스',
#   '확보',
#   '확실하다',
#   '확인',
#   '활동',
#   '회사',
#   '회장',
#   '획득',
#   '효율',
#   '후베이성',
#   '훨씬',
#   '희영',
#   '힘들다'],
#  ['가능성',
#   '가다',
#   '가운데',
#   '가족',
#   '가지',
#   '가치',
#   '갈등',
#   '감안',
#   '갖다',
#   '같다',
#   '개발',
#   '개선',
#   '개인',
#   '건설',
#   '격리',
#   '경영',
#   '경영인',
#   '경우',
#   '경쟁',
#   '계약',
#   '고가',
#   '고문',
#   '고심',
#   '공감',
#   '공동',
#   '공시',
#   '과정',
#   '관심',
#   '교수',
#   '구조',
#   '구축',
#   '구현',
#   '국민연금',
#   '그것',
#   '그렇다',
#   '그레이스',
#   '그룹',
#   '기간',
#   '기다',
#   '기업',
#   '기자',
#   '기존',
#   '김경준',
#   '김포공항',
#   '까지',
#   '나머지',
#   '나서다',
#   '남매',
#   '내다',
#   '노력',
#   '노조',
#   '늘다',
#   '다가오다',
#   '다녀오다',
#   '대한',
#   '대한항공',
#   '대해',
#   '덧붙이다',
#   '델타항공',
#   '도입',
#   '도착',
#   '동생',
#   '동안',
#   '돼다',
#   '되다',
#   '모범',
#   '모친',
#   '무관',
#   '반도',
#   '발전',
#   '발표',
#   '밝히다',
#   '방식',
#   '배경',
#   '법무',
#   '법인',
#   '변수',
#   '보다',
#   '보유',
#   '보이다',
#   '복귀',
#   '본격',
#   '부사',
#   '부회장',
#   '분구',
#   '분쟁',
#   '비롯',
#   '비행',
#   '사내',
#   '사모펀드',
#   '사실',
#   '상황',
#   '설명',
#   '성부',
#   '성장',
#   '수당',
#   '수준',
#   '쉬다',
#   '스케줄',
#   '승무원',
#   '심각하다',
#   '아쉬움',
#   '아직',
#   '않다',
#   '알려지다',
#   '앞두다',
#   '어머니',
#   '없다',
#   '에도',
#   '에서',
#   '에서는',
#   '여기',
#   '역시',
#   '연대',
#   '영진',
#   '오다',
#   '오전',
#   '우한',
#   '우호',
#   '위기',
#   '위해',
#   '으로서',
#   '으로서는',
#   '의결권',
#   '의하다',
#   '이다',
#   '이라고',
#   '이렇다',
#   '이루어지다',
#   '이뤄지다',
#   '이며',
#   '이명희',
#   '이번',
#   '이사',
#   '이익',
#   '일명',
#   '일선',
#   '입장',
#   '있다',
#   '자가',
#   '자원',
#   '장담',
#   '장이',
#   '재무',
#   '적극',
#   '전격',
#   '전무',
#   '전문',
#   '전선',
#   '전세기',
#   '정립',
#   '정보',
#   '정부',
#   '정석',
#   '제도',
#   '제안',
#   '조원태',
#   '조현민',
#   '조현아',
#   '주간',
#   '주식',
#   '주주',
#   '주주총회',
#   '줄어들다',
#   '중국',
#   '중인',
#   '지배구조',
#   '지원',
#   '지주사',
#   '직원',
#   '처럼',
#   '처우',
#   '처음',
#   '총수',
#   '최선',
#   '치닫다',
#   '카카오',
#   '탑승',
#   '태평양',
#   '통해',
#   '펀드',
#   '포함',
#   '필요하다',
#   '하고',
#   '하다',
#   '하지만',
#   '한진',
#   '함께',
#   '합의',
#   '해석',
#   '행보',
#   '행사',
#   '향배',
#   '허다',
#   '혁신',
#   '현재',
#   '협력',
#   '홀딩스',
#   '화해',
#   '확보',
#   '확실하다',
#   '확인',
#   '활동',
#   '회사',
#   '회장',
#   '효율',
#   '힘들다'],
#  ['가능성',
#   '가다',
#   '가운데',
#   '가족',
#   '가지',
#   '가치',
#   '간의',
#   '갈등',
#   '감안',
#   '강화하다',
#   '갖다',
#   '같다',
#   '개발',
#   '개선',
#   '개인',
#   '건설',
#   '격리',
#   '경영',
#   '경영인',
#   '경우',
#   '경쟁',
#   '계약',
#   '고가',
#   '고문',
#   '고심',
#   '공감',
#   '공동',
#   '공시',
#   '과반수',
#   '과정',
#   '관심',
#   '교민',
#   '교수',
#   '구조',
#   '구축',
#   '구현',
#   '국민연금',
#   '그것',
#   '그런데',
#   '그렇다',
#   '그레이스',
#   '그룹',
#   '그리고',
#   '기간',
#   '기다',
#   '기업',
#   '기자',
#   '기존',
#   '김경준',
#   '김포공항',
#   '까지',
#   '나머지',
#   '나서다',
#   '남매',
#   '내다',
#   '내다보다',
#   '노력',
#   '노조',
#   '누나',
#   '늘다',
#   '다가오다',
#   '다녀오다',
#   '대표',
#   '대한',
#   '대한항공',
#   '대해',
#   '덧붙이다',
#   '델타항공',
#   '도입',
#   '도착',
#   '동생',
#   '동안',
#   '돼다',
#   '되다',
#   '들다',
#   '때문',
#   '라며',
#   '모범',
#   '모친',
#   '무관',
#   '반도',
#   '발전',
#   '발표',
#   '밝히다',
#   '방식',
#   '배경',
#   '벌어지다',
#   '법무',
#   '법인',
#   '변수',
#   '보다',
#   '보유',
#   '보이다',
#   '복귀',
#   '본격',
#   '부사',
#   '부터',
#   '부회장',
#   '분구',
#   '분쟁',
#   '비롯',
#   '비행',
#   '빠지다',
#   '사내',
#   '사모펀드',
#   '사실',
#   '상황',
#   '선임',
#   '설명',
#   '성부',
#   '성장',
#   '수당',
#   '수준',
#   '쉬다',
#   '스케줄',
#   '승무원',
#   '시간',
#   '심각하다',
#   '아쉬움',
#   '아직',
#   '않다',
#   '알려지다',
#   '앞두다',
#   '어머니',
#   '어젯밤',
#   '없다',
#   '에도',
#   '에서',
#   '에서는',
#   '여기',
#   '여동생',
#   '역시',
#   '연대',
#   '영진',
#   '오다',
#   '오전',
#   '우한',
#   '우호',
#   '위기',
#   '위해',
#   '유지',
#   '으로서',
#   '으로서는',
#   '의결권',
#   '의하다',
#   '이다',
#   '이라고',
#   '이렇다',
#   '이루어지다',
#   '이뤄지다',
#   '이며',
#   '이명희',
#   '이미',
#   '이번',
#   '이사',
#   '이사회',
#   '이익',
#   '이준희',
#   '일명',
#   '일반',
#   '일선',
#   '잃다',
#   '입장',
#   '있다',
#   '자가',
#   '자신',
#   '자원',
#   '장담',
#   '장이',
#   '재무',
#   '적극',
#   '전격',
#   '전무',
#   '전문',
#   '전선',
#   '전세기',
#   '정립',
#   '정보',
#   '정부',
#   '정석',
#   '제도',
#   '제안',
#   '조원태',
#   '조현민',
#   '조현아',
#   '주간',
#   '주식',
#   '주의',
#   '주주',
#   '주주총회',
#   '줄어들다',
#   '중국',
#   '중심',
#   '중인',
#   '지배구조',
#   '지원',
#   '지주사',
#   '직원',
#   '찬성',
#   '처럼',
#   '처우',
#   '처음',
#   '체제',
#   '총수',
#   '최선',
#   '취재',
#   '치닫다',
#   '카카오',
#   '탑승',
#   '태평양',
#   '통해',
#   '펀드',
#   '포함',
#   '필요하다',
#   '하고',
#   '하다',
#   '하지만',
#   '한국',
#   '한진',
#   '함께',
#   '합의',
#   '해석',
#   '행동',
#   '행보',
#   '행사',
#   '향배',
#   '허다',
#   '혁신',
#   '현재',
#   '협력',
#   '홀딩스',
#   '화해',
#   '확보',
#   '확실하다',
#   '확인',
#   '활동',
#   '회사',
#   '회장',
#   '효율',
#   '힘들다'],
#  ['가능성',
#   '가다',
#   '가운데',
#   '가족',
#   '가지',
#   '가치',
#   '간의',
#   '갈등',
#   '감안',
#   '강화하다',
#   '갖다',
#   '같다',
#   '개발',
#   '개선',
#   '개인',
#   '거치다',
#   '건설',
#   '격리',
#   '결정',
#   '경영',
#   '경영인',
#   '경영학',
#   '경우',
#   '경쟁',
#   '계약',
#   '고가',
#   '고문',
#   '고심',
#   '공감',
#   '공동',
#   '공시',
#   '과반수',
#   '과정',
#   '관계',
#   '관계자',
#   '관심',
#   '교민',
#   '교수',
#   '교체',
#   '구조',
#   '구축',
#   '구현',
#   '국민연금',
#   '그것',
#   '그런데',
#   '그렇다',
#   '그레이스',
#   '그룹',
#   '그리고',
#   '기간',
#   '기다',
#   '기사',
#   '기업',
#   '기자',
#   '기존',
#   '김경준',
#   '김포공항',
#   '까지',
#   '꾸준하다',
#   '나머지',
#   '나서다',
#   '남매',
#   '내다',
#   '내다보다',
#   '네트워크',
#   '노력',
#   '노조',
#   '누나',
#   '늘다',
#   '다가오다',
#   '다녀오다',
#   '다른',
#   '대결',
#   '대표',
#   '대한',
#   '대한항공',
#   '대해',
#   '덧붙이다',
#   '델타항공',
#   '도입',
#   '도착',
#   '동생',
#   '동안',
#   '돼다',
#   '되다',
#   '들다',
#   '따르다',
#   '때문',
#   '라는',
#   '라며',
#   '만약',
#   '만큼',
#   '모두',
#   '모범',
#   '모친',
#   '무관',
#   '물러나다',
#   '물론',
#   '반도',
#   '발전',
#   '발표',
#   '밝히다',
#   '방식',
#   '방향',
#   '배경',
#   '배제',
#   '벌어지다',
#   '법무',
#   '법인',
#   '변수',
#   '보다',
#   '보유',
#   '보이다',
#   '복귀',
#   '복직',
#   '본격',
#   '부결',
#   '부사',
#   '부정',
#   '부터',
#   '부회장',
#   '분구',
#   '분쟁',
#   '불가능하다',
#   '불거지다',
#   '불과하다',
#   '불구',
#   '비롯',
#   '비행',
#   '빠지다',
#   '사내',
#   '사모펀드',
#   '사실',
#   '사업',
#   '사외이사',
#   '사장',
#   '상황',
#   '서다',
#   '선언',
#   '선임',
#   '선택',
#   '설명',
#   '성부',
#   '성장',
#   '세력',
#   '수당',
#   '수준',
#   '쉬다',
#   '스케줄',
#   '승무원',
#   '시간',
#   '신청',
#   '심각하다',
#   '아니다',
#   '아쉬움',
#   '아직',
#   '않다',
#   '알려지다',
#   '앞두다',
#   '어머니',
#   '어젯밤',
#   '얻다',
#   '업계',
#   '없다',
#   '에게',
#   '에도',
#   '에서',
#   '에서는',
#   '여기',
#   '여동생',
#   '역시',
#   '역할',
#   '연대',
#   '연합군',
#   '영진',
#   '예정',
#   '오다',
#   '오전',
#   '요구',
#   '우한',
#   '우호',
#   '위기',
#   '위해',
#   '유지',
#   '으로서',
#   '으로서는',
#   '의결권',
#   '의하다',
#   '이다',
#   '이라고',
#   '이렇다',
#   '이루어지다',
#   '이뤄지다',
#   '이며',
#   '이명희',
#   '이미',
#   '이번',
#   '이사',
#   '이사회',
#   '이상',
#   '이어지다',
#   '이익',
#   '이준희',
#   '이후',
#   '일가',
#   '일명',
#   '일반',
#   '일선',
#   '잃다',
#   '입장',
#   '있다',
#   '자가',
#   '자신',
#   '자원',
#   '잡다',
#   '잡지',
#   '장담',
#   '장이',
#   '재무',
#   '적극',
#   '전격',
#   '전무',
#   '전문',
#   '전선',
#   '전세기',
#   '전해지다',
#   '절대',
#   '정립',
#   '정보',
#   '정부',
#   '정석',
#   '제기',
#   '제도',
#   '제안',
#   '제외',
#   '조양호',
#   '조원태',
#   '조현민',
#   '조현아',
#   '주간',
#   '주식',
#   '주의',
#   '주주',
#   '주주총회',
#   '줄어들다',
#   '중국',
#   '중심',
#   '중인',
#   '지난해',
#   '지배구조',
#   '지원',
#   '지주사',
#   '직원',
#   '직접',
#   '찬성',
#   '처럼',
#   '처우',
#   '처음',
#   '체제',
#   '총수',
#   '최근',
#   '최선',
#   '취재',
#   '치닫다',
#   '카카오',
#   '탑승',
#   '태평양',
#   '통한',
#   '통해',
#   '판단',
#   '펀드',
#   '포기',
#   '포함',
#   '필요하다',
#   '하고',
#   '하다',
#   '하지만',
#   '한국',
#   '한진',
#   '함께',
#   '합의',
#   '합치다',
#   '항공',
#   '해석',
#   '행동',
#   '행보',
#   '행사',
#   '향배',
#   '허다',
#   '혁신',
#   '현재',
#   '협력',
#   '호텔',
#   '홀딩스',
#   '화해',
#   '확보',
#   '확실하다',
#   '확인',
#   '활동',
#   '회사',
#   '회장',
#   '효율',
#   '힘들다'],
#  ['가능성',
#   '가다',
#   '가운데',
#   '가족',
#   '가지',
#   '가치',
#   '갈등',
#   '감안',
#   '강화하다',
#   '갖다',
#   '개발',
#   '개선',
#   '개인',
#   '건설',
#   '격리',
#   '결정',
#   '경영',
#   '경영인',
#   '경우',
#   '계약',
#   '고가',
#   '고문',
#   '공감',
#   '공동',
#   '공시',
#   '과반수',
#   '과정',
#   '관계자',
#   '관련',
#   '관심',
#   '교민',
#   '국민연금',
#   '그동안',
#   '그렇다',
#   '그룹',
#   '그리고',
#   '기간',
#   '기업',
#   '기자',
#   '기존',
#   '기준',
#   '김포공항',
#   '까지',
#   '나서다',
#   '남매',
#   '누나',
#   '늘다',
#   '다녀오다',
#   '다른',
#   '대결',
#   '대표',
#   '대한',
#   '대한항공',
#   '대해',
#   '덧붙이다',
#   '델타항공',
#   '도입',
#   '도착',
#   '동생',
#   '동안',
#   '돼다',
#   '되다',
#   '들다',
#   '따르다',
#   '때문',
#   '라는',
#   '라며',
#   '만큼',
#   '매입',
#   '모두',
#   '모으다',
#   '모친',
#   '밖에',
#   '반도',
#   '발표',
#   '밝히다',
#   '방식',
#   '배경',
#   '법무',
#   '법인',
#   '변수',
#   '보다',
#   '보유',
#   '보이다',
#   '복귀',
#   '본격',
#   '부사',
#   '분석',
#   '분율',
#   '분쟁',
#   '불과하다',
#   '비롯',
#   '비행',
#   '사내',
#   '사모펀드',
#   '사실',
#   '사업',
#   '사외이사',
#   '상황',
#   '선언',
#   '세력',
#   '수당',
#   '수준',
#   '쉬다',
#   '승무원',
#   '아니다',
#   '않다',
#   '알려지다',
#   '앞두다',
#   '양자',
#   '어머니',
#   '얻다',
#   '업계',
#   '없다',
#   '에게',
#   '에도',
#   '에서',
#   '에서는',
#   '여기',
#   '역시',
#   '역할',
#   '연대',
#   '연합',
#   '연합군',
#   '영진',
#   '예정',
#   '오다',
#   '오전',
#   '요구',
#   '우한',
#   '우호',
#   '위기',
#   '위해',
#   '유지',
#   '의결권',
#   '의하다',
#   '이다',
#   '이라고',
#   '이라는',
#   '이렇다',
#   '이뤄지다',
#   '이며',
#   '이명희',
#   '이번',
#   '이사',
#   '이사회',
#   '이상',
#   '이익',
#   '이후',
#   '일가',
#   '일선',
#   '입장',
#   '있다',
#   '자가',
#   '자신',
#   '자원',
#   '잡다',
#   '장담',
#   '장이',
#   '적극',
#   '전망',
#   '전무',
#   '전문',
#   '전선',
#   '전세기',
#   '정부',
#   '정석',
#   '제기',
#   '제도',
#   '제안',
#   '제외',
#   '조양호',
#   '조원태',
#   '조현민',
#   '조현아',
#   '주요',
#   '주주',
#   '주주총회',
#   '중국',
#   '중심',
#   '중인',
#   '지난해',
#   '지배구조',
#   '지주사',
#   '직원',
#   '직접',
#   '참석',
#   '처음',
#   '체제',
#   '총수',
#   '추가',
#   '카카오',
#   '탑승',
#   '태평양',
#   '통해',
#   '투자',
#   '특히',
#   '판단',
#   '펀드',
#   '평가',
#   '포인트',
#   '포함',
#   '필요하다',
#   '하고',
#   '하다',
#   '하지만',
#   '한진',
#   '함께',
#   '합의',
#   '합치다',
#   '해오다',
#   '행사',
#   '혁신',
#   '현재',
#   '협력',
#   '호텔',
#   '확보',
#   '확실하다',
#   '활동',
#   '회장',
#   '효율'],
#  ['가능성',
#   '가다',
#   '가운데',
#   '가족',
#   '가지',
#   '가치',
#   '갈등',
#   '감안',
#   '강화하다',
#   '갖다',
#   '개발',
#   '개선',
#   '개인',
#   '건설',
#   '격리',
#   '결정',
#   '경영',
#   '경영인',
#   '경우',
#   '경쟁',
#   '계약',
#   '고가',
#   '고문',
#   '공감',
#   '공동',
#   '공시',
#   '과반수',
#   '과정',
#   '관계',
#   '관계자',
#   '관련',
#   '관심',
#   '교민',
#   '구조',
#   '구축',
#   '국민연금',
#   '그것',
#   '그동안',
#   '그렇다',
#   '그레이스',
#   '그룹',
#   '그리고',
#   '기간',
#   '기사',
#   '기업',
#   '기자',
#   '기존',
#   '기준',
#   '김포공항',
#   '까지',
#   '꾸준하다',
#   '나서다',
#   '남매',
#   '내다',
#   '누나',
#   '늘다',
#   '다가오다',
#   '다녀오다',
#   '다른',
#   '대결',
#   '대표',
#   '대한',
#   '대한항공',
#   '대해',
#   '대호',
#   '덧붙이다',
#   '델타항공',
#   '도입',
#   '도착',
#   '동생',
#   '동안',
#   '돼다',
#   '되다',
#   '들다',
#   '따르다',
#   '때문',
#   '라는',
#   '라며',
#   '만큼',
#   '많다',
#   '매입',
#   '명의',
#   '모두',
#   '모으다',
#   '모친',
#   '목적',
#   '밖에',
#   '반도',
#   '발전',
#   '발표',
#   '밝히다',
#   '방식',
#   '방향',
#   '배경',
#   '법무',
#   '법인',
#   '변수',
#   '보다',
#   '보유',
#   '보이다',
#   '복귀',
#   '본격',
#   '부사',
#   '분류',
#   '분석',
#   '분율',
#   '분쟁',
#   '불과하다',
#   '비롯',
#   '비행',
#   '사내',
#   '사모펀드',
#   '사실',
#   '사업',
#   '사외이사',
#   '상황',
#   '선언',
#   '설명',
#   '성장',
#   '세력',
#   '수당',
#   '수준',
#   '쉬다',
#   '승무원',
#   '심각하다',
#   '아니다',
#   '않다',
#   '알려지다',
#   '앞두다',
#   '양자',
#   '어머니',
#   '얻다',
#   '업계',
#   '없다',
#   '에게',
#   '에도',
#   '에서',
#   '에서는',
#   '여기',
#   '여동생',
#   '역시',
#   '역할',
#   '연대',
#   '연합',
#   '연합군',
#   '영진',
#   '예정',
#   '오다',
#   '오전',
#   '요구',
#   '우한',
#   '우호',
#   '위기',
#   '위해',
#   '유지',
#   '의결권',
#   '의하다',
#   '이다',
#   '이라고',
#   '이라는',
#   '이렇다',
#   '이뤄지다',
#   '이며',
#   '이명희',
#   '이번',
#   '이사',
#   '이사회',
#   '이상',
#   '이익',
#   '이후',
#   '일가',
#   '일선',
#   '입장',
#   '있다',
#   '자가',
#   '자신',
#   '자원',
#   '잡다',
#   '장담',
#   '장이',
#   '재무',
#   '적극',
#   '전망',
#   '전무',
#   '전문',
#   '전선',
#   '전세기',
#   '정부',
#   '정석',
#   '제기',
#   '제도',
#   '제안',
#   '제외',
#   '조양호',
#   '조원태',
#   '조현민',
#   '조현아',
#   '주식',
#   '주요',
#   '주의',
#   '주주',
#   '주주총회',
#   '중국',
#   '중심',
#   '중인',
#   '지난해',
#   '지배구조',
#   '지주사',
#   '직원',
#   '직접',
#   '참석',
#   '처음',
#   '체제',
#   '총수',
#   '추가',
#   '카카오',
#   '탑승',
#   '태평양',
#   '통한',
#   '통해',
#   '투자',
#   '특수',
#   '특히',
#   '판단',
#   '펀드',
#   '평가',
#   '포인트',
#   '포함',
#   '풀이',
#   '필요하다',
#   '하고',
#   '하다',
#   '하지만',
#   '한진',
#   '함께',
#   '합의',
#   '합치다',
#   '해오다',
#   '행동',
#   '행사',
#   '혁신',
#   '현재',
#   '협력',
#   '호텔',
#   '홀딩스',
#   '확보',
#   '확실하다',
#   '활동',
#   '회사',
#   '회장',
#   '효율'],
#  ['가능성',
#   '가다',
#   '가세',
#   '가운데',
#   '가족',
#   '가지',
#   '가치',
#   '갈등',
#   '감안',
#   '강화하다',
#   '갖다',
#   '같다',
#   '개발',
#   '개선',
#   '개인',
#   '건설',
#   '격리',
#   '결정',
#   '경영',
#   '경영인',
#   '경우',
#   '경쟁',
#   '계약',
#   '고가',
#   '고문',
#   '공감',
#   '공동',
#   '공시',
#   '과반수',
#   '과정',
#   '관계',
#   '관계자',
#   '관련',
#   '관심',
#   '교민',
#   '구조',
#   '구축',
#   '구현',
#   '국민연금',
#   '그것',
#   '그동안',
#   '그렇다',
#   '그레이스',
#   '그룹',
#   '그리고',
#   '기간',
#   '기사',
#   '기업',
#   '기자',
#   '기존',
#   '기준',
#   '김포공항',
#   '까지',
#   '꾸준하다',
#   '나머지',
#   '나서다',
#   '남매',
#   '내다',
#   '노력',
#   '누나',
#   '늘다',
#   '다가오다',
#   '다녀오다',
#   '다른',
#   '대결',
#   '대표',
#   '대한',
#   '대한항공',
#   '대해',
#   '대호',
#   '덧붙이다',
#   '델타항공',
#   '도입',
#   '도착',
#   '동생',
#   '동안',
#   '돼다',
#   '되다',
#   '들다',
#   '따르다',
#   '때문',
#   '라는',
#   '라며',
#   '만큼',
#   '많다',
#   '매입',
#   '명의',
#   '모두',
#   '모범',
#   '모으다',
#   '모친',
#   '목적',
#   '밖에',
#   '반도',
#   '발전',
#   '발표',
#   '밝히다',
#   '방식',
#   '방향',
#   '배경',
#   '법무',
#   '법인',
#   '변수',
#   '보다',
#   '보유',
#   '보이다',
#   '복귀',
#   '본격',
#   '부사',
#   '분류',
#   '분석',
#   '분율',
#   '분쟁',
#   '불과하다',
#   '비롯',
#   '비행',
#   '사내',
#   '사모펀드',
#   '사실',
#   '사업',
#   '사외이사',
#   '상황',
#   '선언',
#   '선임',
#   '설명',
#   '성부',
#   '성장',
#   '세력',
#   '수당',
#   '수준',
#   '쉬다',
#   '승무원',
#   '심각하다',
#   '아니다',
#   '않다',
#   '알려지다',
#   '앞두다',
#   '양자',
#   '어머니',
#   '얻다',
#   '업계',
#   '없다',
#   '에게',
#   '에도',
#   '에서',
#   '에서는',
#   '여기',
#   '여동생',
#   '역시',
#   '역할',
#   '연대',
#   '연합',
#   '연합군',
#   '영진',
#   '예상',
#   '예정',
#   '오다',
#   '오전',
#   '요구',
#   '우한',
#   '우호',
#   '위기',
#   '위해',
#   '유지',
#   '의결권',
#   '의하다',
#   '이다',
#   '이라고',
#   '이라는',
#   '이렇다',
#   '이뤄지다',
#   '이며',
#   '이명희',
#   '이번',
#   '이사',
#   '이사회',
#   '이상',
#   '이익',
#   '이후',
#   '일가',
#   '일선',
#   '입장',
#   '있다',
#   '자가',
#   '자신',
#   '자원',
#   '잡다',
#   '장담',
#   '장이',
#   '재무',
#   '적극',
#   '전망',
#   '전무',
#   '전문',
#   '전선',
#   '전세기',
#   '정립',
#   '정부',
#   '정석',
#   '제기',
#   '제도',
#   '제안',
#   '제외',
#   '조양호',
#   '조원태',
#   '조현민',
#   '조현아',
#   '주식',
#   '주요',
#   '주의',
#   '주장',
#   '주주',
#   '주주총회',
#   '중국',
#   '중심',
#   '중인',
#   '지난해',
#   '지배구조',
#   '지주사',
#   '직원',
#   '직접',
#   '참석',
#   '처음',
#   '체결',
#   '체제',
#   '총수',
#   '추가',
#   '치열하다',
#   '카카오',
#   '탑승',
#   '태평양',
#   '통한',
#   '통해',
#   '퇴진',
#   '투자',
#   '특수',
#   '특히',
#   '판단',
#   '펀드',
#   '평가',
#   '포인트',
#   '포함',
#   '풀이',
#   '필요하다',
#   '하고',
#   '하다',
#   '하지만',
#   '한진',
#   '함께',
#   '합의',
#   '합치다',
#   '해오다',
#   '행동',
#   '행사',
#   '혁신',
#   '현재',
#   '협력',
#   '형성',
#   '호텔',
#   '홀딩스',
#   '확보',
#   '확실하다',
#   '활동',
#   '회사',
#   '회장',
#   '효율'],
#  ['가능성',
#   '가다',
#   '가족',
#   '가치',
#   '각자',
#   '강조',
#   '강화하다',
#   '갖다',
#   '개발',
#   '개선',
#   '개인',
#   '건설',
#   '격리',
#   '결정',
#   '경영',
#   '경영인',
#   '경우',
#   '경쟁',
#   '계약',
#   '고가',
#   '고문',
#   '공감',
#   '공동',
#   '공시',
#   '과정',
#   '관계',
#   '관계자',
#   '관심',
#   '교민',
#   '구조',
#   '구축',
#   '국민연금',
#   '그것',
#   '그동안',
#   '그렇다',
#   '그레이스',
#   '그룹',
#   '그리고',
#   '기업',
#   '기자',
#   '기존',
#   '까지',
#   '꾸준하다',
#   '나서다',
#   '나오다',
#   '남매',
#   '내다',
#   '누나',
#   '다가오다',
#   '대결',
#   '대표',
#   '대한',
#   '대한항공',
#   '대해',
#   '더하다',
#   '델타항공',
#   '도입',
#   '동맹',
#   '동생',
#   '돼다',
#   '되다',
#   '들다',
#   '따르다',
#   '때문',
#   '라며',
#   '모두',
#   '모친',
#   '반도',
#   '발전',
#   '발표',
#   '밝히다',
#   '방식',
#   '방향',
#   '법무',
#   '법인',
#   '변수',
#   '보다',
#   '보유',
#   '보이다',
#   '본격',
#   '부사',
#   '분석',
#   '분율',
#   '분쟁',
#   '비롯',
#   '비행',
#   '사내',
#   '사모펀드',
#   '사실',
#   '사업',
#   '사외이사',
#   '상황',
#   '서다',
#   '선임',
#   '설명',
#   '성부',
#   '성장',
#   '세력',
#   '승무원',
#   '심각하다',
#   '않다',
#   '알려지다',
#   '앞두다',
#   '어머니',
#   '얻다',
#   '업계',
#   '없다',
#   '에게',
#   '에서',
#   '에선',
#   '여기',
#   '역시',
#   '역할',
#   '연합',
#   '연합군',
#   '영진',
#   '예정',
#   '오다',
#   '오전',
#   '요구',
#   '우군',
#   '우한',
#   '우호',
#   '위기',
#   '위해',
#   '유지',
#   '의결권',
#   '의하다',
#   '이다',
#   '이라고',
#   '이란',
#   '이뤄지다',
#   '이며',
#   '이명희',
#   '이번',
#   '이사',
#   '이사회',
#   '이상',
#   '이익',
#   '이후',
#   '일가',
#   '일선',
#   '입장',
#   '있다',
#   '자가',
#   '자원',
#   '잡다',
#   '장이',
#   '재무',
#   '적극',
#   '전망',
#   '전무',
#   '전문',
#   '전선',
#   '전세기',
#   '정부',
#   '정석',
#   '제기',
#   '제도',
#   '제안',
#   '제외',
#   '조양호',
#   '조원태',
#   '조현민',
#   '조현아',
#   '주식',
#   '주요',
#   '주주',
#   '주주총회',
#   '중국',
#   '중심',
#   '지난해',
#   '지배구조',
#   '지주사',
#   '직원',
#   '직접',
#   '참석',
#   '체제',
#   '총수',
#   '최대',
#   '추가',
#   '치열하다',
#   '카카오',
#   '탑승',
#   '태평양',
#   '통해',
#   '투자',
#   '특수',
#   '판단',
#   '펀드',
#   '포인트',
#   '포함',
#   '풀이',
#   '필요하다',
#   '하고',
#   '하다',
#   '한진',
#   '함께',
#   '합의',
#   '합치다',
#   '해오다',
#   '행사',
#   '혁신',
#   '현재',
#   '협력',
#   '형성',
#   '호텔',
#   '홀딩스',
#   '화해',
#   '확보',
#   '활동',
#   '회장',
#   '효율'],
#  ['가능성',
#   '가다',
#   '가족',
#   '가치',
#   '각자',
#   '강조',
#   '강화하다',
#   '갖다',
#   '개발',
#   '개선',
#   '개인',
#   '건설',
#   '격리',
#   '결정',
#   '경영',
#   '경영인',
#   '경우',
#   '경쟁',
#   '계약',
#   '고가',
#   '고문',
#   '고민',
#   '공감',
#   '공동',
#   '공시',
#   '과반수',
#   '과정',
#   '관계',
#   '관계자',
#   '관련',
#   '관심',
#   '교민',
#   '구조',
#   '구축',
#   '국민연금',
#   '그것',
#   '그동안',
#   '그렇다',
#   '그레이스',
#   '그룹',
#   '그리고',
#   '기간',
#   '기업',
#   '기자',
#   '기존',
#   '까지',
#   '꾸준하다',
#   '나서다',
#   '나오다',
#   '남매',
#   '내다',
#   '노력',
#   '누나',
#   '다가오다',
#   '대결',
#   '대다',
#   '대표',
#   '대한',
#   '대한항공',
#   '대해',
#   '더하다',
#   '덧붙이다',
#   '델타항공',
#   '도입',
#   '동맹',
#   '동생',
#   '돼다',
#   '되다',
#   '들다',
#   '따르다',
#   '때문',
#   '라며',
#   '많다',
#   '모두',
#   '모친',
#   '목적',
#   '반대',
#   '반도',
#   '발전',
#   '발표',
#   '밝히다',
#   '방식',
#   '방향',
#   '법무',
#   '법인',
#   '변수',
#   '보다',
#   '보유',
#   '보이다',
#   '본격',
#   '부사',
#   '분류',
#   '분석',
#   '분율',
#   '분쟁',
#   '비롯',
#   '비행',
#   '사내',
#   '사모펀드',
#   '사실',
#   '사업',
#   '사외이사',
#   '상황',
#   '서다',
#   '선임',
#   '설명',
#   '성부',
#   '성장',
#   '세력',
#   '승무원',
#   '심각하다',
#   '아이',
#   '않다',
#   '알려지다',
#   '앞두다',
#   '어머니',
#   '얻다',
#   '업계',
#   '없다',
#   '에게',
#   '에서',
#   '에선',
#   '여기',
#   '역시',
#   '역할',
#   '연합',
#   '연합군',
#   '영진',
#   '예정',
#   '오다',
#   '오전',
#   '요구',
#   '우군',
#   '우한',
#   '우호',
#   '위기',
#   '위해',
#   '유지',
#   '의결권',
#   '의하다',
#   '이다',
#   '이라고',
#   '이란',
#   '이뤄지다',
#   '이며',
#   '이명희',
#   '이번',
#   '이사',
#   '이사회',
#   '이상',
#   '이익',
#   '이후',
#   '일가',
#   '일선',
#   '입장',
#   '있다',
#   '자가',
#   '자원',
#   '잡다',
#   '장이',
#   '재무',
#   '적극',
#   '전망',
#   '전무',
#   '전문',
#   '전선',
#   '전세기',
#   '정부',
#   '정석',
#   '제기',
#   '제도',
#   '제안',
#   '제외',
#   '조양호',
#   '조원태',
#   '조현민',
#   '조현아',
#   '주식',
#   '주요',
#   '주의',
#   '주주',
#   '주주총회',
#   '중국',
#   '중심',
#   '증진',
#   '지난해',
#   '지배구조',
#   '지주사',
#   '직원',
#   '직접',
#   '참석',
#   '체결',
#   '체제',
#   '총수',
#   '최대',
#   '추가',
#   '치열하다',
#   '카카오',
#   '케이',
#   '탑승',
#   '태평양',
#   '통한',
#   '통해',
#   '투자',
#   '특수',
#   '판단',
#   '펀드',
#   '포인트',
#   '포함',
#   '풀이',
#   '필요하다',
#   '하고',
#   '하다',
#   '한진',
#   '함께',
#   '합의',
#   '합치다',
#   '해오다',
#   '행사',
#   '혁신',
#   '현재',
#   '협력',
#   '형성',
#   '호텔',
#   '홀딩스',
#   '화해',
#   '확보',
#   '활동',
#   '회사',
#   '회장',
#   '효율'],
#  ['가능성',
#   '가다',
#   '가족',
#   '가치',
#   '각자',
#   '강조',
#   '강화하다',
#   '개발',
#   '개선',
#   '건설',
#   '격리',
#   '결정',
#   '경영',
#   '경영인',
#   '경우',
#   '경쟁',
#   '계약',
#   '고가',
#   '고문',
#   '공감',
#   '공동',
#   '공시',
#   '관계',
#   '관계자',
#   '관련',
#   '관심',
#   '국민연금',
#   '그것',
#   '그동안',
#   '그렇다',
#   '그레이스',
#   '그룹',
#   '그리고',
#   '기업',
#   '기자',
#   '기존',
#   '까지',
#   '나서다',
#   '남매',
#   '내다',
#   '내용',
#   '누나',
#   '늘다',
#   '대결',
#   '대표',
#   '대한',
#   '대한항공',
#   '대해',
#   '더하다',
#   '델타항공',
#   '도입',
#   '동맹',
#   '동생',
#   '돼다',
#   '되다',
#   '들다',
#   '따르다',
#   '때문',
#   '모두',
#   '모친',
#   '반대',
#   '반도',
#   '발전',
#   '발표',
#   '밝히다',
#   '방식',
#   '법무',
#   '법인',
#   '변수',
#   '보다',
#   '보유',
#   '보이다',
#   '부사',
#   '부정',
#   '분석',
#   '분율',
#   '분쟁',
#   '비롯',
#   '비행',
#   '사내',
#   '사모펀드',
#   '사실',
#   '사업',
#   '사외이사',
#   '상황',
#   '서다',
#   '선임',
#   '성부',
#   '성장',
#   '세력',
#   '승무원',
#   '심각하다',
#   '아이',
#   '않다',
#   '알려지다',
#   '앞두다',
#   '어머니',
#   '얻다',
#   '업계',
#   '없다',
#   '에게',
#   '에서',
#   '에서는',
#   '에선',
#   '여기',
#   '연합',
#   '연합군',
#   '영진',
#   '예상',
#   '예정',
#   '오다',
#   '오전',
#   '요구',
#   '우군',
#   '우한',
#   '우호',
#   '위기',
#   '위해',
#   '유지',
#   '의결권',
#   '의하다',
#   '이다',
#   '이라고',
#   '이라는',
#   '이란',
#   '이렇다',
#   '이뤄지다',
#   '이며',
#   '이명희',
#   '이번',
#   '이사',
#   '이사회',
#   '이익',
#   '이후',
#   '일가',
#   '일선',
#   '입장',
#   '있다',
#   '자가',
#   '잡다',
#   '장이',
#   '적극',
#   '전망',
#   '전무',
#   '전문',
#   '전세기',
#   '정석',
#   '제도',
#   '제안',
#   '제외',
#   '조양호',
#   '조원태',
#   '조현민',
#   '조현아',
#   '주식',
#   '주요',
#   '주의',
#   '주주',
#   '주주총회',
#   '중심',
#   '지난해',
#   '지배구조',
#   '참석',
#   '참여',
#   '체제',
#   '총수',
#   '최대',
#   '추가',
#   '추천',
#   '치열하다',
#   '카카오',
#   '케이',
#   '탑승',
#   '태평양',
#   '통해',
#   '투자',
#   '특수',
#   '판단',
#   '펀드',
#   '평가',
#   '포인트',
#   '포함',
#   '필요하다',
#   '하고',
#   '하다',
#   '한진',
#   '함께',
#   '합의',
#   '합치다',
#   '해오다',
#   '행사',
#   '혁신',
#   '현재',
#   '협력',
#   '형성',
#   '호텔',
#   '홀딩스',
#   '확보',
#   '활동',
#   '회장',
#   '효율'],
#  ['가능성',
#   '가다',
#   '가족',
#   '가치',
#   '강화하다',
#   '개발',
#   '개선',
#   '건설',
#   '격리',
#   '결정',
#   '경영',
#   '경영인',
#   '경우',
#   '경쟁',
#   '계약',
#   '고가',
#   '고문',
#   '공감',
#   '공동',
#   '공시',
#   '관계',
#   '관계자',
#   '관심',
#   '구조',
#   '구축',
#   '국민연금',
#   '그것',
#   '그동안',
#   '그렇다',
#   '그레이스',
#   '그룹',
#   '그리고',
#   '기업',
#   '기자',
#   '기존',
#   '까지',
#   '나서다',
#   '남매',
#   '내다',
#   '내용',
#   '노력',
#   '누나',
#   '늘다',
#   '대결',
#   '대표',
#   '대한',
#   '대한항공',
#   '대해',
#   '더하다',
#   '덧붙이다',
#   '델타항공',
#   '도입',
#   '동맹',
#   '동생',
#   '돼다',
#   '되다',
#   '들다',
#   '따르다',
#   '때문',
#   '라며',
#   '모두',
#   '모친',
#   '목적',
#   '반대',
#   '반도',
#   '발전',
#   '발표',
#   '밝히다',
#   '방식',
#   '법무',
#   '법인',
#   '변수',
#   '보다',
#   '보유',
#   '보이다',
#   '부사',
#   '분석',
#   '분율',
#   '분쟁',
#   '비롯',
#   '비행',
#   '사내',
#   '사모펀드',
#   '사실',
#   '사업',
#   '사외이사',
#   '상황',
#   '서다',
#   '선임',
#   '설명',
#   '성부',
#   '성장',
#   '세력',
#   '승무원',
#   '심각하다',
#   '아이',
#   '않다',
#   '알려지다',
#   '앞두다',
#   '어머니',
#   '얻다',
#   '업계',
#   '없다',
#   '에게',
#   '에서',
#   '에서는',
#   '에선',
#   '여기',
#   '역시',
#   '연합',
#   '연합군',
#   '영진',
#   '예정',
#   '오다',
#   '오전',
#   '요구',
#   '우군',
#   '우한',
#   '우호',
#   '위기',
#   '위해',
#   '유지',
#   '의결권',
#   '의하다',
#   '이다',
#   '이라고',
#   '이렇다',
#   '이뤄지다',
#   '이며',
#   '이명희',
#   '이번',
#   '이사',
#   '이사회',
#   '이익',
#   '이후',
#   '일가',
#   '일선',
#   '입장',
#   '있다',
#   '자가',
#   '잡다',
#   '장이',
#   '재무',
#   '적극',
#   '전망',
#   '전무',
#   '전문',
#   '전선',
#   '전세기',
#   '정석',
#   '제도',
#   '제안',
#   '제외',
#   '조양호',
#   '조원태',
#   '조현민',
#   '조현아',
#   '주식',
#   '주요',
#   '주의',
#   '주주',
#   '주주총회',
#   '중심',
#   '지난해',
#   '지배구조',
#   '참석',
#   '체결',
#   '체제',
#   '총수',
#   '최대',
#   '추가',
#   '치열하다',
#   '카카오',
#   '케이',
#   '탑승',
#   '태평양',
#   '통해',
#   '투자',
#   '특수',
#   '펀드',
#   '평가',
#   '포인트',
#   '포함',
#   '필요하다',
#   '하고',
#   '하다',
#   '한진',
#   '함께',
#   '합의',
#   '합치다',
#   '해오다',
#   '행동',
#   '행사',
#   '혁신',
#   '현재',
#   '협력',
#   '호텔',
#   '홀딩스',
#   '확보',
#   '활동',
#   '회사',
#   '회장',
#   '효율'],
#  ['가능성',
#   '가다',
#   '가족',
#   '가치',
#   '강화하다',
#   '개발',
#   '개선',
#   '건설',
#   '격리',
#   '결정',
#   '경영',
#   '경영인',
#   '경우',
#   '경쟁',
#   '계약',
#   '고가',
#   '고문',
#   '공감',
#   '공동',
#   '공시',
#   '관계',
#   '관계자',
#   '관심',
#   '구조',
#   '구축',
#   '구현',
#   '국민연금',
#   '그것',
#   '그동안',
#   '그렇다',
#   '그레이스',
#   '그룹',
#   '그리고',
#   '기업',
#   '기자',
#   '기존',
#   '까지',
#   '나서다',
#   '남매',
#   '내다',
#   '내용',
#   '노력',
#   '누나',
#   '늘다',
#   '다가오다',
#   '대결',
#   '대표',
#   '대한',
#   '대한항공',
#   '대해',
#   '더하다',
#   '덧붙이다',
#   '델타항공',
#   '도입',
#   '동맹',
#   '동생',
#   '돼다',
#   '되다',
#   '들다',
#   '따르다',
#   '때문',
#   '라며',
#   '모두',
#   '모친',
#   '목적',
#   '반대',
#   '반도',
#   '발전',
#   '발표',
#   '밝히다',
#   '방식',
#   '법무',
#   '법인',
#   '변수',
#   '보다',
#   '보유',
#   '보이다',
#   '부사',
#   '분석',
#   '분율',
#   '분쟁',
#   '비롯',
#   '비행',
#   '사내',
#   '사모펀드',
#   '사실',
#   '사업',
#   '사외이사',
#   '상황',
#   '서다',
#   '선임',
#   '설명',
#   '성부',
#   '성장',
#   '세력',
#   '승무원',
#   '심각하다',
#   '아이',
#   '않다',
#   '알려지다',
#   '앞두다',
#   '어머니',
#   '얻다',
#   '업계',
#   '없다',
#   '에게',
#   '에는',
#   '에서',
#   '에서는',
#   '에선',
#   '여기',
#   '역시',
#   '연합',
#   '연합군',
#   '영진',
#   '예정',
#   '오다',
#   '오전',
#   '요구',
#   '우군',
#   '우한',
#   '우호',
#   '위기',
#   '위해',
#   '유지',
#   '의결권',
#   '의하다',
#   '이다',
#   '이라고',
#   '이렇다',
#   '이뤄지다',
#   '이며',
#   '이명희',
#   '이번',
#   '이사',
#   '이사회',
#   '이익',
#   '이후',
#   '일가',
#   '일선',
#   '입장',
#   '있다',
#   '자가',
#   '잡다',
#   '장이',
#   '재무',
#   '적극',
#   '전망',
#   '전무',
#   '전문',
#   '전선',
#   '전세기',
#   '정석',
#   '제도',
#   '제안',
#   '제외',
#   '조양호',
#   '조원태',
#   '조현민',
#   '조현아',
#   '주식',
#   '주요',
#   '주의',
#   '주주',
#   '주주총회',
#   '중심',
#   '증진',
#   '지난해',
#   '지배구조',
#   '참석',
#   '체결',
#   '체제',
#   '총수',
#   '최대',
#   '추가',
#   '치열하다',
#   '카카오',
#   '케이',
#   '탑승',
#   '태평양',
#   '통해',
#   '투자',
#   '특수',
#   '펀드',
#   '평가',
#   '포인트',
#   '포함',
#   '필요하다',
#   '하고',
#   '하다',
#   '한진',
#   '함께',
#   '합의',
#   '합치다',
#   '해오다',
#   '행동',
#   '행사',
#   '혁신',
#   '현재',
#   '협력',
#   '호텔',
#   '홀딩스',
#   '확보',
#   '활동',
#   '회사',
#   '회장',
#   '효율'],
#  ['가능성',
#   '가다',
#   '가족',
#   '가치',
#   '강조',
#   '강화하다',
#   '개발',
#   '개선',
#   '개인',
#   '건설',
#   '격리',
#   '결정',
#   '경영',
#   '경영인',
#   '경우',
#   '경쟁',
#   '계약',
#   '고가',
#   '고문',
#   '고민',
#   '공감',
#   '공동',
#   '공시',
#   '관계',
#   '관계자',
#   '관심',
#   '구조',
#   '구축',
#   '구현',
#   '국민연금',
#   '그것',
#   '그동안',
#   '그렇다',
#   '그레이스',
#   '그룹',
#   '그리고',
#   '기업',
#   '기자',
#   '기존',
#   '까지',
#   '꾸준하다',
#   '나서다',
#   '남매',
#   '내다',
#   '내용',
#   '노력',
#   '누나',
#   '늘다',
#   '다가오다',
#   '대결',
#   '대표',
#   '대한',
#   '대한항공',
#   '대해',
#   '더하다',
#   '덧붙이다',
#   '델타항공',
#   '도입',
#   '동맹',
#   '동생',
#   '돼다',
#   '되다',
#   '들다',
#   '따르다',
#   '때문',
#   '라며',
#   '많다',
#   '명의',
#   '모두',
#   '모범',
#   '모친',
#   '목적',
#   '반대',
#   '반도',
#   '발전',
#   '발표',
#   '밝히다',
#   '방식',
#   '방향',
#   '법무',
#   '법인',
#   '변수',
#   '보다',
#   '보유',
#   '보이다',
#   '부사',
#   '분석',
#   '분율',
#   '분쟁',
#   '불과하다',
#   '비롯',
#   '비행',
#   '사내',
#   '사모펀드',
#   '사실',
#   '사업',
#   '사외이사',
#   '상황',
#   '서다',
#   '선임',
#   '설명',
#   '성부',
#   '성장',
#   '세력',
#   '승무원',
#   '심각하다',
#   '아이',
#   '않다',
#   '알려지다',
#   '앞두다',
#   '어머니',
#   '얻다',
#   '업계',
#   '없다',
#   '에게',
#   '에는',
#   '에서',
#   '에서는',
#   '에선',
#   '여기',
#   '역시',
#   '연합',
#   '연합군',
#   '영진',
#   '예정',
#   '오다',
#   '오전',
#   '요구',
#   '우군',
#   '우한',
#   '우호',
#   '위기',
#   '위해',
#   '유지',
#   '의결권',
#   '의하다',
#   '이다',
#   '이라고',
#   '이렇다',
#   '이뤄지다',
#   '이며',
#   '이명희',
#   '이번',
#   '이사',
#   '이사회',
#   '이익',
#   '이후',
#   '일가',
#   '일선',
#   '입장',
#   '있다',
#   '자가',
#   '잡다',
#   '장이',
#   '재무',
#   '적극',
#   '전격',
#   '전망',
#   '전무',
#   '전문',
#   '전선',
#   '전세기',
#   '전적',
#   '정립',
#   '정석',
#   '제기',
#   '제도',
#   '제안',
#   '제외',
#   '조양호',
#   '조원태',
#   '조현민',
#   '조현아',
#   '주식',
#   '주요',
#   '주의',
#   '주주',
#   '주주총회',
#   '중심',
#   '증진',
#   '지난해',
#   '지배구조',
#   '참석',
#   '체결',
#   '체제',
#   '총수',
#   '최대',
#   '추가',
#   '치열하다',
#   '카카오',
#   '케이',
#   '탑승',
#   '태평양',
#   '통한',
#   '통해',
#   '투자',
#   '특수',
#   '펀드',
#   '평가',
#   '포인트',
#   '포함',
#   '필요하다',
#   '하고',
#   '하다',
#   '한진',
#   '함께',
#   '합의',
#   '합치다',
#   '해오다',
#   '행동',
#   '행사',
#   '혁신',
#   '현재',
#   '협력',
#   '호텔',
#   '홀딩스',
#   '확보',
#   '활동',
#   '회사',
#   '회장',
#   '효율'],
#  ['가능성',
#   '가다',
#   '가족',
#   '가치',
#   '강조',
#   '강화하다',
#   '개발',
#   '개선',
#   '개인',
#   '건설',
#   '격리',
#   '결정',
#   '경영',
#   '경영인',
#   '경우',
#   '경쟁',
#   '계약',
#   '고가',
#   '고문',
#   '고민',
#   '공감',
#   '공동',
#   '공시',
#   '관계',
#   '관계자',
#   '관심',
#   '구조',
#   '구축',
#   '구현',
#   '국민연금',
#   '그것',
#   '그동안',
#   '그렇다',
#   '그레이스',
#   '그룹',
#   '그리고',
#   '기업',
#   '기자',
#   '기존',
#   '까지',
#   '꾸준하다',
#   '나서다',
#   '남매',
#   '내다',
#   '내용',
#   '노력',
#   '누나',
#   '늘다',
#   '다가오다',
#   '대결',
#   '대표',
#   '대한',
#   '대한항공',
#   '대해',
#   '더하다',
#   '덧붙이다',
#   '델타항공',
#   '도입',
#   '동맹',
#   '동생',
#   '돼다',
#   '되다',
#   '들다',
#   '따르다',
#   '때문',
#   '라며',
#   '많다',
#   '명의',
#   '모두',
#   '모든',
#   '모범',
#   '모친',
#   '목적',
#   '반대',
#   '반도',
#   '발전',
#   '발표',
#   '밝히다',
#   '방식',
#   '방향',
#   '법무',
#   '법인',
#   '변수',
#   '보다',
#   '보유',
#   '보이다',
#   '부사',
#   '분석',
#   '분율',
#   '분쟁',
#   '불과하다',
#   '비롯',
#   '비행',
#   '사내',
#   '사모펀드',
#   '사실',
#   '사업',
#   '사외이사',
#   '상황',
#   '서다',
#   '선임',
#   '설명',
#   '성부',
#   '성장',
#   '세력',
#   '소외',
#   '승무원',
#   '심각하다',
#   '아이',
#   '않다',
#   '알려지다',
#   '앞두다',
#   '어머니',
#   '얻다',
#   '업계',
#   '없다',
#   '에게',
#   '에는',
#   '에서',
#   '에서는',
#   '에선',
#   '여기',
#   '역시',
#   '연합',
#   '연합군',
#   '영진',
#   '예상',
#   '예정',
#   '오다',
#   '오전',
#   '요구',
#   '우군',
#   '우한',
#   '우호',
#   '위기',
#   '위해',
#   '유지',
#   '의결권',
#   '의하다',
#   '이다',
#   '이라고',
#   '이렇다',
#   '이뤄지다',
#   '이며',
#   '이명희',
#   '이번',
#   '이사',
#   '이사회',
#   '이익',
#   '이후',
#   '일가',
#   '일선',
#   '입장',
#   '있다',
#   '자가',
#   '잡다',
#   '장이',
#   '재무',
#   '적극',
#   '전격',
#   '전망',
#   '전무',
#   '전문',
#   '전선',
#   '전세기',
#   '전적',
#   '정립',
#   '정석',
#   '제기',
#   '제도',
#   '제안',
#   '제외',
#   '조양호',
#   '조원태',
#   '조현민',
#   '조현아',
#   '주식',
#   '주요',
#   '주의',
#   '주주',
#   '주주총회',
#   '중심',
#   '증진',
#   '지난해',
#   '지배구조',
#   '참석',
#   '체결',
#   '체제',
#   '총수',
#   '최대',
#   '추가',
#   '치열하다',
#   '카카오',
#   '케이',
#   '탑승',
#   '태평양',
#   '통한',
#   '통해',
#   '투자',
#   '특수',
#   '펀드',
#   '평가',
#   '포인트',
#   '포함',
#   '필요하다',
#   '하고',
#   '하다',
#   '한진',
#   '한층',
#   '함께',
#   '합의',
#   '합치다',
#   '해오다',
#   '행동',
#   '행사',
#   '혁신',
#   '현재',
#   '협력',
#   '호텔',
#   '홀딩스',
#   '확보',
#   '활동',
#   '회사',
#   '회장',
#   '효율'],
#  ['가능성',
#   '가다',
#   '가족',
#   '가치',
#   '강조',
#   '강화하다',
#   '개발',
#   '개선',
#   '개인',
#   '건설',
#   '결정',
#   '경영',
#   '경영인',
#   '경우',
#   '계약',
#   '고가',
#   '고문',
#   '고민',
#   '공감',
#   '공동',
#   '공시',
#   '관계',
#   '관계자',
#   '관련',
#   '구조',
#   '구축',
#   '구현',
#   '국민연금',
#   '그것',
#   '그동안',
#   '그렇다',
#   '그레이스',
#   '그룹',
#   '기업',
#   '기자',
#   '기존',
#   '까지',
#   '꾸준하다',
#   '나서다',
#   '남매',
#   '내다',
#   '내용',
#   '노력',
#   '늘다',
#   '다가오다',
#   '대결',
#   '대표',
#   '대한',
#   '대한항공',
#   '대해',
#   '더하다',
#   '덧붙이다',
#   '델타항공',
#   '도입',
#   '동맹',
#   '동생',
#   '돼다',
#   '되다',
#   '들다',
#   '따르다',
#   '때문',
#   '많다',
#   '명의',
#   '모두',
#   '모범',
#   '모친',
#   '목적',
#   '반대',
#   '반도',
#   '발전',
#   '발표',
#   '밝히다',
#   '방식',
#   '방향',
#   '법무',
#   '법인',
#   '보다',
#   '보유',
#   '보이다',
#   '부사',
#   '분류',
#   '분율',
#   '분쟁',
#   '비롯',
#   '비행',
#   '사내',
#   '사모펀드',
#   '사실',
#   '사업',
#   '사외이사',
#   '상황',
#   '서다',
#   '선임',
#   '설명',
#   '성부',
#   '성장',
#   '세력',
#   '소외',
#   '승무원',
#   '심각하다',
#   '아이',
#   '않다',
#   '알려지다',
#   '앞두다',
#   '어머니',
#   '얻다',
#   '업계',
#   '없다',
#   '에게',
#   '에서',
#   '에서는',
#   '에선',
#   '여기',
#   '역시',
#   '연대',
#   '연합',
#   '연합군',
#   '영진',
#   '예정',
#   '오다',
#   '요구',
#   '우군',
#   '우한',
#   '우호',
#   '위기',
#   '위해',
#   '의결권',
#   '의하다',
#   '이다',
#   '이라고',
#   '이렇다',
#   '이뤄지다',
#   '이르다',
#   '이며',
#   '이명희',
#   '이번',
#   '이사',
#   '이사회',
#   '이익',
#   '일가',
#   '일선',
#   '일원',
#   '입장',
#   '있다',
#   '자가',
#   '잡다',
#   '장이',
#   '재무',
#   '적극',
#   '전격',
#   '전망',
#   '전무',
#   '전문',
#   '전선',
#   '전세기',
#   '전적',
#   '정립',
#   '정석',
#   '제기',
#   '제도',
#   '제안',
#   '제외',
#   '조원태',
#   '조현민',
#   '조현아',
#   '주식',
#   '주요',
#   '주의',
#   '주주',
#   '주주총회',
#   '중심',
#   '증진',
#   '지난해',
#   '지배구조',
#   '체결',
#   '체제',
#   '총수',
#   '최근',
#   '최대',
#   '추가',
#   '치열하다',
#   '카카오',
#   '케이',
#   '탑승',
#   '태평양',
#   '통해',
#   '투자',
#   '특수',
#   '펀드',
#   '포인트',
#   '포함',
#   '필요하다',
#   '하고',
#   '하다',
#   '한진',
#   '함께',
#   '합의',
#   '해오다',
#   '행동',
#   '행사',
#   '혁신',
#   '현재',
#   '협력',
#   '호텔',
#   '홀딩스',
#   '확보',
#   '활동',
#   '회사',
#   '회장',
#   '효율'],
#  ['가능성',
#   '가다',
#   '가족',
#   '가치',
#   '강조',
#   '강화하다',
#   '개발',
#   '개선',
#   '개인',
#   '건설',
#   '격리',
#   '결정',
#   '경영',
#   '경영인',
#   '경우',
#   '계약',
#   '고가',
#   '고문',
#   '고민',
#   '공감',
#   '공동',
#   '공시',
#   '관계',
#   '관계자',
#   '관련',
#   '관심',
#   '교민',
#   '구조',
#   '구축',
#   '구현',
#   '국민연금',
#   '그것',
#   '그동안',
#   '그렇다',
#   '그레이스',
#   '그룹',
#   '기업',
#   '기자',
#   '기존',
#   '까지',
#   '꾸준하다',
#   '나서다',
#   '남매',
#   '내다',
#   '내용',
#   '노력',
#   '누나',
#   '늘다',
#   '다가오다',
#   '대결',
#   '대표',
#   '대한',
#   '대한항공',
#   '대해',
#   '더하다',
#   '덧붙이다',
#   '델타항공',
#   '도입',
#   '동맹',
#   '동생',
#   '돼다',
#   '되다',
#   '들다',
#   '따르다',
#   '때문',
#   '많다',
#   '명의',
#   '모두',
#   '모범',
#   '모친',
#   '목적',
#   '반대',
#   '반도',
#   '발전',
#   '발표',
#   '밝히다',
#   '방식',
#   '방향',
#   '법무',
#   '법인',
#   '보다',
#   '보유',
#   '보이다',
#   '부사',
#   '분류',
#   '분석',
#   '분율',
#   '분쟁',
#   '비롯',
#   '비행',
#   '사내',
#   '사모펀드',
#   '사실',
#   '사업',
#   '사외이사',
#   '상황',
#   '서다',
#   '선임',
#   '설명',
#   '성부',
#   '성장',
#   '세력',
#   '소외',
#   '승무원',
#   '심각하다',
#   '아니다',
#   '아이',
#   '않다',
#   '알려지다',
#   '앞두다',
#   '어머니',
#   '얻다',
#   '업계',
#   '없다',
#   '에게',
#   '에서',
#   '에서는',
#   '에선',
#   '여기',
#   '역시',
#   '연대',
#   '연합',
#   '연합군',
#   '영진',
#   '예정',
#   '오다',
#   '요구',
#   '우군',
#   '우한',
#   '우호',
#   '위기',
#   '위해',
#   '의결권',
#   '의하다',
#   '이다',
#   '이라고',
#   '이라는',
#   '이렇다',
#   '이뤄지다',
#   '이르다',
#   '이며',
#   '이명희',
#   '이번',
#   '이사',
#   '이사회',
#   '이익',
#   '이후',
#   '일가',
#   '일선',
#   '일원',
#   '입장',
#   '있다',
#   '자가',
#   '잡다',
#   '장이',
#   '재무',
#   '적극',
#   '전격',
#   '전망',
#   '전무',
#   '전문',
#   '전선',
#   '전세기',
#   '전적',
#   '정립',
#   '정석',
#   '제기',
#   '제도',
#   '제안',
#   '제외',
#   '조원태',
#   '조현민',
#   '조현아',
#   '주식',
#   '주요',
#   '주의',
#   '주주',
#   '주주총회',
#   '중국',
#   '중심',
#   '증진',
#   '지난해',
#   '지배구조',
#   '지지',
#   '체결',
#   '체제',
#   '총수',
#   '최근',
#   '최대',
#   '추가',
#   '측은',
#   '치열하다',
#   '카카오',
#   '케이',
#   '탑승',
#   '태평양',
#   '통해',
#   '투자',
#   '특별',
#   '특수',
#   '펀드',
#   '포인트',
#   '포함',
#   '필요하다',
#   '하고',
#   '하다',
#   '한진',
#   '함께',
#   '합의',
#   '합치다',
#   '해오다',
#   '행동',
#   '행사',
#   '혁신',
#   '현재',
#   '협력',
#   '호텔',
#   '홀딩스',
#   '확보',
#   '활동',
#   '회사',
#   '회장',
#   '효율'],
#  ['가능성',
#   '가다',
#   '가족',
#   '가치',
#   '강화하다',
#   '개발',
#   '개선',
#   '개인',
#   '건설',
#   '결정',
#   '경영',
#   '경영인',
#   '경우',
#   '계약',
#   '고가',
#   '고문',
#   '고민',
#   '공감',
#   '공동',
#   '공시',
#   '관계',
#   '관계자',
#   '관련',
#   '구조',
#   '구축',
#   '구현',
#   '국민연금',
#   '그것',
#   '그동안',
#   '그렇다',
#   '그레이스',
#   '그룹',
#   '기업',
#   '기자',
#   '기존',
#   '까지',
#   '꾸준하다',
#   '나서다',
#   '남매',
#   '내다',
#   '내용',
#   '노력',
#   '늘다',
#   '다가오다',
#   '대결',
#   '대한',
#   '대한항공',
#   '대해',
#   '더하다',
#   '덧붙이다',
#   '델타항공',
#   '도입',
#   '동맹',
#   '동생',
#   '돼다',
#   '되다',
#   '들다',
#   '따르다',
#   '때문',
#   '많다',
#   '명의',
#   '모두',
#   '모범',
#   '모친',
#   '반대',
#   '반도',
#   '발전',
#   '발표',
#   '밝히다',
#   '방식',
#   '방향',
#   '법무',
#   '법인',
#   '보다',
#   '보유',
#   '보이다',
#   '부사',
#   '분율',
#   '분쟁',
#   '비롯',
#   '비행',
#   '사내',
#   '사모펀드',
#   '사실',
#   '사업',
#   '사외이사',
#   '상황',
#   '서다',
#   '선임',
#   '설명',
#   '성부',
#   '성장',
#   '세력',
#   '소외',
#   '승무원',
#   '심각하다',
#   '안건',
#   '않다',
#   '알려지다',
#   '앞두다',
#   '어머니',
#   '얻다',
#   '업계',
#   '없다',
#   '에게',
#   '에서',
#   '에서는',
#   '에선',
#   '여기',
#   '역시',
#   '연합',
#   '연합군',
#   '영진',
#   '예정',
#   '오다',
#   '요구',
#   '우군',
#   '우한',
#   '우호',
#   '위기',
#   '위해',
#   '의결권',
#   '의하다',
#   '이다',
#   '이라고',
#   '이렇다',
#   '이뤄지다',
#   '이르다',
#   '이며',
#   '이명희',
#   '이번',
#   '이사',
#   '이사회',
#   '이익',
#   '일가',
#   '일선',
#   '일원',
#   '입장',
#   '있다',
#   '자가',
#   '잡다',
#   '장이',
#   '재무',
#   '저희',
#   '적극',
#   '전격',
#   '전망',
#   '전무',
#   '전문',
#   '전선',
#   '전세기',
#   '전적',
#   '정립',
#   '정석',
#   '제기',
#   '제도',
#   '제안',
#   '조원태',
#   '조현민',
#   '조현아',
#   '주식',
#   '주요',
#   '주의',
#   '주주',
#   '주주총회',
#   '중심',
#   '증진',
#   '지난해',
#   '지배구조',
#   '지지',
#   '직접',
#   '체결',
#   '체제',
#   '총수',
#   '최근',
#   '최대',
#   '측은',
#   '카카오',
#   '탑승',
#   '태평양',
#   '통한',
#   '통해',
#   '투자',
#   '특별',
#   '특수',
#   '펀드',
#   '포함',
#   '필요하다',
#   '하고',
#   '하다',
#   '한진',
#   '함께',
#   '합의',
#   '합치다',
#   '행동',
#   '행사',
#   '혁신',
#   '현재',
#   '협력',
#   '호텔',
#   '홀딩스',
#   '확보',
#   '활동',
#   '회사',
#   '회장',
#   '효율'],
#  ['가능성',
#   '가다',
#   '가족',
#   '가치',
#   '강화하다',
#   '개발',
#   '개선',
#   '개인',
#   '건설',
#   '결정',
#   '경영',
#   '경영인',
#   '경우',
#   '계약',
#   '고가',
#   '고문',
#   '고민',
#   '공감',
#   '공동',
#   '공시',
#   '관계',
#   '관계자',
#   '관련',
#   '구조',
#   '구축',
#   '구현',
#   '국민연금',
#   '그것',
#   '그동안',
#   '그렇다',
#   '그레이스',
#   '그룹',
#   '기업',
#   '기자',
#   '기존',
#   '까지',
#   '꾸준하다',
#   '나서다',
#   '남매',
#   '내다',
#   '내용',
#   '노력',
#   '늘다',
#   '다가오다',
#   '대결',
#   '대한',
#   '대한항공',
#   '대해',
#   '더하다',
#   '덧붙이다',
#   '델타항공',
#   '도입',
#   '동맹',
#   '동생',
#   '돼다',
#   '되다',
#   '들다',
#   '따르다',
#   '때문',
#   '많다',
#   '명의',
#   '모두',
#   '모범',
#   '모친',
#   '반대',
#   '반도',
#   '발전',
#   '발표',
#   '밝히다',
#   '방식',
#   '방향',
#   '법무',
#   '법인',
#   '보다',
#   '보유',
#   '보이다',
#   '부사',
#   '분율',
#   '분쟁',
#   '비롯',
#   '비행',
#   '사내',
#   '사모펀드',
#   '사실',
#   '사업',
#   '사외이사',
#   '상황',
#   '서다',
#   '선임',
#   '설명',
#   '성부',
#   '성장',
#   '세력',
#   '소외',
#   '승무원',
#   '심각하다',
#   '안건',
#   '않다',
#   '알려지다',
#   '앞두다',
#   '어머니',
#   '얻다',
#   '업계',
#   '없다',
#   '에게',
#   '에서',
#   '에서는',
#   '에선',
#   '여기',
#   '역시',
#   '연대',
#   '연합',
#   '연합군',
#   '영진',
#   '예정',
#   '오다',
#   '요구',
#   '우군',
#   '우한',
#   '우호',
#   '위기',
#   '위해',
#   '의결권',
#   '의하다',
#   '이다',
#   '이라고',
#   '이렇다',
#   '이뤄지다',
#   '이르다',
#   '이며',
#   '이명희',
#   '이번',
#   '이사',
#   '이사회',
#   '이익',
#   '일가',
#   '일선',
#   '일원',
#   '입장',
#   '있다',
#   '자가',
#   '잡다',
#   '장이',
#   '재무',
#   '저희',
#   '적극',
#   '전격',
#   '전망',
#   '전무',
#   '전문',
#   '전선',
#   '전세기',
#   '전적',
#   '정립',
#   '정석',
#   '제기',
#   '제도',
#   '제안',
#   '조원태',
#   '조현민',
#   '조현아',
#   '좌우',
#   '주식',
#   '주요',
#   '주의',
#   '주주',
#   '주주총회',
#   '중심',
#   '증진',
#   '지난해',
#   '지배구조',
#   '지지',
#   '직접',
#   '체결',
#   '체제',
#   '총수',
#   '최근',
#   '최대',
#   '최선',
#   '측은',
#   '카카오',
#   '탑승',
#   '태평양',
#   '통한',
#   '통해',
#   '투자',
#   '특별',
#   '특수',
#   '펀드',
#   '포함',
#   '필요하다',
#   '하고',
#   '하다',
#   '한진',
#   '함께',
#   '합의',
#   '합치다',
#   '행동',
#   '행사',
#   '혁신',
#   '현재',
#   '협력',
#   '호텔',
#   '홀딩스',
#   '확보',
#   '활동',
#   '회사',
#   '회장',
#   '효율'],
#  ['가능성',
#   '가다',
#   '가족',
#   '가치',
#   '강화하다',
#   '갖다',
#   '개발',
#   '개선',
#   '개인',
#   '건설',
#   '결정',
#   '경영',
#   '경영인',
#   '경우',
#   '계약',
#   '고가',
#   '고문',
#   '고민',
#   '공감',
#   '공동',
#   '공시',
#   '관계',
#   '관계자',
#   '관련',
#   '구조',
#   '구축',
#   '구현',
#   '국민연금',
#   '그것',
#   '그동안',
#   '그렇다',
#   '그레이스',
#   '그룹',
#   '기업',
#   '기자',
#   '기존',
#   '까지',
#   '꾸준하다',
#   '나서다',
#   '남매',
#   '내다',
#   '내용',
#   '노력',
#   '늘다',
#   '다가오다',
#   '대결',
#   '대한',
#   '대한항공',
#   '대해',
#   '더하다',
#   '덧붙이다',
#   '델타항공',
#   '도입',
#   '동맹',
#   '동생',
#   '돼다',
#   '되다',
#   '들다',
#   '따르다',
#   '때문',
#   '많다',
#   '명의',
#   '모두',
#   '모범',
#   '모친',
#   '반대',
#   '반도',
#   '발전',
#   '발표',
#   '밝히다',
#   '방식',
#   '방향',
#   '법무',
#   '법인',
#   '보다',
#   '보유',
#   '보이다',
#   '부사',
#   '분율',
#   '분쟁',
#   '비롯',
#   '비행',
#   '사내',
#   '사모펀드',
#   '사실',
#   '사업',
#   '사외이사',
#   '상황',
#   '새롭다',
#   '서다',
#   '선임',
#   '설명',
#   '성부',
#   '성장',
#   '세력',
#   '소외',
#   '승무원',
#   '심각하다',
#   '안건',
#   '않다',
#   '알려지다',
#   '앞두다',
#   '어느',
#   '어머니',
#   '얻다',
#   '업계',
#   '없다',
#   '에게',
#   '에서',
#   '에서는',
#   '에선',
#   '여기',
#   '역시',
#   '연대',
#   '연합',
#   '연합군',
#   '영진',
#   '예정',
#   '오다',
#   '요구',
#   '우군',
#   '우한',
#   '우호',
#   '위기',
#   '위해',
#   '의결권',
#   '의하다',
#   '이다',
#   '이라고',
#   '이렇다',
#   '이뤄지다',
#   '이르다',
#   '이며',
#   '이명희',
#   '이번',
#   '이사',
#   '이사회',
#   '이익',
#   '이후',
#   '일가',
#   '일선',
#   '일원',
#   '입장',
#   '있다',
#   '자가',
#   '잡다',
#   '장이',
#   '재무',
#   '저희',
#   '적극',
#   '전격',
#   '전망',
#   '전무',
#   '전문',
#   '전선',
#   '전세기',
#   '전적',
#   '정립',
#   '정석',
#   '제기',
#   '제도',
#   '제안',
#   '제외',
#   '조양호',
#   '조원태',
#   '조현민',
#   '조현아',
#   '좌우',
#   '주식',
#   '주요',
#   '주의',
#   '주주',
#   '주주총회',
#   '중심',
#   '증진',
#   '지난해',
#   '지배구조',
#   '지지',
#   '직접',
#   '참석',
#   '체결',
#   '체제',
#   '총수',
#   '최근',
#   '최대',
#   '최선',
#   '추가',
#   '측은',
#   '카카오',
#   '탑승',
#   '태평양',
#   '통한',
#   '통해',
#   '투자',
#   '특별',
#   '특수',
#   '펀드',
#   '평가',
#   '포인트',
#   '포함',
#   '필요하다',
#   '하고',
#   '하다',
#   '한진',
#   '함께',
#   '합의',
#   '합치다',
#   '행동',
#   '행사',
#   '혁신',
#   '현재',
#   '협력',
#   '호텔',
#   '홀딩스',
#   '확보',
#   '활동',
#   '회사',
#   '회장',
#   '효율'],
#  ['가능성',
#   '가다',
#   '가족',
#   '가치',
#   '강화하다',
#   '갖다',
#   '개발',
#   '개선',
#   '개인',
#   '건설',
#   '결정',
#   '경영',
#   '경영인',
#   '경우',
#   '계약',
#   '고가',
#   '고문',
#   '고민',
#   '공감',
#   '공동',
#   '공시',
#   '관계',
#   '관계자',
#   '관련',
#   '구조',
#   '구축',
#   '구현',
#   '국민연금',
#   '그것',
#   '그동안',
#   '그렇다',
#   '그레이스',
#   '그룹',
#   '기업',
#   '기자',
#   '기존',
#   '까지',
#   '꾸준하다',
#   '나서다',
#   '남매',
#   '내다',
#   '내용',
#   '노력',
#   '늘다',
#   '다가오다',
#   '대결',
#   '대한',
#   '대한항공',
#   '대해',
#   '더하다',
#   '덧붙이다',
#   '델타항공',
#   '도입',
#   '동맹',
#   '동생',
#   '돼다',
#   '되다',
#   '들다',
#   '따르다',
#   '때문',
#   '많다',
#   '명의',
#   '모두',
#   '모든',
#   '모범',
#   '모친',
#   '반대',
#   '반도',
#   '발전',
#   '발표',
#   '밝히다',
#   '방식',
#   '방향',
#   '법무',
#   '법인',
#   '보다',
#   '보유',
#   '보이다',
#   '부사',
#   '분율',
#   '분쟁',
#   '불과하다',
#   '비롯',
#   '비행',
#   '사내',
#   '사모펀드',
#   '사실',
#   '사업',
#   '사외이사',
#   '상황',
#   '새롭다',
#   '서다',
#   '선임',
#   '설명',
#   '성부',
#   '성장',
#   '세력',
#   '소외',
#   '승무원',
#   '심각하다',
#   '안건',
#   '않다',
#   '알려지다',
#   '앞두다',
#   '어느',
#   '어머니',
#   '얻다',
#   '업계',
#   '없다',
#   '에게',
#   '에서',
#   '에서는',
#   '에선',
#   '여기',
#   '역시',
#   '연대',
#   '연합',
#   '연합군',
#   '영진',
#   '예상',
#   '예정',
#   '오다',
#   '요구',
#   '우군',
#   '우한',
#   '우호',
#   '위기',
#   '위해',
#   '의결권',
#   '의하다',
#   '이다',
#   '이라고',
#   '이렇다',
#   '이뤄지다',
#   '이르다',
#   '이며',
#   '이명희',
#   '이번',
#   '이사',
#   '이사회',
#   '이익',
#   '이후',
#   '일가',
#   '일선',
#   '일원',
#   '입장',
#   '있다',
#   '자가',
#   '잡다',
#   '장이',
#   '재무',
#   '저희',
#   '적극',
#   '전격',
#   '전망',
#   '전무',
#   '전문',
#   '전선',
#   '전세기',
#   '전적',
#   '정립',
#   '정석',
#   '제기',
#   '제도',
#   '제안',
#   '제외',
#   '조양호',
#   '조원태',
#   '조현민',
#   '조현아',
#   '좌우',
#   '주식',
#   '주요',
#   '주의',
#   '주주',
#   '주주총회',
#   '중심',
#   '증진',
#   '지난해',
#   '지배구조',
#   '지지',
#   '직접',
#   '참석',
#   '체결',
#   '체제',
#   '총수',
#   '최근',
#   '최대',
#   '최선',
#   '추가',
#   '취지',
#   '측은',
#   '카카오',
#   '탑승',
#   '태평양',
#   '통한',
#   '통해',
#   '투자',
#   '특별',
#   '특수',
#   '특정',
#   '펀드',
#   '평가',
#   '포인트',
#   '포함',
#   '필요하다',
#   '하고',
#   '하다',
#   '한진',
#   '함께',
#   '합의',
#   '합치다',
#   '행동',
#   '행사',
#   '혁신',
#   '현재',
#   '협력',
#   '호텔',
#   '홀딩스',
#   '확보',
#   '활동',
#   '회사',
#   '회장',
#   '효율'],
#  ['가능성',
#   '가다',
#   '가족',
#   '가치',
#   '강화하다',
#   '개발',
#   '개선',
#   '개인',
#   '건설',
#   '결정',
#   '경영',
#   '경영인',
#   '경우',
#   '계약',
#   '고가',
#   '고문',
#   '고민',
#   '공감',
#   '공동',
#   '공시',
#   '관계',
#   '관계자',
#   '구조',
#   '구축',
#   '구현',
#   '국민연금',
#   '그것',
#   '그동안',
#   '그레이스',
#   '그룹',
#   '기업',
#   '기자',
#   '기존',
#   '까지',
#   '꾸준하다',
#   '나서다',
#   '남매',
#   '내다',
#   '내용',
#   '노력',
#   '늘다',
#   '다가오다',
#   '대결',
#   '대한',
#   '대한항공',
#   '대해',
#   '더하다',
#   '덧붙이다',
#   '델타항공',
#   '도입',
#   '동맹',
#   '동생',
#   '돼다',
#   '되다',
#   '들다',
#   '따르다',
#   '때문',
#   '많다',
#   '명의',
#   '모두',
#   '모범',
#   '모친',
#   '반대',
#   '반도',
#   '발전',
#   '발표',
#   '밝히다',
#   '방식',
#   '방향',
#   '법무',
#   '법인',
#   '보다',
#   '보유',
#   '보이다',
#   '부사',
#   '분율',
#   '분쟁',
#   '비롯',
#   '사내',
#   '사모펀드',
#   '사업',
#   '사외이사',
#   '상황',
#   '새롭다',
#   '서다',
#   '선임',
#   '설명',
#   '성부',
#   '성장',
#   '세력',
#   '소외',
#   '승무원',
#   '심각하다',
#   '안건',
#   '않다',
#   '알려지다',
#   '앞두다',
#   '어느',
#   '어머니',
#   '얻다',
#   '없다',
#   '에게',
#   '에서',
#   '에서는',
#   '에선',
#   '여기',
#   '역시',
#   '연합',
#   '연합군',
#   '영진',
#   '예상',
#   '예정',
#   '오다',
#   '우군',
#   '우한',
#   '우호',
#   '위기',
#   '위해',
#   '의결권',
#   '의하다',
#   '이다',
#   '이라고',
#   '이뤄지다',
#   '이르다',
#   '이며',
#   '이명희',
#   '이번',
#   '이사',
#   '이사회',
#   '이익',
#   '일가',
#   '일선',
#   '일원',
#   '입장',
#   '있다',
#   '자가',
#   '잡다',
#   '장이',
#   '재무',
#   '저희',
#   '적극',
#   '전격',
#   '전망',
#   '전무',
#   '전문',
#   '전선',
#   '전세기',
#   '전적',
#   '정립',
#   '정석',
#   '제기',
#   '제도',
#   '제안',
#   '조양호',
#   '조원태',
#   '조현민',
#   '조현아',
#   '좌우',
#   '주식',
#   '주요',
#   '주의',
#   '주주',
#   '주주총회',
#   '중심',
#   '증진',
#   '지난해',
#   '지배구조',
#   '직접',
#   '체결',
#   '체제',
#   '총수',
#   '최대',
#   '추가',
#   '측은',
#   '카카오',
#   '탑승',
#   '태평양',
#   '통한',
#   '통해',
#   '투자',
#   '특별',
#   '특수',
#   '펀드',
#   '포인트',
#   '포함',
#   '필요하다',
#   '하고',
#   '하다',
#   '한진',
#   '함께',
#   '합의',
#   '행동',
#   '행사',
#   '혁신',
#   '현재',
#   '협력',
#   '호텔',
#   '홀딩스',
#   '확보',
#   '활동',
#   '회사',
#   '회장',
#   '효율'],
#  ['가능성',
#   '가다',
#   '가족',
#   '가치',
#   '강화하다',
#   '개발',
#   '개선',
#   '개인',
#   '건설',
#   '결정',
#   '경영',
#   '경영인',
#   '경우',
#   '계약',
#   '고가',
#   '고문',
#   '고민',
#   '공감',
#   '공동',
#   '공시',
#   '관계',
#   '관계자',
#   '구조',
#   '구축',
#   '구현',
#   '국민연금',
#   '그것',
#   '그동안',
#   '그레이스',
#   '그룹',
#   '기업',
#   '기자',
#   '기존',
#   '까지',
#   '꾸준하다',
#   '나서다',
#   '남매',
#   '내다',
#   '내용',
#   '노력',
#   '늘다',
#   '다가오다',
#   '대결',
#   '대한',
#   '대한항공',
#   '대해',
#   '더하다',
#   '덧붙이다',
#   '델타항공',
#   '도입',
#   '동맹',
#   '동생',
#   '돼다',
#   '되다',
#   '들다',
#   '따르다',
#   '때문',
#   '많다',
#   '명의',
#   '모두',
#   '모든',
#   '모범',
#   '모친',
#   '반대',
#   '반도',
#   '발전',
#   '발표',
#   '밝히다',
#   '방식',
#   '방향',
#   '법무',
#   '법인',
#   '보다',
#   '보유',
#   '보이다',
#   '부사',
#   '분율',
#   '분쟁',
#   '비롯',
#   '사내',
#   '사모펀드',
#   '사업',
#   '사외이사',
#   '상황',
#   '새롭다',
#   '서다',
#   '선임',
#   '설명',
#   '성부',
#   '성장',
#   '세력',
#   '소외',
#   '승무원',
#   '심각하다',
#   '안건',
#   '않다',
#   '알려지다',
#   '앞두다',
#   '어느',
#   '어머니',
#   '얻다',
#   '업계',
#   '없다',
#   '에게',
#   '에서',
#   '에서는',
#   '에선',
#   '여기',
#   '역시',
#   '연합',
#   '연합군',
#   '영진',
#   '예상',
#   '예정',
#   '오다',
#   '우한',
#   '우호',
#   '위기',
#   '위해',
#   '의결권',
#   '의하다',
#   '이다',
#   '이라고',
#   '이뤄지다',
#   '이르다',
#   '이며',
#   '이명희',
#   '이번',
#   '이사',
#   '이사회',
#   '이익',
#   '일가',
#   '일선',
#   '일원',
#   '입장',
#   '있다',
#   '자가',
#   '잡다',
#   '장이',
#   '재무',
#   '저희',
#   '적극',
#   '전격',
#   '전망',
#   '전무',
#   '전문',
#   '전선',
#   '전세기',
#   '전적',
#   '정립',
#   '정석',
#   '제기',
#   '제도',
#   '제안',
#   '조양호',
#   '조원태',
#   '조현민',
#   '조현아',
#   '좌우',
#   '주식',
#   '주요',
#   '주의',
#   '주주',
#   '주주총회',
#   '중심',
#   '증진',
#   '지난해',
#   '지배구조',
#   '직접',
#   '체결',
#   '체제',
#   '총수',
#   '최대',
#   '추가',
#   '측은',
#   '카카오',
#   '탑승',
#   '태평양',
#   '통한',
#   '통해',
#   '투자',
#   '특별',
#   '특수',
#   '특정',
#   '펀드',
#   '포인트',
#   '포함',
#   '필요하다',
#   '하고',
#   '하다',
#   '한진',
#   '함께',
#   '합의',
#   '행동',
#   '행사',
#   '혁신',
#   '현재',
#   '협력',
#   '호텔',
#   '홀딩스',
#   '확보',
#   '활동',
#   '회사',
#   '회장',
#   '효율'],
#  ['가능성',
#   '가다',
#   '가족',
#   '가치',
#   '강화하다',
#   '개발',
#   '개선',
#   '개인',
#   '건설',
#   '결정',
#   '경영',
#   '경영인',
#   '경우',
#   '계약',
#   '고가',
#   '고문',
#   '고민',
#   '공감',
#   '공동',
#   '공시',
#   '관계',
#   '관계자',
#   '관련',
#   '구조',
#   '구축',
#   '구현',
#   '국민연금',
#   '그것',
#   '그동안',
#   '그레이스',
#   '그룹',
#   '기업',
#   '기자',
#   '기존',
#   '까지',
#   '꾸준하다',
#   '나서다',
#   '남매',
#   '내다',
#   '내용',
#   '노력',
#   '늘다',
#   '다가오다',
#   '대결',
#   '대한',
#   '대한항공',
#   '대해',
#   '더하다',
#   '덧붙이다',
#   '델타항공',
#   '도입',
#   '동맹',
#   '동생',
#   '돼다',
#   '되다',
#   '들다',
#   '따르다',
#   '때문',
#   '많다',
#   '명의',
#   '모두',
#   '모든',
#   '모범',
#   '모친',
#   '반대',
#   '반도',
#   '발전',
#   '발표',
#   '밝히다',
#   '방식',
#   '방향',
#   '법무',
#   '법인',
#   '보다',
#   '보유',
#   '보이다',
#   '부사',
#   '분율',
#   '분쟁',
#   '비롯',
#   '사내',
#   '사모펀드',
#   '사실',
#   '사업',
#   '사외이사',
#   '상황',
#   '새롭다',
#   '서다',
#   '선임',
#   '설명',
#   '성부',
#   '성장',
#   '세력',
#   '소외',
#   '승무원',
#   '심각하다',
#   '안건',
#   '않다',
#   '알려지다',
#   '앞두다',
#   '어느',
#   '어머니',
#   '얻다',
#   '업계',
#   '없다',
#   '에게',
#   '에서',
# ...
#   '다음',
#   '달러',
#   '당시',
#   '대다',
#   '대비',
#   '대상',
#   '대표',
#   '대한',
#   '대한항공',
#   '대해',
#   '델타항공',
#   '도입',
#   '돼다',
#   '되다',
#   '들다',
#   '따르다',
#   '때문',
#   '라며',
#   '롯데',
#   '마스크',
#   '마일',
#   '마일리지',
#   '만원',
#   '만큼',
#   '많다',
#   '맞다',
#   '매입',
#   '매출',
#   '모두',
#   '모듈러',
#   '목적',
#   '미국',
#   '반도',
#   '반도체',
#   '받다',
#   '발생',
#   '발표',
#   '밝히다',
#   '법인',
#   '변경',
#   '보다',
#   '보유',
#   '보이다',
#   '부문',
#   '부사',
#   '부터',
#   '분기',
#   '분석',
#   '분율',
#   '분쟁',
#   '비롯',
#   '사내',
#   '사모펀드',
#   '사실',
#   '사업',
#   '사용',
#   '사장',
#   '사진',
#   '사태',
#   '산업',
#   '삼성',
#   '상승',
#   '상황',
#   '새롭다',
#   '서다',
#   '서비스',
#   '서울',
#   '선임',
#   '설명',
#   '성장',
#   '소비자',
#   '소재',
#   '수수료',
#   '수요',
#   '수준',
#   '수출',
#   '시장',
#   '신종',
#   '실적',
#   '아니다',
#   '아시아나',
#   '않다',
#   '알려지다',
#   '앞두다',
#   '앞서',
#   '어떻다',
#   '억원',
#   '업계',
#   '업종',
#   '업체',
#   '없다',
#   '에게',
#   '에는',
#   '에도',
#   '에서',
#   '에서는',
#   '여객',
#   '여행',
#   '여행사',
#   '역시',
#   '역할',
#   '연구원',
#   '영업',
#   '영향',
#   '예상',
#   '예정',
#   '오다',
#   '오르다',
#   '올해',
#   '우려',
#   '우한',
#   '운항',
#   '위해',
#   '유가',
#   '유류',
#   '의결권',
#   '이다',
#   '이라고',
#   '이라는',
#   '이란',
#   '이르다',
#   '이명희',
#   '이번',
#   '이사',
#   '이상',
#   '이스타항공',
#   '이용',
#   '이익',
#   '이후',
#   '인수',
#   '인천',
#   '일가',
#   '일본',
#   '입장',
#   '있다',
#   '장이',
#   '재계',
#   '재무',
#   '적극',
#   '적립',
#   '전망',
#   '전무',
#   '전문',
#   '전자',
#   '정부',
#   '정석',
#   '제공',
#   '제도',
#   '제외',
#   '제주항공',
#   '조양호',
#   '조원태',
#   '조현민',
#   '조현아',
#   '종목',
#   '주가',
#   '주식',
#   '주요',
#   '주의',
#   '주주',
#   '주주총회',
#   '중국',
#   '중단',
#   '중이',
#   '증가',
#   '증권',
#   '지난',
#   '지난달',
#   '지난해',
#   '지배구조',
#   '지속',
#   '지역',
#   '직원',
#   '진에어',
#   '진행',
#   '참여',
#   '체결',
#   '총수',
#   '최근',
#   '최대',
#   '추가',
#   '카드',
#   '카카오',
#   '커지다',
#   '크다',
#   '통해',
#   '투자',
#   '특히',
#   '판교',
#   '판매',
#   '패키징',
#   '펀드',
#   '평가',
#   '폐렴',
#   '포인트',
#   '포함',
#   '필요하다',
#   '하고',
#   '하다',
#   '하락',
#   '하지만',
#   '한국',
#   '한다는',
#   '한진',
#   '할인',
#   '할증',
#   '함께',
#   '항공',
#   '항공권',
#   '항공사',
#   '해당',
#   '해외',
#   '해협',
#   '행사',
#   '현재',
#   '협력',
#   '혜택',
#   '호르무즈',
#   '호텔',
#   '확대',
#   '확보',
#   '확산',
#   '환불',
#   '회사',
#   '회장'],
#  ['가능성',
#   '가다',
#   '가운데',
#   '가장',
#   '가족',
#   '가치',
#   '각각',
#   '갈등',
#   '감소',
#   '같다',
#   '개발',
#   '개선',
#   '개편안',
#   '거래',
#   '건설',
#   '검토',
#   '결정',
#   '결제',
#   '경영',
#   '경영인',
#   '경우',
#   '경제',
#   '계약',
#   '계열',
#   '계획',
#   '고객',
#   '고문',
#   '공동',
#   '공시',
#   '공정위',
#   '관계',
#   '관계자',
#   '관련',
#   '구조',
#   '국내',
#   '국민연금',
#   '규모',
#   '그렇다',
#   '그룹',
#   '금융',
#   '기간',
#   '기사',
#   '기업',
#   '기자',
#   '기존',
#   '기준',
#   '까지',
#   '나서다',
#   '나오다',
#   '남매',
#   '내다',
#   '내용',
#   '노선',
#   '높다',
#   '늘다',
#   '늘리다',
#   '다른',
#   '다음',
#   '달러',
#   '당시',
#   '대다',
#   '대비',
#   '대상',
#   '대표',
#   '대한',
#   '대한항공',
#   '대해',
#   '델타항공',
#   '도입',
#   '돼다',
#   '되다',
#   '들다',
#   '따르다',
#   '때문',
#   '라며',
#   '롯데',
#   '마스크',
#   '마일',
#   '마일리지',
#   '만원',
#   '만큼',
#   '많다',
#   '맞다',
#   '매입',
#   '매출',
#   '모두',
#   '모듈러',
#   '목적',
#   '미국',
#   '반도',
#   '반도체',
#   '받다',
#   '발생',
#   '발표',
#   '밝히다',
#   '법인',
#   '변경',
#   '보다',
#   '보유',
#   '보이다',
#   '부문',
#   '부사',
#   '부터',
#   '분기',
#   '분석',
#   '분율',
#   '분쟁',
#   '비롯',
#   '사내',
#   '사모펀드',
#   '사실',
#   '사업',
#   '사용',
#   '사장',
#   '사진',
#   '사태',
#   '산업',
#   '삼성',
#   '상승',
#   '상품',
#   '상황',
#   '새롭다',
#   '서다',
#   '서비스',
#   '서울',
#   '선임',
#   '설명',
#   '성장',
#   '소비자',
#   '소재',
#   '수수료',
#   '수요',
#   '수준',
#   '수출',
#   '시장',
#   '신종',
#   '실적',
#   '아니다',
#   '아시아나',
#   '않다',
#   '알려지다',
#   '앞두다',
#   '앞서',
#   '어떻다',
#   '억원',
#   '업계',
#   '업종',
#   '업체',
#   '없다',
#   '에게',
#   '에는',
#   '에도',
#   '에서',
#   '에서는',
#   '여객',
#   '여행',
#   '여행사',
#   '역시',
#   '역할',
#   '연구원',
#   '영업',
#   '영향',
#   '예상',
#   '예정',
#   '오다',
#   '오르다',
#   '올해',
#   '우려',
#   '우한',
#   '운항',
#   '위해',
#   '유가',
#   '유류',
#   '의결권',
#   '이다',
#   '이라고',
#   '이라는',
#   '이란',
#   '이르다',
#   '이명희',
#   '이번',
#   '이사',
#   '이상',
#   '이스타항공',
#   '이용',
#   '이익',
#   '이후',
#   '인수',
#   '인천',
#   '일가',
#   '일본',
#   '입장',
#   '있다',
#   '장이',
#   '재계',
#   '재무',
#   '적극',
#   '적립',
#   '전망',
#   '전무',
#   '전문',
#   '전자',
#   '정부',
#   '정석',
#   '제공',
#   '제도',
#   '제외',
#   '제주항공',
#   '조양호',
#   '조원태',
#   '조현민',
#   '조현아',
#   '종목',
#   '주가',
#   '주식',
#   '주요',
#   '주의',
#   '주주',
#   '주주총회',
#   '중국',
#   '중단',
#   '중이',
#   '증가',
#   '증권',
#   '지난',
#   '지난달',
#   '지난해',
#   '지배구조',
#   '지속',
#   '지역',
#   '직원',
#   '진에어',
#   '진행',
#   '참여',
#   '체결',
#   '총수',
#   '최근',
#   '최대',
#   '추가',
#   '카드',
#   '카카오',
#   '커지다',
#   '크다',
#   '통해',
#   '투자',
#   '특히',
#   '판교',
#   '판매',
#   '패키징',
#   '펀드',
#   '평가',
#   '폐렴',
#   '포인트',
#   '포함',
#   '필요하다',
#   '하고',
#   '하다',
#   '하락',
#   '하지만',
#   '한국',
#   '한다는',
#   '한진',
#   '할인',
#   '할증',
#   '함께',
#   '항공',
#   '항공권',
#   '항공사',
#   '해당',
#   '해외',
#   '해협',
#   '행사',
#   '현재',
#   '협력',
#   '혜택',
#   '호르무즈',
#   '호텔',
#   '확대',
#   '확보',
#   '확산',
#   '환불',
#   '회사',
#   '회장'],
#  ['가능성',
#   '가다',
#   '가운데',
#   '가장',
#   '가족',
#   '가치',
#   '각각',
#   '갈등',
#   '감소',
#   '같다',
#   '개발',
#   '개선',
#   '개편안',
#   '거래',
#   '건설',
#   '검토',
#   '결정',
#   '결제',
#   '경영',
#   '경영인',
#   '경우',
#   '경제',
#   '계약',
#   '계열',
#   '계획',
#   '고객',
#   '고문',
#   '공동',
#   '공시',
#   '공정위',
#   '관계',
#   '관계자',
#   '관련',
#   '구조',
#   '국내',
#   '국민연금',
#   '규모',
#   '그렇다',
#   '그룹',
#   '글로벌',
#   '금융',
#   '기간',
#   '기사',
#   '기업',
#   '기자',
#   '기존',
#   '기준',
#   '까지',
#   '나서다',
#   '나오다',
#   '남매',
#   '내다',
#   '내용',
#   '노선',
#   '높다',
#   '늘다',
#   '늘리다',
#   '다른',
#   '다음',
#   '달러',
#   '당시',
#   '대다',
#   '대비',
#   '대상',
#   '대표',
#   '대한',
#   '대한항공',
#   '대해',
#   '델타항공',
#   '도입',
#   '돼다',
#   '되다',
#   '들다',
#   '따르다',
#   '때문',
#   '라며',
#   '롯데',
#   '마스크',
#   '마일',
#   '마일리지',
#   '만원',
#   '만큼',
#   '많다',
#   '맞다',
#   '매입',
#   '매출',
#   '모두',
#   '모듈러',
#   '모든',
#   '목적',
#   '미국',
#   '반도',
#   '반도체',
#   '받다',
#   '발생',
#   '발표',
#   '밝히다',
#   '법인',
#   '변경',
#   '보다',
#   '보유',
#   '보이다',
#   '부문',
#   '부사',
#   '부터',
#   '분기',
#   '분석',
#   '분율',
#   '분쟁',
#   '비롯',
#   '사내',
#   '사모펀드',
#   '사실',
#   '사업',
#   '사용',
#   '사장',
#   '사진',
#   '사태',
#   '산업',
#   '삼성',
#   '상승',
#   '상품',
#   '상황',
#   '새롭다',
#   '서다',
#   '서비스',
#   '서울',
#   '선임',
#   '설명',
#   '성장',
#   '소비자',
#   '소재',
#   '수수료',
#   '수요',
#   '수준',
#   '수출',
#   '시장',
#   '신종',
#   '실적',
#   '아니다',
#   '아시아나',
#   '않다',
#   '알려지다',
#   '앞두다',
#   '앞서',
#   '어떻다',
#   '억원',
#   '업계',
#   '업종',
#   '업체',
#   '없다',
#   '에게',
#   '에는',
#   '에도',
#   '에서',
#   '에서는',
#   '여객',
#   '여행',
#   '여행사',
#   '역시',
#   '역할',
#   '연구원',
#   '영업',
#   '영향',
#   '예상',
#   '예정',
#   '오다',
#   '오르다',
#   '올해',
#   '우려',
#   '우한',
#   '운항',
#   '위해',
#   '유가',
#   '유류',
#   '의결권',
#   '이다',
#   '이라고',
#   '이라는',
#   '이란',
#   '이르다',
#   '이명희',
#   '이번',
#   '이사',
#   '이상',
#   '이스타항공',
#   '이용',
#   '이익',
#   '이후',
#   '인수',
#   '인천',
#   '일가',
#   '일본',
#   '입장',
#   '있다',
#   '장이',
#   '재계',
#   '재무',
#   '적극',
#   '적립',
#   '전망',
#   '전무',
#   '전문',
#   '전자',
#   '정부',
#   '정석',
#   '제공',
#   '제도',
#   '제외',
#   '제주항공',
#   '조양호',
#   '조원',
#   '조원태',
#   '조현민',
#   '조현아',
#   '종목',
#   '주가',
#   '주식',
#   '주요',
#   '주의',
#   '주주',
#   '주주총회',
#   '중국',
#   '중단',
#   '증가',
#   '증권',
#   '지난',
#   '지난달',
#   '지난해',
#   '지배구조',
#   '지속',
#   '지역',
#   '지원',
#   '직원',
#   '진에어',
#   '진행',
#   '참여',
#   '체결',
#   '총수',
#   '최근',
#   '최대',
#   '추가',
#   '카드',
#   '카카오',
#   '커지다',
#   '크다',
#   '통해',
#   '투자',
#   '특히',
#   '판교',
#   '판매',
#   '패키징',
#   '펀드',
#   '평가',
#   '폐렴',
#   '포인트',
#   '포함',
#   '필요하다',
#   '하고',
#   '하다',
#   '하락',
#   '하지만',
#   '한국',
#   '한다는',
#   '한진',
#   '할인',
#   '할증',
#   '함께',
#   '항공',
#   '항공권',
#   '항공사',
#   '해당',
#   '해외',
#   '해협',
#   '행사',
#   '현재',
#   '협력',
#   '혜택',
#   '호르무즈',
#   '호텔',
#   '확대',
#   '확보',
#   '확산',
#   '환불',
#   '회사',
#   '회장'],
#  ['가능성',
#   '가다',
#   '가운데',
#   '가장',
#   '가족',
#   '가치',
#   '각각',
#   '갈등',
#   '감소',
#   '같다',
#   '개발',
#   '개선',
#   '개편안',
#   '거래',
#   '건설',
#   '검토',
#   '결정',
#   '결제',
#   '경영',
#   '경영인',
#   '경우',
#   '경제',
#   '계약',
#   '계열',
#   '계획',
#   '고객',
#   '고문',
#   '공동',
#   '공시',
#   '공정위',
#   '관계',
#   '관계자',
#   '관련',
#   '구조',
#   '국내',
#   '국민연금',
#   '규모',
#   '그렇다',
#   '그룹',
#   '글로벌',
#   '금융',
#   '기간',
#   '기사',
#   '기업',
#   '기자',
#   '기존',
#   '기준',
#   '까지',
#   '나서다',
#   '나오다',
#   '남매',
#   '내다',
#   '내용',
#   '노선',
#   '높다',
#   '늘다',
#   '늘리다',
#   '다른',
#   '다음',
#   '달러',
#   '당시',
#   '대다',
#   '대비',
#   '대상',
#   '대표',
#   '대한',
#   '대한항공',
#   '대해',
#   '델타항공',
#   '도입',
#   '돼다',
#   '되다',
#   '들다',
#   '따르다',
#   '때문',
#   '라며',
#   '롯데',
#   '마스크',
#   '마일',
#   '마일리지',
#   '만원',
#   '만큼',
#   '많다',
#   '맞다',
#   '매입',
#   '매출',
#   '모두',
#   '모듈러',
#   '모든',
#   '목적',
#   '미국',
#   '반도',
#   '반도체',
#   '받다',
#   '발생',
#   '발표',
#   '밝히다',
#   '법인',
#   '변경',
#   '보다',
#   '보유',
#   '보이다',
#   '부문',
#   '부사',
#   '부터',
#   '분기',
#   '분석',
#   '분율',
#   '분쟁',
#   '비롯',
#   '사모펀드',
#   '사실',
#   '사업',
#   '사용',
#   '사장',
#   '사진',
#   '사태',
#   '산업',
#   '삼성',
#   '상승',
#   '상품',
#   '상황',
#   '새롭다',
#   '서다',
#   '서비스',
#   '서울',
#   '선임',
#   '설명',
#   '성장',
#   '소비자',
#   '소재',
#   '수수료',
#   '수요',
#   '수준',
#   '수출',
#   '시장',
#   '신종',
#   '실적',
#   '아니다',
#   '아시아나',
#   '않다',
#   '알려지다',
#   '앞두다',
#   '앞서',
#   '어떻다',
#   '억원',
#   '업계',
#   '업종',
#   '업체',
#   '없다',
#   '에게',
#   '에는',
#   '에도',
#   '에서',
#   '에서는',
#   '여객',
#   '여행',
#   '여행사',
#   '역시',
#   '역할',
#   '연구원',
#   '영업',
#   '영향',
#   '예상',
#   '예정',
#   '오다',
#   '오르다',
#   '올해',
#   '우려',
#   '우한',
#   '운항',
#   '위해',
#   '유가',
#   '유류',
#   '의결권',
#   '이다',
#   '이라고',
#   '이라는',
#   '이란',
#   '이르다',
#   '이명희',
#   '이번',
#   '이사',
#   '이상',
#   '이스타항공',
#   '이용',
#   '이익',
#   '이후',
#   '인수',
#   '인천',
#   '일가',
#   '일본',
#   '입장',
#   '있다',
#   '장이',
#   '재계',
#   '재무',
#   '적극',
#   '적립',
#   '전망',
#   '전무',
#   '전문',
#   '전자',
#   '정부',
#   '정석',
#   '제공',
#   '제도',
#   '제외',
#   '제주항공',
#   '조양호',
#   '조원',
#   '조원태',
#   '조현민',
#   '조현아',
#   '종목',
#   '주가',
#   '주식',
#   '주요',
#   '주의',
#   '주주',
#   '주주총회',
#   '중국',
#   '중단',
#   '증가',
#   '증권',
#   '지난',
#   '지난달',
#   '지난해',
#   '지배구조',
#   '지속',
#   '지역',
#   '지원',
#   '직원',
#   '진에어',
#   '진행',
#   '참여',
#   '체결',
#   '총수',
#   '최근',
#   '최대',
#   '추가',
#   '카드',
#   '카카오',
#   '커지다',
#   '크다',
#   '통해',
#   '투자',
#   '특히',
#   '판교',
#   '판매',
#   '패키징',
#   '펀드',
#   '평가',
#   '폐렴',
#   '포인트',
#   '포함',
#   '필요하다',
#   '하고',
#   '하다',
#   '하락',
#   '하지만',
#   '한국',
#   '한다는',
#   '한진',
#   '할인',
#   '할증',
#   '함께',
#   '항공',
#   '항공권',
#   '항공사',
#   '해외',
#   '해협',
#   '행사',
#   '현재',
#   '협력',
#   '혜택',
#   '호르무즈',
#   '호텔',
#   '확대',
#   '확보',
#   '확산',
#   '환불',
#   '회사',
#   '회장'],
#  ['가능성',
#   '가다',
#   '가운데',
#   '가장',
#   '가족',
#   '가치',
#   '각각',
#   '갈등',
#   '감소',
#   '같다',
#   '개발',
#   '개선',
#   '개편안',
#   '거래',
#   '건설',
#   '검토',
#   '결정',
#   '결제',
#   '경영',
#   '경영인',
#   '경우',
#   '경제',
#   '계약',
#   '계열',
#   '계획',
#   '고객',
#   '고문',
#   '공동',
#   '공시',
#   '공정위',
#   '관계',
#   '관계자',
#   '관련',
#   '구조',
#   '국내',
#   '국민연금',
#   '규모',
#   '그렇다',
#   '그룹',
#   '글로벌',
#   '금융',
#   '기간',
#   '기사',
#   '기업',
#   '기자',
#   '기존',
#   '기준',
#   '까지',
#   '나서다',
#   '나오다',
#   '남매',
#   '내다',
#   '내용',
#   '노선',
#   '높다',
#   '늘다',
#   '늘리다',
#   '다른',
#   '다음',
#   '달러',
#   '당시',
#   '대다',
#   '대비',
#   '대상',
#   '대표',
#   '대한',
#   '대한항공',
#   '대해',
#   '델타항공',
#   '도입',
#   '돼다',
#   '되다',
#   '들다',
#   '따르다',
#   '때문',
#   '라며',
#   '롯데',
#   '마스크',
#   '마일',
#   '마일리지',
#   '만원',
#   '만큼',
#   '많다',
#   '맞다',
#   '매입',
#   '매출',
#   '모두',
#   '모듈러',
#   '모든',
#   '목적',
#   '미국',
#   '반도',
#   '반도체',
#   '받다',
#   '발생',
#   '발표',
#   '밝히다',
#   '법인',
#   '변경',
#   '보다',
#   '보유',
#   '보이다',
#   '부문',
#   '부사',
#   '부터',
#   '분기',
#   '분석',
#   '분율',
#   '분쟁',
#   '비롯',
#   '사모펀드',
#   '사실',
#   '사업',
#   '사용',
#   '사장',
#   '사진',
#   '사태',
#   '산업',
#   '삼성',
#   '상승',
#   '상품',
#   '상황',
#   '새롭다',
#   '서다',
#   '서비스',
#   '서울',
#   '선임',
#   '설명',
#   '성장',
#   '소비자',
#   '소재',
#   '수수료',
#   '수요',
#   '수준',
#   '수출',
#   '시장',
#   '신종',
#   '실적',
#   '아니다',
#   '아시아나',
#   '않다',
#   '알려지다',
#   '앞두다',
#   '앞서',
#   '어떻다',
#   '억원',
#   '업계',
#   '업종',
#   '업체',
#   '없다',
#   '에게',
#   '에는',
#   '에도',
#   '에서',
#   '에서는',
#   '여객',
#   '여행',
#   '여행사',
#   '역시',
#   '역할',
#   '연구원',
#   '영업',
#   '영향',
#   '예상',
#   '예정',
#   '오다',
#   '오르다',
#   '올해',
#   '우려',
#   '우한',
#   '운항',
#   '위해',
#   '유가',
#   '유류',
#   '의결권',
#   '이다',
#   '이라고',
#   '이라는',
#   '이란',
#   '이르다',
#   '이명희',
#   '이번',
#   '이사',
#   '이상',
#   '이스타항공',
#   '이용',
#   '이익',
#   '이후',
#   '인수',
#   '인천',
#   '일가',
#   '일본',
#   '입장',
#   '있다',
#   '장이',
#   '재계',
#   '재무',
#   '적극',
#   '적립',
#   '전망',
#   '전무',
#   '전문',
#   '전자',
#   '정부',
#   '정석',
#   '제공',
#   '제도',
#   '제외',
#   '제주항공',
#   '조양호',
#   '조원',
#   '조원태',
#   '조현민',
#   '조현아',
#   '종목',
#   '주가',
#   '주식',
#   '주요',
#   '주의',
#   '주주',
#   '주주총회',
#   '중국',
#   '중단',
#   '증가',
#   '증권',
#   '지난',
#   '지난달',
#   '지난해',
#   '지배구조',
#   '지속',
#   '지역',
#   '지원',
#   '직원',
#   '진에어',
#   '진행',
#   '참여',
#   '체결',
#   '총수',
#   '최근',
#   '최대',
#   '추가',
#   '카드',
#   '카카오',
#   '커지다',
#   '크다',
#   '통해',
#   '투자',
#   '특히',
#   '판교',
#   '판매',
#   '패키징',
#   '펀드',
#   '평가',
#   '폐렴',
#   '포인트',
#   '포함',
#   '필요하다',
#   '하고',
#   '하다',
#   '하락',
#   '하지만',
#   '한국',
#   '한다는',
#   '한진',
#   '할인',
#   '할증',
#   '함께',
#   '항공',
#   '항공권',
#   '항공사',
#   '해외',
#   '해협',
#   '행사',
#   '현재',
#   '협력',
#   '혜택',
#   '호르무즈',
#   '호텔',
#   '확대',
#   '확보',
#   '확산',
#   '환불',
#   '회사',
#   '회장'],
#  ['가능성',
#   '가다',
#   '가운데',
#   '가장',
#   '가족',
#   '가치',
#   '각각',
#   '갈등',
#   '감소',
#   '같다',
#   '개발',
#   '개선',
#   '개편안',
#   '거래',
#   '건설',
#   '검토',
#   '결정',
#   '결제',
#   '경영',
#   '경영인',
#   '경우',
#   '경제',
#   '계약',
#   '계열',
#   '계획',
#   '고객',
#   '고문',
#   '공동',
#   '공시',
#   '공정위',
#   '관계',
#   '관계자',
#   '관련',
#   '구조',
#   '국내',
#   '국민연금',
#   '규모',
#   '그렇다',
#   '그룹',
#   '글로벌',
#   '금융',
#   '기간',
#   '기사',
#   '기업',
#   '기자',
#   '기존',
#   '기준',
#   '까지',
#   '나서다',
#   '나오다',
#   '남매',
#   '내다',
#   '내용',
#   '노선',
#   '높다',
#   '늘다',
#   '늘리다',
#   '다른',
#   '다음',
#   '달러',
#   '당시',
#   '대다',
#   '대비',
#   '대상',
#   '대표',
#   '대한',
#   '대한항공',
#   '대해',
#   '델타항공',
#   '도입',
#   '돼다',
#   '되다',
#   '들다',
#   '따르다',
#   '때문',
#   '라며',
#   '롯데',
#   '마스크',
#   '마일',
#   '마일리지',
#   '만원',
#   '만큼',
#   '많다',
#   '맞다',
#   '매입',
#   '매출',
#   '모두',
#   '모듈러',
#   '모든',
#   '목적',
#   '미국',
#   '반도',
#   '반도체',
#   '받다',
#   '발생',
#   '발표',
#   '밝히다',
#   '법인',
#   '변경',
#   '보다',
#   '보유',
#   '보이다',
#   '부문',
#   '부사',
#   '부터',
#   '분기',
#   '분석',
#   '분율',
#   '분쟁',
#   '비롯',
#   '사내',
#   '사모펀드',
#   '사실',
#   '사업',
#   '사용',
#   '사장',
#   '사진',
#   '사태',
#   '산업',
#   '삼성',
#   '상승',
#   '상황',
#   '새롭다',
#   '서다',
#   '서비스',
#   '서울',
#   '선임',
#   '설명',
#   '성장',
#   '소비자',
#   '소재',
#   '수수료',
#   '수요',
#   '수준',
#   '수출',
#   '시장',
#   '신종',
#   '실적',
#   '아니다',
#   '아시아나',
#   '않다',
#   '알려지다',
#   '앞두다',
#   '앞서',
#   '어떻다',
#   '억원',
#   '업계',
#   '업종',
#   '업체',
#   '없다',
#   '에게',
#   '에는',
#   '에도',
#   '에서',
#   '에서는',
#   '여객',
#   '여행',
#   '역시',
#   '역할',
#   '연구원',
#   '영업',
#   '영향',
#   '예상',
#   '예정',
#   '오다',
#   '오르다',
#   '올해',
#   '우려',
#   '우한',
#   '운영',
#   '운항',
#   '위해',
#   '유가',
#   '유류',
#   '의결권',
#   '이다',
#   '이라고',
#   '이라는',
#   '이란',
#   '이르다',
#   '이명희',
#   '이번',
#   '이사',
#   '이상',
#   '이스타항공',
#   '이용',
#   '이익',
#   '이후',
#   '인수',
#   '인천',
#   '일가',
#   '일본',
#   '입장',
#   '있다',
#   '장이',
#   '재계',
#   '재무',
#   '적극',
#   '적립',
#   '전망',
#   '전무',
#   '전문',
#   '전자',
#   '정부',
#   '정석',
#   '제공',
#   '제도',
#   '제외',
#   '제주항공',
#   '조양호',
#   '조원',
#   '조원태',
#   '조현민',
#   '조현아',
#   '종목',
#   '주가',
#   '주식',
#   '주요',
#   '주의',
#   '주주',
#   '주주총회',
#   '중국',
#   '중단',
#   '중이',
#   '증가',
#   '증권',
#   '지난',
#   '지난달',
#   '지난해',
#   '지배구조',
#   '지속',
#   '지역',
#   '지원',
#   '직원',
#   '진에어',
#   '진행',
#   '참여',
#   '체결',
#   '총수',
#   '최근',
#   '최대',
#   '추가',
#   '카드',
#   '카카오',
#   '커지다',
#   '크다',
#   '통해',
#   '투자',
#   '특히',
#   '판교',
#   '판매',
#   '패키징',
#   '펀드',
#   '평가',
#   '폐렴',
#   '포인트',
#   '포함',
#   '필요하다',
#   '하고',
#   '하다',
#   '하락',
#   '하지만',
#   '한국',
#   '한다는',
#   '한진',
#   '할인',
#   '할증',
#   '함께',
#   '항공',
#   '항공권',
#   '항공사',
#   '해외',
#   '해협',
#   '행사',
#   '현대',
#   '현재',
#   '협력',
#   '혜택',
#   '호르무즈',
#   '호텔',
#   '확대',
#   '확보',
#   '확산',
#   '환불',
#   '회사',
#   '회장'],
#  ['가능성',
#   '가다',
#   '가운데',
#   '가장',
#   '가족',
#   '가치',
#   '각각',
#   '갈등',
#   '감소',
#   '같다',
#   '개발',
#   '개선',
#   '개편안',
#   '거래',
#   '건설',
#   '검토',
#   '결정',
#   '결제',
#   '경영',
#   '경영인',
#   '경우',
#   '경제',
#   '계약',
#   '계열',
#   '계획',
#   '고객',
#   '고문',
#   '공동',
#   '공시',
#   '공정위',
#   '관계',
#   '관계자',
#   '관련',
#   '구조',
#   '국내',
#   '국민연금',
#   '규모',
#   '그렇다',
#   '그룹',
#   '글로벌',
#   '금융',
#   '기간',
#   '기사',
#   '기업',
#   '기자',
#   '기존',
#   '기준',
#   '까지',
#   '나서다',
#   '나오다',
#   '남매',
#   '내다',
#   '내용',
#   '노선',
#   '높다',
#   '늘다',
#   '늘리다',
#   '다른',
#   '다음',
#   '달러',
#   '당시',
#   '대다',
#   '대비',
#   '대상',
#   '대표',
#   '대한',
#   '대한항공',
#   '대해',
#   '델타항공',
#   '도입',
#   '돼다',
#   '되다',
#   '들다',
#   '따르다',
#   '때문',
#   '라며',
#   '롯데',
#   '마스크',
#   '마일',
#   '마일리지',
#   '만원',
#   '만큼',
#   '많다',
#   '맞다',
#   '매입',
#   '매출',
#   '모두',
#   '모듈러',
#   '모든',
#   '목적',
#   '문제',
#   '미국',
#   '반도',
#   '반도체',
#   '받다',
#   '발생',
#   '발표',
#   '밝히다',
#   '법인',
#   '변경',
#   '보다',
#   '보유',
#   '보이다',
#   '부문',
#   '부사',
#   '부터',
#   '분기',
#   '분석',
#   '분율',
#   '분쟁',
#   '비롯',
#   '사내',
#   '사모펀드',
#   '사실',
#   '사업',
#   '사용',
#   '사장',
#   '사진',
#   '사태',
#   '산업',
#   '삼성',
#   '상승',
#   '상황',
#   '새롭다',
#   '서다',
#   '서비스',
#   '서울',
#   '선임',
#   '설명',
#   '성장',
#   '소비자',
#   '소재',
#   '수수료',
#   '수요',
#   '수준',
#   '수출',
#   '시장',
#   '신종',
#   '실적',
#   '아니다',
#   '아시아나',
#   '않다',
#   '알려지다',
#   '앞두다',
#   '앞서',
#   '어떻다',
#   '억원',
#   '업계',
#   '업종',
#   '업체',
#   '없다',
#   '에게',
#   '에는',
#   '에도',
#   '에서',
#   '에서는',
#   '여객',
#   '여행',
#   '역시',
#   '역할',
#   '연구원',
#   '영업',
#   '영향',
#   '예상',
#   '예정',
#   '오다',
#   '오르다',
#   '올해',
#   '우려',
#   '우한',
#   '운영',
#   '운항',
#   '위해',
#   '유가',
#   '유류',
#   '의결권',
#   '이다',
#   '이라고',
#   '이라는',
#   '이란',
#   '이르다',
#   '이명희',
#   '이번',
#   '이사',
#   '이상',
#   '이스타항공',
#   '이용',
#   '이익',
#   '이후',
#   '인수',
#   '인천',
#   '일가',
#   '일본',
#   '입장',
#   '있다',
#   '장이',
#   '재계',
#   '재무',
#   '적극',
#   '적립',
#   '전망',
#   '전무',
#   '전문',
#   '전자',
#   '정부',
#   '정석',
#   '제공',
#   '제도',
#   '제외',
#   '제주항공',
#   '조양호',
#   '조원',
#   '조원태',
#   '조현민',
#   '조현아',
#   '종목',
#   '주가',
#   '주식',
#   '주요',
#   '주의',
#   '주주',
#   '주주총회',
#   '중국',
#   '중단',
#   '중이',
#   '증가',
#   '증권',
#   '지난',
#   '지난달',
#   '지난해',
#   '지배구조',
#   '지속',
#   '지역',
#   '지원',
#   '직원',
#   '진에어',
#   '진행',
#   '참여',
#   '체결',
#   '총수',
#   '최근',
#   '최대',
#   '추가',
#   '카드',
#   '카카오',
#   '커지다',
#   '크다',
#   '통해',
#   '투자',
#   '특히',
#   '판교',
#   '판매',
#   '패키징',
#   '펀드',
#   '평가',
#   '폐렴',
#   '포인트',
#   '포함',
#   '필요하다',
#   '하고',
#   '하다',
#   '하락',
#   '하지만',
#   '한국',
#   '한다는',
#   '한진',
#   '할인',
#   '할증',
#   '함께',
#   '항공',
#   '항공권',
#   '항공사',
#   '해외',
#   '해협',
#   '행사',
#   '현대',
#   '현재',
#   '협력',
#   '혜택',
#   '호르무즈',
#   '호텔',
#   '확대',
#   '확보',
#   '확산',
#   '환불',
#   '회사',
#   '회장']]

# %%
tfidf_df.to_excel(r'korean_air_tfidf.xlsx')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-12-75e88b351fcc> in <module>
# ----> 1 tfidf_df.to_excel(r'korean_air_tfidf.xlsx')
#
# /usr/lib/python3.7/site-packages/pandas/core/generic.py in to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep, verbose, freeze_panes)
#    2030             startcol=startcol,
#    2031             freeze_panes=freeze_panes,
# -> 2032             engine=engine,
#    2033         )
#    2034
#
# /usr/lib/python3.7/site-packages/pandas/io/formats/excel.py in write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine)
#     728             need_save = False
#     729         else:
# --> 730             writer = ExcelWriter(stringify_path(writer), engine=engine)
#     731             need_save = True
#     732
#
# /usr/lib/python3.7/site-packages/pandas/io/excel/_openpyxl.py in __init__(self, path, engine, mode, **engine_kwargs)
#      16     def __init__(self, path, engine=None, mode="w", **engine_kwargs):
#      17         # Use the openpyxl module as the Excel writer.
# ---> 18         from openpyxl.workbook import Workbook
#      19
#      20         super().__init__(path, mode=mode, **engine_kwargs)
#
# ModuleNotFoundError: No module named 'openpyxl'
