# %%
import pandas as pd

korean_air_data = pd.read_csv("korean_air_data/korean_air_2020_07.csv")

korean_air_data.columns = ["a","title","text","editor","times","date"]

del korean_air_data["a"]

# na값 제거
data = korean_air_data.dropna()

# 불용어 지정
stopwords = ['의','가','이','은','들','는','좀','잘','걍','과','박정환','도','을','것','를','등','으로','자','에','등','와','한','하다''것','\n','로']

# 한글 외의 모든 데이터 제거 : 기업명이 영어로 되어있는 경우를 어떻게 처리 해야할까?
data = data.text.str.replace("[^ㄱ-ㅎㅏ-ㅣ가-힣 ]","")

# %%
from konlpy.corpus import kolaw
from konlpy.tag import Okt
from konlpy.utils import pprint

from nltk.collocations import BigramAssocMeasures
from nltk.collocations import TrigramAssocMeasures
from nltk.metrics.association import QuadgramAssocMeasures
from nltk.collocations import BigramCollocationFinder
from nltk.collocations import TrigramCollocationFinder
from nltk.collocations import QuadgramCollocationFinder

from collections import Counter

ngram = [(BigramAssocMeasures(),BigramCollocationFinder),
         (TrigramAssocMeasures(),TrigramCollocationFinder),
         (QuadgramAssocMeasures(),QuadgramCollocationFinder)]

okt= Okt()# loading tagger
nouns = []
for sen in data:
    token = okt.morphs(sen, stem = True) # get nouns
    token = [word for word in token if not word in stopwords] 
    nouns.append(token)

# %%
founds_from_4measure = []
for i in range(0,len(nouns)):
    for measure, finder in ngram:
        finder = finder.from_words(nouns[i])
        founds = finder.nbest(measure.pmi, 10)       # pmi - 상위 10개 추출
        founds += finder.nbest(measure.chi_sq, 10)   # chi_sq - 상위 10개 추출
        founds += finder.nbest(measure.mi_like, 10)  # mi_like - 상위 10개 추출
        founds += finder.nbest(measure.jaccard, 10)  # jaccard - 상위 10개 추출

        founds_from_4measure += founds

collocations = [' '.join(collocation) for collocation in founds_from_4measure]
collocations = [(w,f) for w,f in Counter(collocations).most_common() if f > 2]
pprint(collocations)
# Out:
# [('금융감독원 전 자공시', 84),
#  ('개발 증권', 80),
#  ('거래소 데이터', 80),
#  ('국민일보 엠로보', 80),
#  ('금융감독원 전', 80),
#  ('개발 증권 뉴스', 80),
#  ('거래소 데이터 토대', 80),
#  ('국민일보 엠로보 개발', 80),
#  ('기사 국민일보 엠로보', 80),
#  ('기자 기사 국민일보', 80),
#  ('개발 증권 뉴스 전용', 80),
#  ('거래소 데이터 토대 작성', 80),
#  ('국민일보 엠로보 개발 증권', 80),
#  ('금융감독원 전 자공시 시스템', 80),
#  ('기사 국민일보 엠로보 개발', 80),
#  ('기자 기사 국민일보 엠로보', 80),
#  ('경 영', 79),
#  ('뉴스 전용 인공 지능', 76),
#  ('기자 기사', 75),
#  ('뉴스 전용 인공', 72),
#  ('기사 국민일보', 71),
#  ('경영 권', 64),
#  ('더욱 풍부하다 정확하다 내용', 64),
#  ('내용 담다 가다', 60),
#  ('기간산업 안정 기금', 60),
#  ('같다 기간', 57),
#  ('기 내', 54),
#  ('감염증 코로나', 52),
#  ('수 있다', 49),
#  ('내용 담다', 45),
#  ('권 부여', 45),
#  ('거래량 주', 44),
#  ('감염증 코로나 사태', 44),
#  ('공원 화', 43),
#  ('권 분쟁', 42),
#  ('계약 체결', 42),
#  ('더욱 풍부하다 정확하다', 40),
#  ('내 면세 품', 40),
#  ('계 열사', 38),
#  ('기내 면세점', 37),
#  ('거래량 주로', 36),
#  ('거래량 주로 직전', 36),
#  ('거래량 주로 직전 거래', 36),
#  ('기 내 면세', 36),
#  ('기 내 면세 품', 35),
#  ('경영 권 분쟁', 34),
#  ('기간산업 안정', 34),
#  ('가액 만원', 34),
#  ('내 면세 품 판매', 33),
#  ('지 분', 32),
#  ('감염증 코로', 30),
#  ('경 영 난', 30),
#  ('년 동기', 28),
#  ('마감 이후 해당 기업', 28),
#  ('년 월', 28),
#  ('감염증 코로 낫다', 28),
#  ('개 월간', 27),
#  ('뉴스 전용', 26),
#  ('기내식 기내 면세점', 26),
#  ('금융 정보', 25),
#  ('공모 방식', 24),
#  ('금액 자기', 24),
#  ('금액 자기 자본', 24),
#  ('기간 년 월', 24),
#  ('데이터 토대 작성', 24),
#  ('시 분 현재 주가', 24),
#  ('관심 쏠리다', 24),
#  ('금융 정보 업체', 24),
#  ('금융 정보 업체 에프', 24),
#  ('대한항공 부사 장', 24),
#  ('앤 컴퍼니', 24),
#  ('구조 개선', 24),
#  ('가액 만원 확정', 24),
#  ('개발 지 분', 24),
#  ('국적 항공사', 23),
#  ('고용 안정', 23),
#  ('계열 회사', 23),
#  ('구 주', 23),
#  ('개발 지', 23),
#  ('면세 품 판매', 22),
#  ('경쟁 입찰', 22),
#  ('경 영진', 22),
#  ('금융투자 업계', 22),
#  ('가지 고', 21),
#  ('가격 조원', 21),
#  ('경 영상', 21),
#  ('기간 년', 20),
#  ('격차 더 벌어지다', 20),
#  ('날 부터 다음', 20),
#  ('날 부터 다음 달', 20),
#  ('국제항 공 운송', 20),
#  ('기내 면세점 사업', 20),
#  ('기내식 기내 면세점 사업', 20),
#  ('끝 까지 추궁', 20),
#  ('각 가격', 20),
#  ('각 가격 조원', 20),
#  ('배타 적 협상 권', 20),
#  ('노동조합 긴밀하다 소통', 20),
#  ('고용 안정 보장', 20),
#  ('레저 개발 지 분', 20),
#  ('그레이스 홀딩스', 19),
#  ('내 면세', 19),
#  ('면세 품', 19),
#  ('신종 코로나바이러스 감염증 코로나', 19),
#  ('년 동기 대비', 18),
#  ('매출 액', 18),
#  ('한진 칼', 18),
#  ('국제항 공', 18),
#  ('계획 대로', 18),
#  ('그 외', 17),
#  ('격차 더', 17),
#  ('관리 공사', 17),
#  ('기내식 기내', 17),
#  ('경복궁 옆', 17),
#  ('스톡 봇', 16),
#  ('경제 유제훈', 16),
#  ('업체 에프 앤 가이드', 16),
#  ('그룹 회장 에게는', 16),
#  ('농협 은행 으로부터', 16),
#  ('건설 조현아 전', 16),
#  ('반도 건설 조현아 전', 16),
#  ('고 있다', 16),
#  ('상승 이며 거래량 주', 16),
#  ('개인 이나', 16),
#  ('거나 매각', 16),
#  ('개인 이나 법인', 16),
#  ('개인 이나 법인 상장회사', 16),
#  ('다 일명 룰 이라고도', 16),
#  ('고 시트', 16),
#  ('기자 기사 제보', 16),
#  ('같다 내용', 16),
#  ('사업 부', 16),
#  ('불다 항공 업 시너지', 16),
#  ('가격 조원 육박', 16),
#  ('각 가격 조원 육박', 16),
#  ('매 각 가격 조원', 16),
#  ('내년 월 까지 만기', 16),
#  ('공원 화 방침', 16),
#  ('기울이다 노동조합 긴밀하다', 16),
#  ('기울이다 노동조합 긴밀하다 소통', 16),
#  ('부문 직원 처우 고용', 16),
#  ('동기 대비', 15),
#  ('서민 형 안심', 15),
#  ('서민 형 안심 전환', 15),
#  ('현 대', 15),
#  ('구 주주', 15),
#  ('내년 월', 15),
#  ('검토 의견', 15),
#  ('국내 항공사', 15),
#  ('공 운송', 15),
#  ('간소 의사결정', 15),
#  ('게을리 채', 15),
#  ('곤란하다 예상', 15),
#  ('마 이스터', 15),
#  ('적 인', 14),
#  ('다음 달', 14),
#  ('계획 이라고', 14),
#  ('고 시트 백', 14),
#  ('경쟁률 대다', 14),
#  ('노력 기울이다 노동조합', 14),
#  ('가장 크다', 13),
#  ('고용 유지', 13),
#  ('송현동 부지', 13),
#  ('건설 조현아', 13),
#  ('과정 에서', 13),
#  ('가장 많다', 13),
#  ('국토교통부 협의', 13),
#  ('공간 활용', 13),
#  ('간 분할', 13),
#  ('기울이다 노동조합', 13),
#  ('경계 용 수직이착륙', 12),
#  ('동력 원 이중화', 12),
#  ('김해 원 기자', 12),
#  ('아시아나 항공', 12),
#  ('하고 있다', 12),
#  ('항공 업계', 12),
#  ('가능성 크다', 12),
#  ('코로나 사태', 12),
#  ('관측 제기', 12),
#  ('곽 선미 기자', 12),
#  ('대한 지배 력', 12),
#  ('대한 지배 력 획득', 12),
#  ('머니투데이 주 명호', 12),
#  ('권 분쟁 벌이', 12),
#  ('경영 권 분쟁 벌이', 12),
#  ('공고 내다', 12),
#  ('강 성부', 12),
#  ('강 성부 펀드', 12),
#  ('전 대한항공 부사 장', 12),
#  ('리 워드 포인트', 12),
#  ('대한 파트너 십', 12),
#  ('대한 파트너 십 계약', 12),
#  ('다 일명 룰', 12),
#  ('다스 톡봇 기자 기사', 12),
#  ('동남아 지역 본부', 12),
#  ('동남아 지역 본부 폐쇄하', 12),
#  ('본부 폐쇄하 조직 슬', 12),
#  ('공 운송 협회', 12),
#  ('국제항 공 운송 협회', 12),
#  ('검토 중이', 12),
#  ('기내 면세점 사업 부르다', 12),
#  ('같다 기 간만', 12),
#  ('경영 환경 변화', 12),
#  ('국토부 승인 거치다', 12),
#  ('기 간만', 12),
#  ('감염증 코로나 사태 장기', 12),
#  ('곽 재민 기자', 12),
#  ('미주 중국 베이징 일본', 12),
#  ('간소 의사결정 체계', 12),
#  ('기사 제보', 12),
#  ('아시아 경제', 12),
#  ('가능 금액 억만원', 12),
#  ('금액 억만원 달', 12),
#  ('가능 금액 억만원 달', 12),
#  ('대한항공 부사 장 행동', 12),
#  ('부사 장 행동 주의', 12),
#  ('시너지 효과 크다 이익', 12),
#  ('감염증 코로나 사태 이후', 12),
#  ('금융투자 업계 에서는', 12),
#  ('강민수 기자', 12),
#  ('머니투데이 강민수 기자', 12),
#  ('경쟁률 대다 기록', 12),
#  ('내년 월 까지', 12),
#  ('건물 사옥', 12),
#  ('머니투데이 이학 렬 기자', 12),
#  ('금융투자 업계 따르다', 12),
#  ('발행 가액 만원 확정', 12),
#  ('가능성 관 내용', 12),
#  ('늘다 전환사채 신주인수권', 12),
#  ('늘다 전환사채 신주인수권 부', 12),
#  ('노력 기울이다 노동조합 긴밀하다', 12),
#  ('기간산업 안정 기금 에서', 12),
#  ('산업 은행 수출입은행 채권', 12),
#  ('공모 방식 이며', 12),
#  ('개발 지 분 자산', 12),
#  ('레저 개발 지', 12),
#  ('년 간', 11),
#  ('시스템 한국 거래소 데이터', 11),
#  ('만 명', 11),
#  ('공개 매수', 11),
#  ('간사 선정', 11),
#  ('가능성 제기', 11),
#  ('같다 기', 11),
#  ('경영 환경', 11),
#  ('가능성 높다', 11),
#  ('까지 만기', 11),
#  ('경영 개선', 11),
#  ('수출입은행 채권 단 으로부터', 11),
#  ('긴밀하다 소통', 11),
#  ('검토 중인', 10),
#  ('경계 용', 10),
#  ('각 작업', 10),
#  ('가장 먼저', 10),
#  ('경진 기자', 10),
#  ('계약 해제', 10),
#  ('보통주 추가', 10),
#  ('채권 단', 10),
#  ('반도 건설', 10),
#  ('반도 건설 조현아', 10),
#  ('유동성 위기 극복', 10),
#  ('공급 부족', 10),
#  ('기대하다 어렵다', 10),
#  ('각 산업', 10),
#  ('같다 시도', 10),
#  ('배타 적 협상', 10),
#  ('공 급량', 10),
#  ('기 대감', 10),
#  ('규모 유상증자', 10),
#  ('더욱 늘어나다', 10),
#  ('네트웍 스', 10),
#  ('경 영상 어려움', 10),
#  ('보통주 추가 상장', 10),
#  ('경영학 교수', 10),
#  ('계류 장', 10),
#  ('가능성 관', 10),
#  ('산업 은행 수출입은행', 10),
#  ('송현동 부지 왕산 마리나', 10),
#  ('영업 이익', 9),
#  ('전 년 동기 대비', 9),
#  ('금융감독원 따르다', 9),
#  ('김현경 기자', 9),
#  ('까지 약', 9),
#  ('경영 실패', 9),
#  ('국가 별', 9),
#  ('신종 코로나바이러스 감염증 코로', 9),
#  ('계열 사들이다', 9),
#  ('구조 개편', 9),
#  ('곽 선미', 9),
#  ('기간 내년', 9),
#  ('조 회장', 9),
#  ('공고 게시', 9),
#  ('농협 은행', 9),
#  ('날 부터', 9),
#  ('배달 민족', 9),
#  ('고객 에게', 9),
#  ('기미 보이지', 9),
#  ('곽 재민', 9),
#  ('가능 금액', 9),
#  ('권한 침해', 9),
#  ('규합 해', 9),
#  ('그룹 회장', 9),
#  ('금액 억만원', 9),
#  ('가장 유리하다', 9),
#  ('고용 불안', 9),
#  ('품 판매', 9),
#  ('상장 예정일', 9),
#  ('매수 목표 주가 만원', 9),
#  ('목표 주가 만원 유지', 9),
#  ('공원 화하다', 9),
#  ('그 돈', 9),
#  ('감사 보고서', 9),
#  ('관 내용', 9),
#  ('관련 내용', 9),
#  ('계획 밝히다', 9),
#  ('고 정비', 8),
#  ('거치다 향후 후속', 8),
#  ('거치다 향후 후속 양산', 8),
#  ('관련 업종 취급', 8),
#  ('관련 업종 취급 제한', 8),
#  ('전 년', 8),
#  ('규모 항공', 8),
#  ('규제 시행', 8),
#  ('월 말', 8),
#  ('같다 기간 약', 8),
#  ('규모 항공 운임', 8),
#  ('기간 약 두', 8),
#  ('나타나다 일 금융감독원', 8),
#  ('두 배 불어', 8),
#  ('반면 여 신', 8),
#  ('배 불어 나다', 8),
#  ('부동산 프로젝트 파이', 8),
#  ('약 두 배', 8),
#  ('같다 기간 약 두', 8),
#  ('기간 약 두 배', 8),
#  ('나타나다 일 금융감독원 따르다', 8),
#  ('두 배 불어 나다', 8),
#  ('부동산 프로젝트 파이 낸싱', 8),
#  ('약 두 배 불어', 8),
#  ('프로젝트 파이 낸싱 장래', 8),
#  ('감소 반면 여 신', 8),
#  ('늘어나다 서민 형 안심', 8),
#  ('강 경민', 8),
#  ('강 경민 기자', 8),
#  ('까지 약 개', 8),
#  ('생존 성 높이다', 8),
#  ('까지 약 개 월간', 8),
#  ('기 순 손실', 8),
#  ('당 기 순 손실', 8),
#  ('개월 간', 8),
#  ('거치다 후속 양산', 8),
#  ('민간 창의 적', 8),
#  ('까지 약 개월 간', 8),
#  ('담다 가다', 8),
#  ('가장 크다 특징', 8),
#  ('관 법률', 8),
#  ('넥 신', 8),
#  ('디 칩스', 8),
#  ('메 틱', 8),
#  ('넥 신 주식매수선택권', 8),
#  ('디 칩스 미래나노텍', 8),
#  ('가장 높다', 8),
#  ('기용 인천대 경영학', 8),
#  ('반면 조현아 전 대한항공', 8),
#  ('감축 통해', 8),
#  ('금리 시대', 8),
#  ('기존 주주', 8),
#  ('기회 잡다', 8),
#  ('김진성 기자', 8),
#  ('금리 시대 맞다', 8),
#  ('기존 주주 및', 8),
#  ('날 유가 증권', 8),
#  ('기존 주주 및 우리', 8),
#  ('높다 신종 코로나바이러스 감염증', 8),
#  ('객실 총 개', 8),
#  ('권 분쟁 중인', 8),
#  ('낮추다 달라 고', 8),
#  ('기간 내년 월', 8),
#  ('가다 주식 연', 8),
#  ('부 사채 발행', 8),
#  ('계약 기간 내년', 8),
#  ('다 계약 기간', 8),
#  ('다 계약 기간 내년', 8),
#  ('개발 날 부터', 8),
#  ('다 향후 힘', 8),
#  ('달초 일반 공모', 8),
#  ('매입 가격 만원', 8),
#  ('물량 주다 매입', 8),
#  ('개발 날 부터 다음', 8),
#  ('다 향후 힘 겨루기', 8),
#  ('달초 일반 공모 방식', 8),
#  ('물량 주다 매입 가격', 8),
#  ('주다 매입 가격 만원', 8),
#  ('가격 만원 이다 앞서', 8),
#  ('거래소 상장', 8),
#  ('과의 격차', 8),
#  ('과의 격차 더', 8),
#  ('과의 격차 더 벌어지다', 8),
#  ('부사 장 반도 건설', 8),
#  ('권 분쟁 벌이 고', 8),
#  ('면세 품 판매 사업', 8),
#  ('조현아 전 대한항공 부사', 8),
#  ('때 현금 처럼', 8),
#  ('분야 에서도 특별', 8),
#  ('때 현금 처럼 자유롭다', 8),
#  ('산업 으로까지 빠르다 확대', 8),
#  ('경계 넘다 이종 간의', 8),
#  ('마케팅 대한 파트너 십', 8),
#  ('게임 즈', 8),
#  ('미디어 시그널 표 추다', 8),
#  ('경제정책 방향 포함', 8),
#  ('관광 숙박업 항공기', 8),
#  ('관련 절차 빠르다', 8),
#  ('규탄 기자회견 갖다', 8),
#  ('금은 현행법 상', 8),
#  ('다르다 다음 달', 8),
#  ('막다 역 부족', 8),
#  ('만큼 관련 절차', 8),
#  ('머니투데이 기성훈 기자', 8),
#  ('관광 숙박업 항공기 취급', 8),
#  ('막다 역 부족 이란', 8),
#  ('만큼 관련 절차 빠르다', 8),
#  ('밀레니엄 힐튼 서울 호텔', 8),
#  ('사진 제 공민 주노', 8),
#  ('산재 보험료 납부 기한', 8),
#  ('씨디 엘 필릭스 총지배인', 8),
#  ('엘 필릭스 총지배인 규탄', 8),
#  ('다크 라 콘스', 8),
#  ('어렵다 진입 장벽 높다', 8),
#  ('구 주 유럽', 8),
#  ('금액 대략 조원', 8),
#  ('제공 김해 원 기자', 8),
#  ('기미 보이지 않다', 8),
#  ('가량 줄 게', 8),
#  ('권 분쟁 화제', 8),
#  ('넘다 오다 동일하다', 8),
#  ('눈 여기다 볼', 8),
#  ('경영 권 분쟁 화제', 8),
#  ('눈 여기다 볼 필요', 8),
#  ('무 보증 회사채 신용등급', 8),
#  ('억 원 이다지 난', 8),
#  ('칼 신주인수권 부 사채', 8),
#  ('기능 각각 분리', 8),
#  ('기아차 정유 칼텍스', 8),
#  ('각 지점', 8),
#  ('개편 나서다', 8),
#  ('지역 본부', 8),
#  ('여객기 좌석', 8),
#  ('각 지점 직접', 8),
#  ('개편 나서다 분석', 8),
#  ('구조 개편 나서다', 8),
#  ('글로벌 영업 지원', 8),
#  ('각 지점 직접 소통', 8),
#  ('경영 환경 변화 신속하다', 8),
#  ('구조 개편 나서다 분석', 8),
#  ('깜짝 흑자 내다 추정', 8),
#  ('대신 한국 본사 글로벌', 8),
#  ('국토부 승인', 8),
#  ('건 이번 처음', 8),
#  ('국토교통부 협의 하', 8),
#  ('노력 박차 가하다', 8),
#  ('림화 자구 노력', 8),
#  ('국토부 승인 거치다 월', 8),
#  ('림화 자구 노력 박차', 8),
#  ('성 일부 증대 시키다', 8),
#  ('수익 성 일부 증대', 8),
#  ('슬 림화 자구 노력', 8),
#  ('내다 화물기 이용', 8),
#  ('떼다 내다 화물기', 8),
#  ('떼다 내다 화물기 이용', 8),
#  ('베이징 일본 도쿄 곳', 8),
#  ('국가 구성', 8),
#  ('림화 차원 이라', 8),
#  ('림화 차원 이라 며', 8),
#  ('간소 의사결정 체계 마련', 8),
#  ('급감 매출 하락', 8),
#  ('매출 하락 항공사', 8),
#  ('급감 매출 하락 항공사', 8),
#  ('매출 하락 항공사 실적', 8),
#  ('고 시트 백 장', 8),
#  ('기사 제보 및', 8),
#  ('기사 제보 및 보도자료', 8),
#  ('기자 기사 제보 및', 8),
#  ('국민은행 으로부터', 8),
#  ('국민은행 으로부터 빌리다', 8),
#  ('사실 상 중단', 8),
#  ('규합 해 자기', 8),
#  ('그 외 대다', 8),
#  ('논의 필요하다 쟁점', 8),
#  ('늑대 떼 전술', 8),
#  ('다예 들다 삼', 8),
#  ('달라 고 주문', 8),
#  ('규합 해 자기 측', 8),
#  ('논의 필요하다 쟁점 사안', 8),
#  ('늑대 떼 전술 쓸다', 8),
#  ('반하다 그 외 대다', 8),
#  ('분산 규합 해 자기', 8),
#  ('분쟁 사례 에서도 조원태', 8),
#  ('강서구 본사 앞', 8),
#  ('업 시너지 효과 크다', 8),
#  ('남부 지법 민사', 8),
#  ('단독 이상현 부장', 8),
#  ('민사 단독 이상현', 8),
#  ('밝히다 재판 불다', 8),
#  ('불법행위 라며 두', 8),
#  ('서울 남부 지법', 8),
#  ('남부 지법 민사 단독', 8),
#  ('단독 이상현 부장 판사', 8),
#  ('민사 단독 이상현 부장', 8),
#  ('서울 남부 지법 민사', 8),
#  ('지법 민사 단독 이상현', 8),
#  ('거래 이뤄지다', 8),
#  ('구입 다르다 않다', 8),
#  ('그 외 추가', 8),
#  ('다르다 않다 이르다', 8),
#  ('대 하기는 어렵다', 8),
#  ('구입 다르다 않다 이르다', 8),
#  ('무엇 인지 그 외', 8),
#  ('앤드 리스 백 방식', 8),
#  ('이용 제한 사유 향후', 8),
#  ('인지 그 외 추가', 8),
#  ('기대 돼다 오다', 8),
#  ('두다 조원태 회장 대립', 8),
#  ('기내식 및', 8),
#  ('관계자 이해관계 충분하다', 8),
#  ('관계자 이해관계 충분하다 고려', 8),
#  ('권한 대행 체제', 8),
#  ('며 흥행 성공하다', 8),
#  ('몰리 며 흥행', 8),
#  ('상장 예정일 일이', 8),
#  ('몰리 며 흥행 성공하다', 8),
#  ('에는 발행 예정 주식', 8),
#  ('김경 택', 8),
#  ('김경 택 기자', 8),
#  ('기간 연말', 8),
#  ('김민경 기자', 8),
#  ('기간 연말 께', 8),
#  ('공정 설비', 8),
#  ('굳다 히', 8),
#  ('김 하고', 8),
#  ('공정 설비 선도', 8),
#  ('굳다 히 자리다', 8),
#  ('늘어나다 보이다 설명', 8),
#  ('다시 한번 확인', 8),
#  ('더욱 늘어나다 보이다', 8),
#  ('매출 액 대비', 8),
#  ('굳다 히 자리다 김', 8),
#  ('더욱 늘어나다 보이다 설명', 8),
#  ('발주 더욱 늘어나다 보이다', 8),
#  ('시장 선점 하 며', 8),
#  ('지난해 매출 액 대비', 8),
#  ('노 단양 천안', 8),
#  ('단양 천안 경주', 8),
#  ('대명 델피 노', 8),
#  ('델피 노 단양', 8),
#  ('디지털 특가 유아', 8),
#  ('리조트 웰리 힐리', 8),
#  ('무제한 플러스 년', 8),
#  ('바깥 활동 자제', 8),
#  ('노 단양 천안 경주', 8),
#  ('대명 델피 노 단양', 8),
#  ('델피 노 단양 천안', 8),
#  ('디지털 특가 유아 용', 8),
#  ('리조트 웰리 힐리 파크', 8),
#  ('약간 추가 요금 보태', 8),
#  ('엘리 시안 강촌 하이', 8),
#  ('가장 크게', 8),
#  ('경제 미치다 영향', 8),
#  ('공 정성 국민', 8),
#  ('공원 화하다 보상', 8),
#  ('공 정성 국민 경제', 8),
#  ('공원 화하다 보상 비', 8),
#  ('국민 경제 미치다 영향', 8),
#  ('대책 본부 회의', 8),
#  ('디스플레이 패널 업체', 8),
#  ('맥 중국 디스플레이', 8),
#  ('디스플레이 패널 업체 오다', 8),
#  ('맥 중국 디스플레이 패널', 8),
#  ('가로막히다 차질', 8),
#  ('가로막히다 차질 빚', 8),
#  ('규모 억원 넘다', 8),
#  ('대응 방안 보고서', 8),
#  ('국토교통부 조 종인 력', 8),
#  ('가능성 보이다', 8),
#  ('강원도 양양', 8),
#  ('걸리다 보다', 8),
#  ('강원도 양양 신규', 8),
#  ('걸리다 보다 해외', 8),
#  ('공 급량 한정', 8),
#  ('광저우 제주 시안', 8),
#  ('그간 하늘 길이', 8),
#  ('기대하다 분위기 다', 8),
#  ('길이 막히다 양국', 8),
#  ('다녀오다 후 주간', 8),
#  ('대부분 오픈 동시', 8),
#  ('강원도 양양 신규 취항', 8),
#  ('걸리다 보다 해외 다녀오다', 8),
#  ('그간 하늘 길이 막히다', 8),
#  ('다녀오다 후 주간 의무', 8),
#  ('대부분 오픈 동시 매진', 8),
#  ('더 걸리다 보다 해외', 8),
#  ('반면 그간 하늘 길이', 8),
#  ('금융투자 업계 에서는 매', 8),
#  ('개정안 마련 오다', 8),
#  ('결성 후 년내', 8),
#  ('관 법률 개정안', 8),
#  ('넘기다 그 돈', 8),
#  ('다시 살리다 프로', 8),
#  ('대거 풀다 해외', 8),
#  ('개정안 마련 오다 정기', 8),
#  ('관 법률 개정안 마련', 8),
#  ('뒤 채무 조정 거치', 8),
#  ('법률 개정안 마련 오다', 8),
#  ('금융 정보 제공', 8),
#  ('금융 정보 제공 업체', 8),
#  ('선전 에어부산 노선도', 8),
#  ('에어부산 노선도 달', 8),
#  ('선전 에어부산 노선도 달', 8),
#  ('서소문 사옥 앞 지나다', 8),
#  ('계 따르다', 8),
#  ('대한항공 만주', 8),
#  ('렉스 위지윅', 8),
#  ('네트웍 스 아이큐', 8),
#  ('대한항공 만주 만원', 8),
#  ('렉스 위지윅 스튜디오', 8),
#  ('만원 일반 공모', 8),
#  ('만주 만원 일반', 8),
#  ('대한항공 만주 만원 일반', 8),
#  ('만주 만원 일반 공모', 8),
#  ('상장 유틸 렉스 위지윅', 8),
#  ('가이드 따르다', 8),
#  ('기준 일', 8),
#  ('디 테크놀로지', 8),
#  ('마 이스터 한양', 8),
#  ('감사 보고서 상', 8),
#  ('가장 많이', 8),
#  ('대림 건설', 8),
#  ('델타 테크', 8),
#  ('겪다 있다', 8),
#  ('각 대금', 8),
#  ('경우 연', 8),
#  ('경우 연 매출', 8),
#  ('간 억만원', 8),
#  ('간 억만원 브랜드', 8),
#  ('강진 광주 고속', 8),
#  ('거래소 상대 상장폐지', 8),
#  ('결과 청약 률', 8),
#  ('경남 제 약', 8),
#  ('계 열사 한진', 8),
#  ('계열 회사 아이파크몰', 8),
#  ('고속 공구 토공', 8),
#  ('공장 월일 스풀', 8),
#  ('간 억만원 브랜드 사용권', 8),
#  ('강진 광주 고속 공구', 8),
#  ('경남 제 약 헬', 8),
#  ('계 열사 한진 칼', 8),
#  ('공장 월일 스풀 밸브', 8),
#  ('관련 배타 적 협상', 8),
#  ('광주 고속 공구 토공', 8),
#  ('국제공항 전망대 서', 8),
#  ('국제공항 전망대 서 바라보다', 8),
#  ('간 분할 지급', 8),
#  ('기금 에서 하반기', 8),
#  ('감염증 코로나 장기', 8),
#  ('감염증 코로나 장기 화', 8),
#  ('개최 하고', 8),
#  ('모습 뉴스 제 공', 8),
#  ('감염증 코로나 사태 인하다', 8),
#  ('금액 내년', 8),
#  ('금액 내년 월', 8),
#  ('까지 만기 도래', 8),
#  ('날 오후 이사회', 8),
#  ('공모 방식 이며 주다', 8),
#  ('금액 내년 월 까지', 8),
#  ('머니투데이 이학 렬', 8),
#  ('가능성 관 내용 포함', 8),
#  ('국내 위 사모펀드', 8),
#  ('달 주주 배정 유상증자', 8),
#  ('관련 내용 보고', 8),
#  ('공원 화하다 밝히다', 8),
#  ('경 영 난 겪다', 8),
#  ('서울시 공원 화 방침', 8),
#  ('기금 운용 심의회', 8),
#  ('기간산업 안정 기금 운용', 8),
#  ('년 간 분할', 8),
#  ('대금 년 간', 8),
#  ('서울 경복궁 옆', 8),
#  ('대금 년 간 분할', 8),
#  ('공항 산업 기술', 8),
#  ('공항 산업 기술 연구원', 8),
#  ('금융채 권', 7),
#  ('형 안심 전환', 7),
#  ('경민 기자', 7),
#  ('간 협의', 7),
#  ('거치다 후속', 7),
#  ('강도원 기자', 7),
#  ('경쟁력 약화', 7),
#  ('가속 화', 7),
#  ('검토 들어가다', 7),
#  ('강화하다 예정', 7),
#  ('감 느끼다', 7),
#  ('게 아니다', 7),
#  ('억 원', 7),
#  ('가다 주식', 7),
#  ('계약 기간', 7),
#  ('지 분율', 7),
#  ('우진 기자', 7),
#  ('머니투데이 주 명호 기자', 7),
#  ('김지윤 기자', 7),
#  ('거 세다', 7),
#  ('거슬러 올라가다', 7),
#  ('대한항공 스타벅스', 7),
#  ('때 현금', 7),
#  ('리 워드', 7),
#  ('강서구 김포공항', 7),
#  ('대한 파트너', 7),
#  ('경우 올해', 7),
#  ('경쟁 벌이', 7),
#  ('과는 차별', 7),
#  ('한진 칼 신주인수권 부', 7),
#  ('각각 분리', 7),
#  ('거치다 월', 7),
#  ('건 이번', 7),
#  ('가치 상승', 7),
#  ('경영 난', 7),
#  ('강서구 본사', 7),
#  ('결정 해당', 7),
#  ('남부 지법', 7),
#  ('다양하다 경제활동', 7),
#  ('단독 이상현', 7),
#  ('대한항공 아시아나', 7),
#  ('권리 락', 7),
#  ('구입 다르다', 7),
#  ('고려 하고', 7),
#  ('며 흥행', 7),
#  ('몰리 며', 7),
#  ('발행 예정', 7),
#  ('대다 기록', 7),
#  ('걸리다 전망', 7),
#  ('늘어나다 보이다', 7),
#  ('다시 한번', 7),
#  ('각국 정부', 7),
#  ('계속 사용', 7),
#  ('거리 두기', 7),
#  ('공 모', 7),
#  ('격리 조처', 7),
#  ('노선도 달', 7),
#  ('기금 운용', 7),
#  ('강진 광주', 7),
#  ('거래소 상대', 7),
#  ('결과 청약', 7),
#  ('경남 제', 7),
#  ('고속 공구', 7),
#  ('공구 토공', 7),
#  ('서울 종로구 송현동 부지', 7),
#  ('월 산업 은행 수출입은행', 7),
#  ('부지 왕산 마리나 부동산', 7),
#  ('가다 약', 7),
#  ('관계자 해당', 7),
#  ('관계 사', 7),
#  ('근로시간 조정', 7),
#  ('거치다 향후', 6),
#  ('관련 업종', 6),
#  ('부동산 장래', 6),
#  ('서민 형', 6),
#  ('매 각', 6),
#  ('기간 약', 6),
#  ('나타나다 일', 6),
#  ('낸싱 장래', 6),
#  ('두 배', 6),
#  ('공항 라운지', 6),
#  ('동력 원', 6),
#  ('채무 보증', 6),
#  ('고도 높이', 6),
#  ('년 부터', 6),
#  ('가장 유력하다', 6),
#  ('거 라는', 6),
#  ('미래에셋 대우', 6),
#  ('날 유가', 6),
#  ('개발 예비', 6),
#  ('객실 총', 6),
#  ('건설 사', 6),
#  ('한진 그룹', 6),
#  ('가다 따르다', 6),
#  ('기내 면세 품', 6),
#  ('경영 악화', 6),
#  ('규모 약', 6),
#  ('공모 총', 6),
#  ('권 방어', 6),
#  ('경영 권 방어', 6),
#  ('가격 만원', 6),
#  ('개발 날', 6),
#  ('다 향후', 6),
#  ('마케팅 대한', 6),
#  ('경제정책 방향', 6),
#  ('고용노동부 따르다', 6),
#  ('공민 주노', 6),
#  ('관광 숙박업', 6),
#  ('관련 절차', 6),
#  ('규탄 기자회견', 6),
#  ('금은 현행법', 6),
#  ('기성훈 기자', 6),
#  ('기자회견 갖다', 6),
#  ('지난 월', 6),
#  ('공적 자금', 6),
#  ('금액 대략', 6),
#  ('구 매', 6),
#  ('가량 줄', 6),
#  ('갈수록 악화', 6),
#  ('공시 일월', 6),
#  ('급락 영향', 6),
#  ('신주 발행', 6),
#  ('기술 통해 언택트', 6),
#  ('네 마는 다양하다', 6),
#  ('다양하다 하이테크 기술', 6),
#  ('들다 영업 재개', 6),
#  ('가능성 커지다', 6),
#  ('사실 상', 6),
#  ('검토 대상', 6),
#  ('국토교통부 승인', 6),
#  ('노력 박차', 6),
#  ('공급 부족하다', 6),
#  ('미주 중국 베이징', 6),
#  ('과연 누구', 6),
#  ('경쟁 사', 6),
#  ('노선 운항', 6),
#  ('공 들이다', 6),
#  ('대한항공 아시아나 항공', 6),
#  ('고 주문', 6),
#  ('나라 만들다', 6),
#  ('분쟁 상황 속', 6),
#  ('국내 사모펀드', 6),
#  ('매 각 가격', 6),
#  ('기대 돼다', 6),
#  ('두다 조원태 회장', 6),
#  ('매수 목표 주가', 6),
#  ('강촌 하이', 6),
#  ('끌 전망', 6),
#  ('나주 중흥', 6),
#  ('낫다 지치다', 6),
#  ('노 단양', 6),
#  ('경제 미치다', 6),
#  ('고안 면밀하다', 6),
#  ('공동 투자', 6),
#  ('공 정성', 6),
#  ('고정관념 탈피', 6),
#  ('국내 사업자', 6),
#  ('공장 인근', 6),
#  ('만원 유지', 6),
#  ('목표 주가 만원', 6),
#  ('김현정 기자', 6),
#  ('경영 실적', 6),
#  ('광저우 제주', 6),
#  ('국가 중심', 6),
#  ('거치 며', 6),
#  ('개정안 마련', 6),
#  ('결성 후', 6),
#  ('구멍 막다', 6),
#  ('그룹 알짜', 6),
#  ('관심 보이다', 6),
#  ('계열 사인', 6),
#  ('급 물살', 6),
#  ('공 방이', 6),
#  ('국제공항 전망대', 6),
#  ('관련 배타', 6),
#  ('나가다 이라고', 6),
#  ('마리나 부동산 자산', 6),
#  ('경우 추가', 6),
#  ('국내 위', 6),
#  ('공항 산업', 6),
#  ('하이브리드 드론', 5),
#  ('실권 주', 5),
#  ('여객 수요', 5),
#  ('신 속', 5),
#  ('네이쳐 홀딩스', 5),
#  ('더 네이쳐', 5),
#  ('지 원금', 5),
#  ('계획 이다', 5),
#  ('지 원', 5),
#  ('자산 매각', 5),
#  ('경영 권 분쟁 중인', 5),
#  ('기안 기금', 5),
#  ('대 카드', 5),
#  ('네 마는 다양하다 하이테크', 5),
#  ('다양하다 하이테크 기술 통해', 5),
#  ('마는 다양하다 하이테크 기술', 5),
#  ('구체 적', 5),
#  ('속 회사', 5),
#  ('아이티 엠', 5),
#  ('삼 성', 5),
#  ('까지 추궁', 5),
#  ('배타 적', 5),
#  ('공모 청약', 5),
#  ('부 매각', 5),
#  ('디 에스케이', 5),
#  ('장 우진', 5),
#  ('길이 막히다', 5),
#  ('국제선 여객', 5),
#  ('매출 감소', 5),
#  ('돼다 일', 5),
#  ('감소 경 영상 어려움', 5),
#  ('단 으로부터', 5),
#  ('근로자 수의', 5),
#  ('경 영상 어려움 겪다', 5),
#  ('매출 피해', 5),
#  ('감 기술', 4),
#  ('감 기술 확보', 4),
#  ('같다 기간 보다', 4),
#  ('고 정비 절감', 4),
#  ('과를 곁들이다 누르다', 4),
#  ('과일 수정 과를', 4),
#  ('광저우 세계 각지', 4),
#  ('기업 고객 에게도', 4),
#  ('내 뉴스 채널', 4),
#  ('고 정비 절감 구조', 4),
#  ('과일 수정 과를 곁들이다', 4),
#  ('내 뉴스 채널 기고', 4),
#  ('뉴스 채널 기고 칼럼', 4),
#  ('독일 프랑크푸르트 베트남 하노이', 4),
#  ('명 마마 무 인기', 4),
#  ('바이오 연료 생산 및', 4),
#  ('방향 사회 패러다임 변화', 4),
#  ('베트남 하노이 중국 광저우', 4),
#  ('고사 직 전일', 4),
#  ('기 저 비용', 4),
#  ('대거 줄 도산', 4),
#  ('도산 행 발생', 4),
#  ('모르다 터 라', 4),
#  ('부채 비율 훌쩍', 4),
#  ('불확실 성 제거', 4),
#  ('비율 훌쩍 넘기다', 4),
#  ('고사 직 전일 뿐', 4),
#  ('기 저 비용 항공사', 4),
#  ('대거 줄 도산 행', 4),
#  ('모르다 터 라 선뜻', 4),
#  ('부채 비율 훌쩍 넘기다', 4),
#  ('비율 훌쩍 넘기다 지난해', 4),
#  ('연 기 저 비용', 4),
#  ('전일 뿐 아니다 주요', 4),
#  ('줄 도산 행 발생', 4),
#  ('금융감독원 발표', 4),
#  ('동향 따르다', 4),
#  ('안심 전환', 4),
#  ('금융감독원 발표 올해', 4),
#  ('부터 정부 서민', 4),
#  ('없다 항공 운임', 4),
#  ('월말 현재 전체', 4),
#  ('일 금융감독원 발표', 4),
#  ('정부 서민 형', 4),
#  ('단말기 할부 대금', 4),
#  ('전 년 동기', 4),
#  ('부터 정부 서민 형', 4),
#  ('일 금융감독원 발표 올해', 4),
#  ('정부 서민 형 안심', 4),
#  ('돼다 월말 현재 전체', 4),
#  ('조사 돼다 월말 현재', 4),
#  ('크게 늘다 때문 이다', 4),
#  ('형 안심 전환 대출', 4),
#  ('공사 주택 저 당', 4),
#  ('과당 경쟁', 4),
#  ('가타 노자 카', 4),
#  ('건전성 나타내다 자기', 4),
#  ('경쟁력 스스로 훼손', 4),
#  ('고스 란 히', 4),
#  ('공적자금 투입 및', 4),
#  ('과당 경쟁 후유증', 4),
#  ('관계 부처 관료', 4),
#  ('기수 대 대다', 4),
#  ('기업 재무 건전성', 4),
#  ('깨다 접근 법', 4),
#  ('가타 노자 카 신야', 4),
#  ('건전성 나타내다 자기 본', 4),
#  ('경쟁력 스스로 훼손 선례', 4),
#  ('고스 란 히 입다', 4),
#  ('공적자금 투입 및 국유화', 4),
#  ('관계 부처 관료 요미우리신문', 4),
#  ('기수 대 대다 노', 4),
#  ('기업 재무 건전성 나타내다', 4),
#  ('나타내다 자기 본 비율', 4),
#  ('노자 카 신야 사장', 4),
#  ('대한항공 총 회', 4),
#  ('동기 대비 발행량', 4),
#  ('분기 부터 급증', 4),
#  ('일 밝히다 한국', 4),
#  ('총 회 걸치다', 4),
#  ('항공사 항공 운임', 4),
#  ('년 동기 대비 발행량', 4),
#  ('대한항공 총 회 걸치다', 4),
#  ('여 신 전 문', 4),
#  ('정부 정책 시행 따르다', 4),
#  ('예대율 규제 정부 정책', 4),
#  ('기 순이익', 4),
#  ('공항 라운지 무료', 4),
#  ('광화문 사옥 이전', 4),
#  ('까지 발급 가능하다', 4),
#  ('달 초 기업', 4),
#  ('대비 늘다 작년', 4),
#  ('듯이 행복하다 삶', 4),
#  ('미치다 듯이 행복하다', 4),
#  ('발급 가능하다 전월', 4),
#  ('본질 초점 맞추다', 4),
#  ('삶 의미 담다', 4),
#  ('까지 발급 가능하다 전월', 4),
#  ('달 초 기업 얼굴', 4),
#  ('듯이 행복하다 삶 의미', 4),
#  ('미치다 듯이 행복하다 삶', 4),
#  ('서울 광화문 사옥 이전', 4),
#  ('쇼핑 오토 헬스 에듀', 4),
#  ('오토 헬스 에듀 커피', 4),
#  ('이용권 공항 라운지 무료', 4),
#  ('장 까지 발급 가능하다', 4),
#  ('주요 특급 호텔 레스토랑', 4),
#  ('개발 고성능', 4),
#  ('속 시범', 4),
#  ('도영 상 에서도', 4),
#  ('도입 돼다 이번', 4),
#  ('뒤 후속 양산', 4),
#  ('상 에서도 정상', 4),
#  ('성 높이다 최대', 4),
#  ('속도 시속 달', 4),
#  ('도영 상 에서도 정상', 4),
#  ('뒤 후속 양산 결정', 4),
#  ('상 에서도 정상 작동', 4),
#  ('생존 성 높이다 최대', 4),
#  ('수 있다 동력 원', 4),
#  ('영하 도영 상 에서도', 4),
#  ('운용 해보다 뒤 후속', 4),
#  ('있다 동력 원 이중화', 4),
#  ('해보다 뒤 후속 양산', 4),
#  ('기 순', 4),
#  ('간 협의 무성의', 4),
#  ('공 김해 원', 4),
#  ('그렇다 계획 전혀', 4),
#  ('다시 배 분할', 4),
#  ('당 기 순', 4),
#  ('대량 매매 방식', 4),
#  ('돕다 제도 다', 4),
#  ('간 협의 무성의 지연', 4),
#  ('공 김해 원 기자', 4),
#  ('기 순 손실 내다', 4),
#  ('두다 우려 시선 쏟아내다', 4),
#  ('블록딜 시간 외 대량', 4),
#  ('사후 에도 지속 가능하다', 4),
#  ('시간 외 대량 매매', 4),
#  ('시점 이라 며 이르다', 4),
#  ('외 대량 매매 방식', 4),
#  ('까지 약 개월', 4),
#  ('높이다 전자광학 및', 4),
#  ('및 적외선 카메라', 4),
#  ('분 이내 운영', 4),
#  ('성 높이다 전자광학', 4),
#  ('거치다 후속 양산 결정', 4),
#  ('높이다 전자광학 및 적외선', 4),
#  ('민간 창의 적 인', 4),
#  ('및 적외선 카메라 탑재', 4),
#  ('생존 성 높이다 전자광학', 4),
#  ('성 높이다 전자광학 및', 4),
#  ('전자광학 및 적외선 카메라', 4),
#  ('해안 경계 용 수직이착륙', 4),
#  ('향상 시키다 정유미 기자', 4),
#  ('강화하다 다양하다', 4),
#  ('강화하다 다양하다 환경', 4),
#  ('고도 높이 고', 4),
#  ('맺다 자사 자체', 4),
#  ('무기체계 일환 신속', 4),
#  ('거치다 후속 양산 여부', 4),
#  ('동력 원 이중화 생존', 4),
#  ('범위 에서도 정상 작동', 4),
#  ('사이 범위 에서도 정상', 4),
#  ('생존 성 강화하다 다양하다', 4),
#  ('성 강화하다 다양하다 환경', 4),
#  ('시키다 유 제 훈', 4),
#  ('온도 사이 범위 에서도', 4),
#  ('원 이중화 생존 성', 4),
#  ('구 조물', 4),
#  ('가지 설계 제조', 4),
#  ('거듭 날 이라고', 4),
#  ('건축물 철근콘크리트 구조', 4),
#  ('계단 실 엘리베이터', 4),
#  ('골 조 타입', 4),
#  ('골다 조르다 나중', 4),
#  ('김 순환 기자', 4),
#  ('노르웨이 스칸디나비아반도 포함', 4),
#  ('먹거리 본격 추진', 4),
#  ('가지 설계 제조 공정', 4),
#  ('계단 실 엘리베이터 홀', 4),
#  ('설계 제조 공정 자동화', 4),
#  ('스웨덴 노르웨이 스칸디나비아반도 포함', 4),
#  ('실 엘리베이터 홀 등를', 4),
#  ('엘리베이터 홀 등를 먼저', 4),
#  ('여 가지 설계 제조', 4),
#  ('영업 지역 상호 보완', 4),
#  ('이번 처음 인데 두', 4),
#  ('향후 스웨덴 노르웨이 스칸디나비아반도', 4),
#  ('가능하다 기능', 4),
#  ('개선 통해', 4),
#  ('가능하다 기능 탑재', 4),
#  ('개선 통해 소방', 4),
#  ('거나 실시간 전송', 4),
#  ('경찰 플랜트 산', 4),
#  ('고 해상도 영상', 4),
#  ('과학기술 정보통신부 사다', 4),
#  ('국기 계 연구원', 4),
#  ('국내 최초 초', 4),
#  ('개선 통해 소방 경찰', 4),
#  ('거나 실시간 전송 받다', 4),
#  ('경찰 플랜트 산 업체', 4),
#  ('고 해상도 영상 촬영', 4),
#  ('과학기술 정보통신부 사다 국기', 4),
#  ('국내 최초 초 경량', 4),
#  ('기간 거치다 향후 후속', 4),
#  ('다 함께 해외 시장', 4),
#  ('거두다 바', 4),
#  ('국적 항공사 망하다', 4),
#  ('그치다 우리 사주', 4),
#  ('기간 만료 대비', 4),
#  ('까지 전 직원', 4),
#  ('늘다 분위기 다른', 4),
#  ('다양하다 방안 마련', 4),
#  ('대상 무급 휴직', 4),
#  ('대형 국적 항공사', 4),
#  ('들이다 크다 영향', 4),
#  ('국적 항공사 망하다 않다', 4),
#  ('그치다 우리 사주 조합', 4),
#  ('까지 전 직원 대상', 4),
#  ('대상 무급 휴직 전환', 4),
#  ('대형 국적 항공사 망하다', 4),
#  ('망하다 않다 이란 심리', 4),
#  ('며 예상외 선방 거두다', 4),
#  ('몰리 며 예상외 선방', 4),
#  ('무급 휴직 전환 신청', 4),
#  ('가다 방안 이야기', 4),
#  ('갈다 거 라는', 4),
#  ('거 라는 전망', 4),
#  ('곳 정도 만', 4),
#  ('과거 한화 그룹', 4),
#  ('금융위 진화 원인', 4),
#  ('나오다 물론 모든', 4),
#  ('느끼다 분위기 전혀', 4),
#  ('대신 년 까지', 4),
#  ('가다 방안 이야기 나오다', 4),
#  ('갈다 거 라는 전망', 4),
#  ('곳 정도 만 운영', 4),
#  ('금융위 진화 원인 제공', 4),
#  ('기간산업 안정 기금 신청', 4),
#  ('느끼다 분위기 전혀 다르다', 4),
#  ('라고 표현 같다 어쨌든', 4),
#  ('방안 이야기 나오다 물론', 4),
#  ('설명 자료 통해 원론', 4),
#  ('수순 갈다 거 라는', 4),
#  ('가격결정 재고 관리', 4),
#  ('경 영 회의', 4),
#  ('경제 금융 센터', 4),
#  ('공 정거 래', 4),
#  ('공정거래법 엄격하다 금지', 4),
#  ('관 법률 도입', 4),
#  ('그대로 물건 건네다', 4),
#  ('금융 센터 간사', 4),
#  ('경제 금융 센터 간사', 4),
#  ('공 정거 래 위원회', 4),
#  ('그대로 물건 건네다 만으로', 4),
#  ('기반 무너 뜨다 리', 4),
#  ('끊임없다 문제 일으키다 오다', 4),
#  ('대물리다 수단 하나로 끊임없다', 4),
#  ('대한항공 항공기 장비 기', 4),
#  ('뒤 부터는 달걀 알맹이', 4),
#  ('맥주 캔 제조 유통', 4),
#  ('문제 일으키다 오다 다년', 4),
#  ('간격 식', 4),
#  ('감사 드리다', 4),
#  ('거머쥐 게', 4),
#  ('건의 리뷰', 4),
#  ('관광지 대한', 4),
#  ('관심 감사', 4),
#  ('간격 식 음료', 4),
#  ('감사 드리다 앞', 4),
#  ('관광지 대한 억만', 4),
#  ('관심 감사 드리다', 4),
#  ('기 내 청결', 4),
#  ('기내 엔터테인먼트 여러', 4),
#  ('내 청결 좌석', 4),
#  ('높다 평가 받다', 4),
#  ('다트 립 어', 4),
#  ('대한 억만 건의', 4),
#  ('간격 식 음료 기내', 4),
#  ('감사 드리다 앞 으로도', 4),
#  ('관광지 대한 억만 건의', 4),
#  ('관심 감사 드리다 앞', 4),
#  ('기 내 청결 좌석', 4),
#  ('내 청결 좌석 간격', 4),
#  ('다트 립 어 드', 4),
#  ('대한 억만 건의 리뷰', 4),
#  ('서비스 기 내 청결', 4),
#  ('수 있다 최선 노력', 4),
#  ('건설 계획', 4),
#  ('공동 건설', 4),
#  ('과정 막대', 4),
#  ('공동 건설 계획', 4),
#  ('과정 막대 예산', 4),
#  ('관련 시장 아직', 4),
#  ('그리고 판로 확보', 4),
#  ('그림 그리고 판로', 4),
#  ('기다 연구개발 과정', 4),
#  ('나로호 역시 대한항공', 4),
#  ('나타나다 특히 현재', 4),
#  ('누리 호 달', 4),
#  ('대한항공 화두 원', 4),
#  ('과정 막대 예산 필요하다', 4),
#  ('관련 시장 아직 영세', 4),
#  ('그림 그리고 판로 확보', 4),
#  ('기다 연구개발 과정 막대', 4),
#  ('나로호 역시 대한항공 화두', 4),
#  ('누리 호 달 궤도선', 4),
#  ('막대 예산 필요하다 설령', 4),
#  ('아랍권 에서는 최초 화성', 4),
#  ('아랍에미리트 아랍권 에서는 최초', 4),
#  ('액 억원 미만 이고', 4),
#  ('공모 일', 4),
#  ('금융 지원', 4),
#  ('기기 제조업', 4),
#  ('기업인 수목', 4),
#  ('기타 정밀', 4),
#  ('대한항공 와이', 4),
#  ('미래나노텍 신성', 4),
#  ('공모 일 세다', 4),
#  ('금융 지원 서비스업', 4),
#  ('기업인 수목 적', 4),
#  ('기타 정밀 기기', 4),
#  ('대한항공 와이 오', 4),
#  ('메 틱 디', 4),
#  ('미래나노텍 신성 엔', 4),
#  ('및 기타 정밀', 4),
#  ('공모 일 세다 신규', 4),
#  ('기업인 수목 적 금융', 4),
#  ('기타 정밀 기기 제조업', 4),
#  ('넥 신 주식매수선택권 제', 4),
#  ('대한항공 와이 오 엠', 4),
#  ('디 칩스 미래나노텍 신성', 4),
#  ('메 틱 디 칩스', 4),
#  ('미래나노텍 신성 엔 지다', 4),
#  ('및 기타 정밀 기기', 4),
#  ('보통주 추가 상 장제', 4),
#  ('가능성 에는 물음표', 4),
#  ('계약 해제 투자', 4),
#  ('국내 최대 항공사', 4),
#  ('국면 에서 가장', 4),
#  ('그래도 국내 최대', 4),
#  ('년 같다 기간', 4),
#  ('다 한편 잠잠하다', 4),
#  ('두다 않다 이라는', 4),
#  ('로서 정부 망하다', 4),
#  ('가능성 에는 물음표 제기', 4),
#  ('국내 최대 항공사 로서', 4),
#  ('국면 에서 가장 먼저', 4),
#  ('그래도 국내 최대 항공사', 4),
#  ('로서 정부 망하다 두다', 4),
#  ('말 부채 비율 넘다', 4),
#  ('망하다 두다 않다 이라는', 4),
#  ('매매 계약 해제 투자', 4),
#  ('내 코스닥', 4),
#  ('대 덕주', 4),
#  ('대한항공 유상', 4),
#  ('모유 상', 4),
#  ('신 주식매수선택권 행사', 4),
#  ('신성 엔 지국', 4),
#  ('실권 주청 약세', 4),
#  ('아 코퍼레이션 에이치', 4),
#  ('아이비 제호 스팩', 4),
#  ('에이 디 칩스', 4),
#  ('에이치 엠씨 아이비', 4),
#  ('엔 지국 내', 4),
#  ('넥 신 주식매수선택권 행사', 4),
#  ('신 주식매수선택권 행사 신규', 4),
#  ('신성 엔 지국 내', 4),
#  ('실권 주청 약세 하주', 4),
#  ('아 코퍼레이션 에이치 엠씨', 4),
#  ('에이 디 칩스 미래나노텍', 4),
#  ('에이치 엠씨 아이비 제호', 4),
#  ('엔 지국 내 코스닥', 4),
#  ('엠씨 아이비 제호 스팩', 4),
#  ('엠투 아 코퍼레이션 에이치', 4),
#  ('가게 두다', 4),
#  ('각하 거나', 4),
#  ('감염병 진정', 4),
#  ('산업 은행', 4),
#  ('각하 거나 출자전환', 4),
#  ('거나 출자전환 통해', 4),
#  ('건 공공 연하다', 4),
#  ('경영 실패 재무', 4),
#  ('경쟁력 타격 받다', 4),
#  ('공공 연하다 사실', 4),
#  ('구채 조억원 차입', 4),
#  ('국가 경쟁력 타격', 4),
#  ('까지 가게 두다', 4),
#  ('끝 지난해 매물', 4),
#  ('각하 거나 출자전환 통해', 4),
#  ('거나 출자전환 통해 일시', 4),
#  ('건 공공 연하다 사실', 4),
#  ('경영 실패 재무 부실', 4),
#  ('공공 연하다 사실 상', 4),
#  ('국가 경쟁력 타격 받다', 4),
#  ('끝 지난해 매물 나오다', 4),
#  ('든 살리다 거 라는', 4),
#  ('료 올라가다 외항 사', 4),
#  ('매 각하 거나 출자전환', 4),
#  ('가깝다 수준', 4),
#  ('가깝다 수준 상승', 4),
#  ('가속 화 하고', 4),
#  ('각 작업 늦어지다', 4),
#  ('같다 기간 차', 4),
#  ('격 단계 하단', 4),
#  ('국가 별 락다운', 4),
#  ('금융 안정화 대책', 4),
#  ('기간 차 입금', 4),
#  ('내놓다 금융 안정화', 4),
#  ('대책 유동성 공급', 4),
#  ('각 작업 늦어지다 유상증자', 4),
#  ('같다 기간 차 입금', 4),
#  ('국가 별 락다운 완화', 4),
#  ('금융 안정화 대책 유동성', 4),
#  ('기간 차 입금 의존', 4),
#  ('내놓다 금융 안정화 대책', 4),
#  ('대책 유동성 공급 노력', 4),
#  ('더욱 가속 화 하고', 4),
#  ('돼다 정부 잇따르다 내놓다', 4),
#  ('래 최대 치르다 기록', 4),
#  ('가깝다 비용', 4),
#  ('간 접촉', 4),
#  ('간격 전체', 4),
#  ('가장 높다 등급', 4),
#  ('간 접촉 최소', 4),
#  ('감염 위험성 현저', 4),
#  ('개체 알려지다 비말', 4),
#  ('구역 별 탑승', 4),
#  ('노선 마스크 착용', 4),
#  ('대다 비율 혼합', 4),
#  ('들어오다 바닥 배출', 4),
#  ('막다 원 리다', 4),
#  ('막연하다 불안감 해소', 4),
#  ('간 접촉 최소 화', 4),
#  ('감염 위험성 현저 히', 4),
#  ('구역 별 탑승 존', 4),
#  ('매 개체 알려지다 비말', 4),
#  ('무균실 의학 실험실 활용', 4),
#  ('별 탑승 존 보딩', 4),
#  ('보딩 통한 승객 간', 4),
#  ('성분 제거 뒤 열', 4),
#  ('소독 외 구역 별', 4),
#  ('승객 간 접촉 최소', 4),
#  ('상법 개정안', 4),
#  ('특수 관계', 4),
#  ('가져가다 쉽다 구조', 4),
#  ('각각 내외 보유', 4),
#  ('경기 풀리다 난', 4),
#  ('고가 매수 요', 4),
#  ('구조 바뀌다 셈', 4),
#  ('기관 투자가 모이다', 4),
#  ('가져가다 쉽다 구조 바뀌다', 4),
#  ('고가 매수 요 구', 4),
#  ('그룹 회장 에게는 룰', 4),
#  ('매수 요 구 그린메일', 4),
#  ('법학 전문 대학원 명예', 4),
#  ('선 성균관대 학교 법학', 4),
#  ('성균관대 학교 법학 전문', 4),
#  ('쉽다 구조 바뀌다 셈', 4),
#  ('꼽히다 초 저', 4),
#  ('난 에도 최근', 4),
#  ('높다 신종 코로나바이러스', 4),
#  ('데 힘 입다', 4),
#  ('들다 대규모 유동성', 4),
#  ('경 영 난 에도', 4),
#  ('금리 시대 맞다 은행', 4),
#  ('꼽히다 초 저 금리', 4),
#  ('난 에도 최근 영화관', 4),
#  ('데 힘 입다 만만원', 4),
#  ('띄우다 요인 꼽히다 초', 4),
#  ('맞다 은행 예 적금', 4),
#  ('밀리다 들다 대규모 유동성', 4),
#  ('밖에 없다', 4),
#  ('공원 화 추진', 4),
#  ('그 땅콩 회항', 4),
#  ('기 내 식기', 4),
#  ('까지는 사실 상', 4),
#  ('내 식기 판', 4),
#  ('넓히다 그 땅콩', 4),
#  ('공원 화 추진 발표', 4),
#  ('권 분쟁 중인 조현아', 4),
#  ('그 땅콩 회항 사건', 4),
#  ('기 내 식기 판', 4),
#  ('넓히다 그 땅콩 회항', 4),
#  ('대한 의견 차이 커지다', 4),
#  ('디스 카운트 달리다 말', 4),
#  ('물러나다 뒤 지난해 조원태', 4),
#  ('보폭 넓히다 그 땅콩', 4),
#  ('사원 숙소 정석비행장 항공정비사', 4),
#  ('레저 개발', 4),
#  ('가격 추가 낮추다', 4),
#  ('각 협상 벌이다', 4),
#  ('건설 사 까지', 4),
#  ('높다 매년 억원', 4),
#  ('다만 신종 코로나바이러스', 4),
#  ('다시 매 각', 4),
#  ('더디다 상황 에서', 4),
#  ('가격 추가 낮추다 달라', 4),
#  ('높다 매년 억원 수준', 4),
#  ('다만 신종 코로나바이러스 감염증', 4),
#  ('다시 매 각 협상', 4),
#  ('더디다 상황 에서 팔리다', 4),
#  ('마무리 짓다 방침 이다', 4),
#  ('매 각 협상 벌이다', 4),
#  ('매년 억원 수준 순이익', 4),
#  ('방침 이다 다만 신종', 4),
#  ('부동산 인수합병 시장 대거', 4),
#  ('각각 상회', 4),
#  ('거래 대금 조억원', 4),
#  ('관건 되다 이라고', 4),
#  ('글로벌 지수 상승', 4),
#  ('당 기 순이익', 4),
#  ('당사 추 정치', 4),
#  ('대금 조억원 기록', 4),
#  ('대한항공 유상증자 및', 4),
#  ('되다 이라고 내다보다', 4),
#  ('드림 씨아이 에스', 4),
#  ('맡다 뿐 만', 4),
#  ('거래 대금 조억원 기록', 4),
#  ('관건 되다 이라고 내다보다', 4),
#  ('당사 추 정치 컨센서스', 4),
#  ('드림 씨아이 에스 굵직하다', 4),
#  ('맡다 뿐 만 아니다', 4),
#  ('바이오 파다 드림 씨아이', 4),
#  ('빅히트 엔터테인먼트 대한항공 유상증자', 4),
#  ('신종 코로나바이러스 감염증 인하다', 4),
#  ('엔터테인먼트 대한항공 유상증자 및', 4),
#  ('이뤄지다 있다 않다 불구', 4),
#  ('격 관리 시스템', 4),
#  ('고 주파 집', 4),
#  ('국내 판권 보유', 4),
#  ('그래픽 브랜드 국내', 4),
#  ('기계 인터페이스 원', 4),
#  ('기기 송수 신', 4),
#  ('기용 전력 증폭기', 4),
#  ('내다 평가 나오다', 4),
#  ('내셔널 지오 그래픽', 4),
#  ('단말 기용 전력', 4),
#  ('고 주파 집 속', 4),
#  ('그래픽 브랜드 국내 판권', 4),
#  ('기계 인터페이스 원 격', 4),
#  ('기용 전력 증폭기 무선통신', 4),
#  ('내셔널 지오 그래픽 브랜드', 4),
#  ('단말 기용 전력 증폭기', 4),
#  ('대한항공 보통주 추가 상장도', 4),
#  ('들어오다 앞서 일반 투자자', 4),
#  ('레이저 고 주파 집', 4),
#  ('만 들어오다 앞서 일반', 4),
#  ('각각 대한항공', 4),
#  ('각각 대한항공 억', 4),
#  ('거치다 단기간 내', 4),
#  ('군사 적 활용', 4),
#  ('단기간 내 도입', 4),
#  ('당국 우선 구매', 4),
#  ('대한항공 억 세', 4),
#  ('발전 속도 빠르다', 4),
#  ('빠르다 차 산업혁명', 4),
#  ('성우 엔지니어링 삼정', 4),
#  ('세 스위 성우', 4),
#  ('각각 대한항공 억 세', 4),
#  ('거치다 단기간 내 도입', 4),
#  ('군사 적 활용 성', 4),
#  ('당국 우선 구매 뒤', 4),
#  ('대한항공 억 세 스위', 4),
#  ('발전 속도 빠르다 차', 4),
#  ('성우 엔지니어링 삼정 솔루션', 4),
#  ('세 스위 성우 엔지니어링', 4),
#  ('속도 빠르다 차 산업혁명', 4),
#  ('스위 성우 엔지니어링 삼정', 4),
#  ('가지다 비다 펀드', 4),
#  ('같이 위태 워', 4),
#  ('국내외 사용자 에게', 4),
#  ('기다 내 걸다', 4),
#  ('내 걸다 갈수록', 4),
#  ('네 다른 한쪽', 4),
#  ('니 픽처스 합작', 4),
#  ('대신 새롭다 투자자', 4),
#  ('라이벌 이어서 뒷맛', 4),
#  ('가지다 비다 펀드 매력', 4),
#  ('같이 위태 워 지는', 4),
#  ('기다 내 걸다 갈수록', 4),
#  ('라이벌 이어서 뒷맛 개다', 4),
#  ('마땅찮다 네 다른 한쪽', 4),
#  ('맞다 연간 수천 억원', 4),
#  ('부분 메우다 범 동아시아', 4),
#  ('블룸버그 통신 보도 후', 4),
#  ('비다 펀드 매력 느끼다', 4),
#  ('소 니 픽처스 합작', 4),
#  ('끌다 올리다', 4),
#  ('기내 면세', 4),
#  ('가열 각종 기술', 4),
#  ('강서 본사 인근', 4),
#  ('건 손실 보지', 4),
#  ('관련 산업 가치', 4),
#  ('구조조정 일자리 잃다', 4),
#  ('금액 배 넘다', 4),
#  ('껌 초콜릿 캔디', 4),
#  ('내 내비 치고', 4),
#  ('내다 관련 산업', 4),
#  ('내다 관련 산업 가치', 4),
#  ('네 모 파트너 즈', 4),
#  ('들이다 현금 창 추다', 4),
#  ('모집 금액 배 넘다', 4),
#  ('벌다 들이다 현금 창', 4),
#  ('사정 좋아지다 언제 든', 4),
#  ('생존권 달리다 문제 보고', 4),
#  ('선배 이자 소니코리아 활약', 4),
#  ('속 내 내비 치고', 4),
#  ('시너지 내다 관련 산업', 4),
#  ('가늠 케', 4),
#  ('가량 소요', 4),
#  ('유지 지', 4),
#  ('각 국제항 공', 4),
#  ('간 현실 화', 4),
#  ('객실 운항 승무원', 4),
#  ('곤 대 단위', 4),
#  ('교수 객실 운항', 4),
#  ('구조조 정시 마땅하다', 4),
#  ('국제항 공 기관', 4),
#  ('나 언 젠', 4),
#  ('년 가량 소요', 4),
#  ('각 국제항 공 기관', 4),
#  ('객실 운항 승무원 특수', 4),
#  ('곤 대 단위 정리해고', 4),
#  ('교수 객실 운항 승무원', 4),
#  ('구조조 정시 마땅하다 새', 4),
#  ('나 언 젠 간', 4),
#  ('대 단위 정리해고 나타나다', 4),
#  ('더 더군다나 각 국제항', 4),
#  ('더군다나 각 국제항 공', 4),
#  ('기회 잡다 개인', 4),
#  ('높다 초 저', 4),
#  ('다 김진성 기자', 4),
#  ('떨어뜨리다 목표 다', 4),
#  ('띄우다 요인 꼽히다', 4),
#  ('목표 다 김진성', 4),
#  ('및 우리 사주', 4),
#  ('높다 초 저 금리', 4),
#  ('떨어뜨리다 목표 다 김진성', 4),
#  ('목표 다 김진성 기자', 4),
#  ('및 우리 사주 조합', 4),
#  ('분위기 띄우다 요인 꼽히다', 4),
#  ('비율 수준 떨어뜨리다 목표', 4),
#  ('사들이다 기회 잡다 개인', 4),
#  ('수준 떨어뜨리다 목표 다', 4),
#  ('안 팔리다 실권 주', 4),
#  ('가속 화하다', 4),
#  ('규제 완화', 4),
#  ('가속 화하다 팬암', 4),
#  ('개편 활발하다 이뤄지다', 4),
#  ('거리 짧다 취항', 4),
#  ('과의 차별성 고려', 4),
#  ('관광 인프라스트럭처 함께', 4),
#  ('구조 개편 활발하다', 4),
#  ('급 급하다 위기', 4),
#  ('급하다 위기 근본', 4),
#  ('까지는 비행기 띄우다', 4),
#  ('내기 쉽다 특정', 4),
#  ('가속 화하다 팬암 이스턴', 4),
#  ('개편 활발하다 이뤄지다 황용', 4),
#  ('거리 짧다 취항 자유롭다', 4),
#  ('구조 개편 활발하다 이뤄지다', 4),
#  ('급 급하다 위기 근본', 4),
#  ('까지는 비행기 띄우다 돈', 4),
#  ('노스웨스트항공 웨스턴 에어라인 인수', 4),
#  ('델타항공 노스웨스트항공 웨스턴 에어라인', 4),
#  ('불매운동 벌어지다 전 전체', 4),
#  ('비행 거리 짧다 취항', 4),
#  ('감 느끼다 수', 4),
#  ('게 아니다 관측', 4),
#  ('관측 우세하다 앞서', 4),
#  ('달 초 일반', 4),
#  ('사용 처 알', 4),
#  ('아니다 관측 우세하다', 4),
#  ('아무 조치 취하', 4),
#  ('게 아니다 관측 우세하다', 4),
#  ('아니다 관측 우세하다 앞서', 4),
#  ('이어서 사용 처 알', 4),
#  ('측 아무 조치 취하', 4),
#  ('나선 게 아니다 관측', 4),
#  ('달 초 일반 공모', 4),
#  ('감감 무소식 인', 4),
#  ('개 월간 고용', 4),
#  ('검토 의견 함께', 4),
#  ('기내식 사업 및', 4),
#  ('김 유혁 한화', 4),
#  ('꿈틀 거 린다', 4),
#  ('달이다 간의 개점휴업', 4),
#  ('두 달이다 간의', 4),
#  ('또 기내식 사업', 4),
#  ('기내식 사업 및 유', 4),
#  ('김 유혁 한화 투자', 4),
#  ('두 달이다 간의 개점휴업', 4),
#  ('또 기내식 사업 및', 4),
#  ('사업 및 유 휴', 4),
#  ('수가 전 년 보다', 4),
#  ('수송 수요 증가 흑자', 4),
#  ('수요 증가 흑자 전환', 4),
#  ('시작 지다 보름 지나다', 4),
#  ('액 최소 가다 주식', 4),
#  ('가운데 그동안', 4),
#  ('가팔랐다 현대차', 4),
#  ('감주 회복', 4),
#  ('개월 만에', 4),
#  ('거래소 따르다', 4),
#  ('경 기민', 4),
#  ('가운데 그동안 시장', 4),
#  ('가팔랐다 현대차 일주일', 4),
#  ('감주 회복 조짐', 4),
#  ('같다 기간 기아차', 4),
#  ('개월 만에 선', 4),
#  ('거래소 따르다 엔씨소프트', 4),
#  ('게 티 이미지', 4),
#  ('경 기민 감주', 4),
#  ('구조조정 진행 돼다', 4),
#  ('국방 호텔 레저', 4),
#  ('가운데 그동안 시장 이끌다', 4),
#  ('개월 만에 선 돌파', 4),
#  ('게 티 이미지 뱅크', 4),
#  ('경 기민 감주 회복', 4),
#  ('구조조정 진행 돼다 의미', 4),
#  ('기민 감주 회복 조짐', 4),
#  ('기업 이익 추 정치', 4),
#  ('김수연 한화 투자 증권', 4),
#  ('돌파 가운데 그동안 시장', 4),
#  ('만에 선 돌파 가운데', 4),
#  ('쏘다 카', 4),
#  ('가하다 새롭다 자유여행', 4),
#  ('건별 만원 이상', 4),
#  ('계획 없다 달', 4),
#  ('공항 라운지 연', 4),
#  ('나 에게 필요하다', 4),
#  ('내놓다 가하다 새롭다', 4),
#  ('농협 밉다 플러스', 4),
#  ('대한항공 천 백원', 4),
#  ('덧붙이다 장은영 기자', 4),
#  ('라고 덧붙이다 장은영', 4),
#  ('가하다 새롭다 자유여행 패스', 4),
#  ('계획 없다 달 에는', 4),
#  ('공항 라운지 연 회', 4),
#  ('내놓다 가하다 새롭다 자유여행', 4),
#  ('라고 덧붙이다 장은영 기자', 4),
#  ('라운지 연 회 무료', 4),
#  ('무료 입장 유니온 페이', 4),
#  ('새롭다 자유여행 패스 출시', 4),
#  ('연 회 무료 입장', 4),
#  ('이벤트 내놓다 가하다 새롭다', 4),
#  ('가다 되다', 4),
#  ('격렬하다 공세', 4),
#  ('워런 트', 4),
#  ('격렬하다 공세 펼치다', 4),
#  ('경 영 위기', 4),
#  ('돈 빌리다 보고', 4),
#  ('부사 장 으로부터', 4),
#  ('사채 발행 바', 4),
#  ('신주 전체 주식', 4),
#  ('경 영 위기 유상증자', 4),
#  ('부 사채 발행 바', 4),
#  ('신주 전체 주식 인', 4),
#  ('영 위기 유상증자 참여', 4),
#  ('월 주주총회 이후 잠잠하다', 4),
#  ('좀더 필요하다 경진 기자', 4),
#  ('지난 월 주주총회 이후', 4),
#  ('건설 조현아 전 대한항공', 4),
#  ('대출 받다', 4),
#  ('감 느끼다 라며', 4),
#  ('기간 내년 월일', 4),
#  ('내년 월일 까지로', 4),
#  ('대 상회사 대한', 4),
#  ('계약 기간 내년 월일', 4),
#  ('기간 내년 월일 까지로', 4),
#  ('내년 월일 까지로 년', 4),
#  ('대 상회사 대한 지배', 4),
#  ('비율 다 계약 기간', 4),
#  ('상회사 대한 지배 력', 4),
#  ('알 수 없다 입장', 4),
#  ('더 벌어지다', 4),
#  ('바람직하다 지배구조 정립', 4),
#  ('건설 구성', 4),
#  ('규모 발행', 4),
#  ('기자 조원태', 4),
#  ('년년 월', 4),
#  ('규모 발행 바', 4),
#  ('년년 월 일이', 4),
#  ('다한 진칼 측', 4),
#  ('만기 년년 월', 4),
#  ('며 만기 년년', 4),
#  ('명호 기자 조원태', 4),
#  ('년년 월 일이 다한', 4),
#  ('다한 진칼 측 개인', 4),
#  ('만기 년년 월 일이', 4),
#  ('며 만기 년년 월', 4),
#  ('밝히다 하지만 업계 에서는', 4),
#  ('방침 이다 거래소 상장', 4),
#  ('없다 밝히다 하지만 업계', 4),
#  ('가격 시가', 4),
#  ('개인 지', 4),
#  ('가격 시가 보다', 4),
#  ('개인 지 분', 4),
#  ('고 있다 연합', 4),
#  ('대량 보유 상황', 4),
#  ('가격 시가 보다 높다', 4),
#  ('계약 기간 내년 월', 4),
#  ('농협 은행 으로부터 자신', 4),
#  ('대량 보유 상황 보고서', 4),
#  ('대한항공 부사 장 대응', 4),
#  ('대해 개인 지 분', 4),
#  ('매입 가격 시가 보다', 4),
#  ('계 증권', 4),
#  ('월 서울 여의도', 4),
#  ('이며 이르다 위해', 4),
#  ('이익 공유 차원', 4),
#  ('조성 목표 괴리될', 4),
#  ('조억원 이며 이르다', 4),
#  ('조절 전환사채 신주인수권', 4),
#  ('협회 회원 사', 4),
#  ('형평성 논란 생기다', 4),
#  ('조억원 이며 이르다 위해', 4),
#  ('간 협약 체결 조속', 4),
#  ('계획 이다 김형석 기자', 4),
#  ('국선 주 협회 회원', 4),
#  ('당초 조성 목표 괴리될', 4),
#  ('성수 금융 위원장 이동걸', 4),
#  ('당 만원 최대', 4),
#  ('분쟁 재 점화', 4),
#  ('사이 또 다시', 4),
#  ('원대 유상증자 추진', 4),
#  ('재 점화 하고', 4),
#  ('분쟁 재 점화 하고', 4),
#  ('주 당 만원 최대', 4),
#  ('권 분쟁 재 점화', 4),
#  ('맞다 대응 보이다 양', 4),
#  ('사이 또 다시 경영', 4),
#  ('간 결합', 4),
#  ('지난해 월', 4),
#  ('간 결합 주목', 4),
#  ('거 세다 후', 4),
#  ('격화 사면초가 처', 4),
#  ('경쟁 벌 이던', 4),
#  ('계약서 에서 합의', 4),
#  ('국가 명단 제외', 4),
#  ('국내선 운항 재개', 4),
#  ('규모 경제 달성', 4),
#  ('금지 홍콩 시위', 4),
#  ('거 세다 후 폭풍', 4),
#  ('경쟁 벌 이던 당시', 4),
#  ('계약서 에서 합의 바', 4),
#  ('국내선 운항 재개 순환', 4),
#  ('금지 홍콩 시위 격화', 4),
#  ('깎다 먹기 경쟁 벌', 4),
#  ('대량 해고 가능성 제기', 4),
#  ('들다 일제 히 적자', 4),
#  ('먹기 경쟁 벌 이던', 4),
#  ('공개 매수 다', 4),
#  ('권 방어 나선', 4),
#  ('그리고 조현아 전', 4),
#  ('농협 은행 에서', 4),
#  ('대한 언급 없다', 4),
#  ('레이더 강 성부', 4),
#  ('만원 공개 매수', 4),
#  ('경영 권 방어 나선', 4),
#  ('공개 매수 다 고', 4),
#  ('권 방어 나선 조원태', 4),
#  ('그리고 조현아 전 대한항공', 4),
#  ('대한항공 부사 장 구성', 4),
#  ('레이더 강 성부 펀드', 4),
#  ('만원 공개 매수 다', 4),
#  ('이미 청약 직접 참여', 4),
#  ('가지다 투자자', 4),
#  ('값 매수', 4),
#  ('같다 수의', 4),
#  ('개선 되다', 4),
#  ('가지다 투자자 새', 4),
#  ('같다 수의 본', 4),
#  ('걸 맞다 바람직하다', 4),
#  ('공시 통해 날', 4),
#  ('기준 새롭다 취득', 4),
#  ('대비 약 웃돈', 4),
#  ('더 많다 우호', 4),
#  ('델타항공 외 더', 4),
#  ('두다 값 매수', 4),
#  ('걸 맞다 바람직하다 지배구조', 4),
#  ('공시 통해 날 부터', 4),
#  ('대비 약 웃돈 얹다', 4),
#  ('더 많다 우호 세력', 4),
#  ('델타항공 외 더 많다', 4),
#  ('많다 우호 세력 끌다', 4),
#  ('맞다 바람직하다 지배구조 정립', 4),
#  ('미국 델타항공 외 더', 4),
#  ('방어 어려움 겪다 전망', 4),
#  ('가능하다 신주', 4),
#  ('공 유상증자', 4),
#  ('거래소 상장 돼다', 4),
#  ('기간 날 부터', 4),
#  ('높다 기간 날', 4),
#  ('대비 높다 기간', 4),
#  ('기간 날 부터 다음', 4),
#  ('높다 기간 날 부터', 4),
#  ('대비 높다 기간 날', 4),
#  ('빌딩 모습 사진 김휘선', 4),
#  ('월 정기 주주총회 에서는', 4),
#  ('가다 결실', 4),
#  ('거두다 못', 4),
#  ('거래 종결', 4),
#  ('결국 파산', 4),
#  ('가다 결실 거두다', 4),
#  ('거두다 못 대해', 4),
#  ('거래 종결 기한', 4),
#  ('결국 파산 수순', 4),
#  ('결실 거두다 못', 4),
#  ('금은 티웨이 나', 4),
#  ('기한 도과 인하다', 4),
#  ('대해 안타깝다 말', 4),
#  ('도과 인하다 기', 4),
#  ('가다 결실 거두다 못', 4),
#  ('거두다 못 대해 안타깝다', 4),
#  ('거래 종결 기한 도과', 4),
#  ('결국 파산 수순 밟다', 4),
#  ('결실 거두다 못 대해', 4),
#  ('금은 티웨이 나 에어부산', 4),
#  ('기간산업 안정 기금 아시아나', 4),
#  ('기한 도과 인하다 기', 4),
#  ('도과 인하다 기 체결', 4),
#  ('명 직원 이다 지난', 4),
#  ('분 희다 석화 방지', 4),
#  ('데리 후데 오카', 4),
#  ('데리 후데 오카 토마토', 4),
#  ('가다 나오다', 4),
#  ('두 회사', 4),
#  ('가다 나오다 이번', 4),
#  ('나오다 이번 처음', 4),
#  ('대다 전국 여', 4),
#  ('또 두 회사', 4),
#  ('만여 대다 전국', 4),
#  ('사업 유통업 계', 4),
#  ('산업 으로까지 빠르다', 4),
#  ('가다 나오다 이번 처음', 4),
#  ('대다 전국 여 곳', 4),
#  ('만여 대다 전국 여', 4),
#  ('상업 표시 신용카드 내놓다', 4),
#  ('전용 상업 표시 신용카드', 4),
#  ('차량 만여 대다 전국', 4),
#  ('계 넘다 항공 외식', 4),
#  ('간의 컬래버레이션', 4),
#  ('간의 컬래버레이션 기대하다', 4),
#  ('구축 해오다 국내', 4),
#  ('기반 업종 경계', 4),
#  ('난 새 기자', 4),
#  ('다빈 난 새', 4),
#  ('데이터 보다 용이하다', 4),
#  ('라인업 기반 업종', 4),
#  ('맞추다 파격 적', 4),
#  ('보다 용이하다 확보', 4),
#  ('구축 해오다 국내 카셰어링', 4),
#  ('다빈 난 새 기자', 4),
#  ('데이터 보다 용이하다 확보', 4),
#  ('라인업 기반 업종 경계', 4),
#  ('상품 설계 비용 수익', 4),
#  ('이종 간의 컬래버레이션 기대하다', 4),
#  ('초점 맞추다 파격 적', 4),
#  ('현재 전국 여 곳', 4),
#  ('그렇다 법적 책임', 4),
#  ('노선 만들다 지역', 4),
#  ('녹음 녹취 까지', 4),
#  ('대책 묻다 지방자치단체', 4),
#  ('때 라는 입장', 4),
#  ('라는 입장 밝히다', 4),
#  ('라디오 패 트롤', 4),
#  ('만들다 지역 경제', 4),
#  ('보다 자금지원 수요', 4),
#  ('부리다 고용 승계', 4),
#  ('노선 만들다 지역 경제', 4),
#  ('때 라는 입장 밝히다', 4),
#  ('라디오 패 트롤 전북', 4),
#  ('만들다 지역 경제 기여', 4),
#  ('보다 자금지원 수요 파악', 4),
#  ('상황 보다 자금지원 수요', 4),
#  ('스타 홀딩스 통해 보유', 4),
#  ('억지 부리다 고용 승계', 4),
#  ('열리다 산업 통상 자원', 4),
#  ('일가 스타 홀딩스 통해', 4),
#  ('맞춤 형', 4),
#  ('대한항공 스타벅스 배달', 4),
#  ('마케팅 대한 파트너', 4),
#  ('방식 브랜드 콜라보레이션', 4),
#  ('브랜드 콜라보레이션 진행', 4),
#  ('사이언스 역량 기반', 4),
#  ('새롭다 방식 브랜드', 4),
#  ('대한항공 스타벅스 배달 민족', 4),
#  ('방식 브랜드 콜라보레이션 진행', 4),
#  ('새롭다 방식 브랜드 콜라보레이션', 4),
#  ('운영 마케팅 대한 파트너', 4),
#  ('이번 엔 모빌리티 플랫폼', 4),
#  ('파트너 십 계약 체결', 4),
#  ('개발 하고 새롭다 방식', 4),
#  ('분 현재 주가', 4),
#  ('업그레이드 통해 더욱 풍부하다', 4),
#  ('엠로보 개발 증권 뉴스', 4),
#  ('국내 에서는 주요', 4),
#  ('그동안 없다 전해지다', 4),
#  ('대표 주도하다 알려지다', 4),
#  ('더 크게 벌리다', 4),
#  ('동원 사례 그동안', 4),
#  ('라는 방식 동원', 4),
#  ('반격 가하다 볼', 4),
#  ('방식 동원 사례', 4),
#  ('국내 에서는 주요 기업', 4),
#  ('그동안 없다 전해지다 김도형', 4),
#  ('대표 주도하다 알려지다 국내', 4),
#  ('동원 사례 그동안 없다', 4),
#  ('라는 방식 동원 사례', 4),
#  ('방식 동원 사례 그동안', 4),
#  ('사례 그동안 없다 전해지다', 4),
#  ('시도 반격 가하다 볼', 4),
#  ('각 보관장 소로', 4),
#  ('경우 대다 대로', 4),
#  ('고속버스 짐칸 작다', 4),
#  ('고유 표 식이', 4),
#  ('군 분 투하', 4),
#  ('그물 비닐 단단하다', 4),
#  ('금속 납작하다 판', 4),
#  ('금지 품목 마약', 4),
#  ('까지만 해도 고속버스', 4),
#  ('군 분 투하 업종', 4),
#  ('그물 비닐 단단하다 고정', 4),
#  ('금지 품목 마약 류', 4),
#  ('까지만 해도 고속버스 짐칸', 4),
#  ('동남아 일본 미주 유럽', 4),
#  ('바코드 찍다 드롭 버튼', 4),
#  ('신경 쓸다 정도 세심', 4),
#  ('에어 웨이 빌다 부착', 4),
#  ('여기 서 더 나아가다', 4),
#  ('결과 보다', 4),
#  ('높이다 반면 조선', 4),
#  ('늘다 송 채경', 4),
#  ('대한항공 및 한진', 4),
#  ('및 한진 호텔', 4),
#  ('반면 조선 기계', 4),
#  ('보유 상장 사이', 4),
#  ('비중 높이다 반면', 4),
#  ('산업 지형 변화', 4),
#  ('상장 사이 며', 4),
#  ('송 채경 화', 4),
#  ('높이다 반면 조선 기계', 4),
#  ('늘다 송 채경 화', 4),
#  ('대한항공 및 한진 호텔', 4),
#  ('및 한진 호텔 신라', 4),
#  ('보유 상장 사이 며', 4),
#  ('비중 높이다 반면 조선', 4),
#  ('송 채경 화 기자', 4),
#  ('인하다 산업 지형 변화', 4),
#  ('기계 설비 제조업 항공', 4),
#  ('달라지다 나타나다 비대 면', 4),
#  ('각국 강력하다 경', 4),
#  ('강력하다 경 기', 4),
#  ('개 기관 투자가', 4),
#  ('경 기 부양책', 4),
#  ('광물 자원 공사', 4),
#  ('김준용 투자 증권', 4),
#  ('께 대한항공 동', 4),
#  ('다정 부채 나', 4),
#  ('담보 부증 권', 4),
#  ('대 캐피탈 다수', 4),
#  ('각국 강력하다 경 기', 4),
#  ('강력하다 경 기 부양책', 4),
#  ('께 대한항공 동 양', 4),
#  ('담보 부증 권 통해', 4),
#  ('대한항공 동 양 생명', 4),
#  ('동 양 생명 광물', 4),
#  ('따르다 위험 자산 회피', 4),
#  ('리스크 매우 적다 언급', 4),
#  ('변동성 확대 불리하다 환경', 4),
#  ('관련 정보기술', 4),
#  ('기계 설비', 4),
#  ('게임 즈 경우', 4),
#  ('경우 올해 들다', 4),
#  ('관련 정보기술 미래', 4),
#  ('높이다 제조업 항공', 4),
#  ('더블유 게임 즈', 4),
#  ('바구니 새롭다 담기다', 4),
#  ('비중 높이다 제조업', 4),
#  ('사이트 스코어 따르다', 4),
#  ('사태 직격탄 맞다', 4),
#  ('소재 순 상승', 4),
#  ('게임 즈 경우 올해', 4),
#  ('경우 올해 들다 확보', 4),
#  ('관련 정보기술 미래 모빌리티', 4),
#  ('높이다 제조업 항공 유통', 4),
#  ('더블유 게임 즈 경우', 4),
#  ('비중 높이다 제조업 항공', 4),
#  ('사이트 스코어 따르다 지난', 4),
#  ('에너지 솔루션 성광벤드 애경', 4),
#  ('우선 순위도 달라지다 조사', 4),
#  ('즈 경우 올해 들다', 4),
#  ('강화하다 계획', 4),
#  ('고객 신뢰', 4),
#  ('고객 신뢰 다시', 4),
#  ('년 대다 초반', 4),
#  ('대다 초반 부터', 4),
#  ('만의 소비자 같다', 4),
#  ('목소리 프랑스 만의', 4),
#  ('발전 시키다 오다', 4),
#  ('상의 위법 사항', 4),
#  ('수 입사 최근', 4),
#  ('신뢰 다시 얻다', 4),
#  ('아우르다 전 세계', 4),
#  ('고객 신뢰 다시 얻다', 4),
#  ('년 대다 초반 부터', 4),
#  ('목소리 프랑스 만의 소비자', 4),
#  ('상의 위법 사항 발견', 4),
#  ('수 입사 최근 변경', 4),
#  ('여성 목소리 프랑스 만의', 4),
#  ('위 여성 목소리 프랑스', 4),
#  ('지구 위 여성 목소리', 4),
#  ('프랑스 만의 소비자 같다', 4),
#  ('허위 품목 신고 적발', 4),
#  ('가량 급등 반면', 4),
#  ('경 영 체제', 4),
#  ('공백 만회 하고도', 4),
#  ('그렇다 날 기준', 4),
#  ('기다 힘드다 상황', 4),
#  ('기자 안다 베스트', 4),
#  ('나르다 모습 장련성', 4),
#  ('대비 가량 급등', 4),
#  ('동남아 지역 해외', 4),
#  ('만회 하고도 남다', 4),
#  ('공백 만회 하고도 남다', 4),
#  ('나르다 모습 장련성 기자', 4),
#  ('대비 가량 급등 반면', 4),
#  ('동남아 지역 해외 본부', 4),
#  ('모습 장련성 기자 안다', 4),
#  ('비상 경 영 체제', 4),
#  ('싣다 나르다 모습 장련성', 4),
#  ('여기 인건비 유류 비', 4),
#  ('위 뾰족 수 찾다', 4),
#  ('위해 유럽 동남아 지역', 4),
#  ('가격 차이', 4),
#  ('가능하다 다', 4),
#  ('개국 오픈', 4),
#  ('개념 벗어나다', 4),
#  ('가격 차이 확인', 4),
#  ('가능하다 다 채', 4),
#  ('계 가능하다 다', 4),
#  ('과는 차별 화', 4),
#  ('기점 약 개국', 4),
#  ('다 채 로운', 4),
#  ('대한 내용 공개', 4),
#  ('메신저 활용 커뮤니티', 4),
#  ('모델 접목 시키다', 4),
#  ('가능하다 다 채 로운', 4),
#  ('계 가능하다 다 채', 4),
#  ('기점 약 개국 오픈', 4),
#  ('및 중동 기점 약', 4),
#  ('비즈니스 모델 접목 시키다', 4),
#  ('아시아 및 중동 기점', 4),
#  ('연 계 가능하다 다', 4),
#  ('영어 중국어 한국어 우선', 4),
#  ('웹 모바일 앱 기본', 4),
#  ('기간 일이 순차', 4),
#  ('기대하다 어렵다 당장', 4),
#  ('나선 저비용항공사 내달', 4),
#  ('늘다 연내 대형', 4),
#  ('만큼 정도 자구', 4),
#  ('모으다 황용 식', 4),
#  ('구 주 유럽 동남아', 4),
#  ('기대하다 어렵다 당장 국토교통부', 4),
#  ('만큼 정도 자구 책', 4),
#  ('모으다 황용 식 세종대', 4),
#  ('밝히다 유 제 훈', 4),
#  ('상 취업 조차 쉬다', 4),
#  ('실제 국제항 공 운송', 4),
#  ('가량 앞서다 조만간', 4),
#  ('각국 지점 관리', 4),
#  ('기 빠지다 가운데', 4),
#  ('나오다 이유 다', 4),
#  ('눈길 끌 고', 4),
#  ('당초 신청 지연', 4),
#  ('두다 판단 해석', 4),
#  ('발상 아이디어 역시', 4),
#  ('발상 아이디어 역시 유', 4),
#  ('본사 각국 지점 관리', 4),
#  ('수송량 최소 이상 늘어나다', 4),
#  ('아이디어 역시 유 휴', 4),
#  ('얘기 나오다 이유 다', 4),
#  ('역 발상 아이디어 역시', 4),
#  ('열다 두다 판단 해석', 4),
#  ('자구 책 일환 이지만', 4),
#  ('최소 이상 늘어나다 이르다', 4),
#  ('주 회', 4),
#  ('휴가 철', 4),
#  ('여름 휴가', 4),
#  ('강화 조치 지속', 4),
#  ('검토 중이 며', 4),
#  ('까지는 시간 걸리다', 4),
#  ('댈러스 오스트리아 빈', 4),
#  ('로스앤젤레스 샌프란시스코 애틀랜타', 4),
#  ('베트남 하노이 호치민', 4),
#  ('비다 더 크게', 4),
#  ('선제 적 확보', 4),
#  ('신종 코로나바이러스 감염증', 4),
#  ('베트남 하노이 호치민 증편', 4),
#  ('워싱턴 로스앤젤레스 샌프란시스코 애틀랜타', 4),
#  ('국 에게 한국 포함', 4),
#  ('따르다 특히 월 이후', 4),
#  ('런던 베트남 하노이 호치민', 4),
#  ('로스앤젤레스 샌프란시스코 애틀랜타 및', 4),
#  ('미주 노선도 날개 펴다', 4),
#  ('비다 더 크게 확대', 4),
#  ('샌프란시스코 애틀랜타 및 프랑스', 4),
#  ('경쟁 나서다', 4),
#  ('내용 공동 제작', 4),
#  ('다양하다 혜택 담기다', 4),
#  ('대면 접촉 최소', 4),
#  ('라는 제목 분', 4),
#  ('메 얼리다 버드', 4),
#  ('모바일 웹 앱', 4),
#  ('부산 브랜드 페스', 4),
#  ('분 분량 애니메이션', 4),
#  ('분량 애니메이션 공항', 4),
#  ('대면 접촉 최소 화하다', 4),
#  ('라는 제목 분 분량', 4),
#  ('부산 브랜드 페스 타', 4),
#  ('분 분량 애니메이션 공항', 4),
#  ('살아나다 기미 보이지 않다', 4),
#  ('셀프 체크 인 기내', 4),
#  ('스타얼라이언스 원월드 세계 대다', 4),
#  ('안전하다 내용 공동 제작', 4),
#  ('열리다 부산 브랜드 페스', 4),
#  ('우선 삼성 카드 하나카드', 4),
#  ('발행 가액', 4),
#  ('마는 다양하다 하이테크', 4),
#  ('하이테크 기술 통해 언택트', 4),
#  ('값 오르다', 4),
#  ('강남 송파구', 4),
#  ('개미 상승', 4),
#  ('고번 지는', 4),
#  ('곡 소리', 4),
#  ('공포 정책', 4),
#  ('과학 석유', 4),
#  ('괴물 유닛', 4),
#  ('국제 방역', 4),
#  ('국회 통째', 4),
#  ('강남 송파구 제멋대로', 4),
#  ('고번 지는 수돗물', 4),
#  ('곡 소리 그린', 4),
#  ('과학 석유 희망', 4),
#  ('괴물 유닛 다섯', 4),
#  ('국제 방역 부실', 4),
#  ('국회 통째 세종', 4),
#  ('그린 뉴딜 깜짝', 4),
#  ('금융 하나은행 조', 4),
#  ('기 료 연료비', 4),
#  ('고번 지는 수돗물 공포', 4),
#  ('곡 소리 그린 뉴딜', 4),
#  ('과학 석유 희망 싣다', 4),
#  ('괴물 유닛 다섯 벨벳', 4),
#  ('국제 방역 부실 지지율', 4),
#  ('국회 통째 세종 가야', 4),
#  ('그린 뉴딜 깜짝 실적', 4),
#  ('금융 하나은행 조 생체인증', 4),
#  ('기 료 연료비 연동제', 4),
#  ('기획 콩값 뛰다 두부', 4),
#  ('가능성 커지다 카드', 4),
#  ('결정 짓다 여름', 4),
#  ('경남 일대 연고', 4),
#  ('국가 별 지점', 4),
#  ('금 억억원 해결', 4),
#  ('급 금 억억원', 4),
#  ('가능성 커지다 카드 사', 4),
#  ('경남 일대 연고 두다', 4),
#  ('금 억억원 해결 요구', 4),
#  ('급 금 억억원 해결', 4),
#  ('농사 결정 짓다 여름', 4),
#  ('더 크다 타격 입다', 4),
#  ('료 임금 등를 충당', 4),
#  ('리스 료 임금 등를', 4),
#  ('개선 흐름 보이다', 4),
#  ('검토 대상 올리다', 4),
#  ('결론 내 리기', 4),
#  ('경기 불확실 성과', 4),
#  ('관심 집중 되어다', 4),
#  ('글로벌 경기 불확실', 4),
#  ('금융투자 자산 분', 4),
#  ('김상만 하나 금융투자', 4),
#  ('까지 주로 이뤄지다', 4),
#  ('대상 올리다 나신', 4),
#  ('검토 대상 올리다 나신', 4),
#  ('경기 불확실 성과 개별', 4),
#  ('글로벌 경기 불확실 성과', 4),
#  ('금융투자 자산 분 석', 4),
#  ('김상만 하나 금융투자 자산', 4),
#  ('식 이번 사이클 넘기다', 4),
#  ('여부 관심 집중 되어다', 4),
#  ('월말 까지 주로 이뤄지다', 4),
#  ('최종 판정 내다 야하다', 4),
#  ('추정 치다 지난달 말', 4),
#  ('간다 작년 에는', 4),
#  ('거의 찾기 어렵다', 4),
#  ('고개 끄덕이다 베이가', 4),
#  ('관심 부탁드리다 동아닷컴', 4),
#  ('기본 연회 비도', 4),
#  ('단어 다소 생소하다', 4),
#  ('대의 매출 액', 4),
#  ('든 가격 바뀌다', 4),
#  ('라는 단어 다소', 4),
#  ('간다 작년 에는 회식', 4),
#  ('기본 연회 비도 적다', 4),
#  ('기아차 정유 칼텍스 우아하다', 4),
#  ('라는 단어 다소 생소하다', 4),
#  ('몇 번의 인증 절차', 4),
#  ('문화 익숙하다 세대 유입', 4),
#  ('볼링 요리 참여 프로그램', 4),
#  ('언제 든 가격 바뀌다', 4),
#  ('에는 회식 볼링 요리', 4),
#  ('연회 비도 적다 실제', 4),
#  ('개조 나선', 4),
#  ('공급 달린다', 4),
#  ('개조 나선 이유', 4),
#  ('계획 이라고 말', 4),
#  ('국토교통부 승인 거치다', 4),
#  ('그 대신 한국', 4),
#  ('개편 나서다 분석 이다', 4),
#  ('그 대신 한국 본사', 4),
#  ('나서다 분석 이다 일', 4),
#  ('반도체 이상 더 적재', 4),
#  ('방역 용품 반도체 이상', 4),
#  ('관계자 보잉', 4),
#  ('거치다 월 운항', 4),
#  ('관계자 보잉 국토부', 4),
#  ('구체 적 인', 4),
#  ('따르다 오다 분기', 4),
#  ('보잉 국토부 승인', 4),
#  ('거치다 월 운항 목표', 4),
#  ('관계자 보잉 국토부 승인', 4),
#  ('구체 적 인 세부', 4),
#  ('보잉 국토부 승인 거치다', 4),
#  ('슬림화 통한 운영 효율', 4),
#  ('공급 부족 인하다', 4),
#  ('깜짝 흑자 내다', 4),
#  ('내다 추정 하고', 4),
#  ('공급 부족 인하다 운임', 4),
#  ('림화 차원 이라고 설명', 4),
#  ('반도체 실으 면 최소', 4),
#  ('방역 용품 반도체 실으', 4),
#  ('거치다 월 중', 4),
#  ('높이다 신종 코로나바이러스', 4),
#  ('도쿄 곳 에서만', 4),
#  ('라고 밝히다 앞서', 4),
#  ('거치다 월 중 운항', 4),
#  ('높이다 신종 코로나바이러스 감염증', 4),
#  ('보잉 허가 국토부 승인', 4),
#  ('사인 보잉 허가 국토부', 4),
#  ('성 높이다 신종 코로나바이러스', 4),
#  ('성장 세 보이다 때문', 4),
#  ('가방 뜻', 4),
#  ('곳 해외', 4),
#  ('간 협의 통해', 4),
#  ('기존 보다 폭넓다', 4),
#  ('또쿄 곳 해외', 4),
#  ('베이징 일본 또쿄', 4),
#  ('별도 가방 뜻', 4),
#  ('보다 폭넓다 인정', 4),
#  ('간 협의 통해 월', 4),
#  ('기존 보다 폭넓다 인정', 4),
#  ('베이징 일본 또쿄 곳', 4),
#  ('슬 림화 차원 이라', 4),
#  ('일본 또쿄 곳 해외', 4),
#  ('중국 베이징 일본 또쿄', 4),
#  ('국토교통부 승인 필요하다', 4),
#  ('길어지다 밸 리카', 4),
#  ('때문 국토교통부 승인', 4),
#  ('라며 제 조', 4),
#  ('바꾸다 이기 때문', 4),
#  ('밸 리카 고', 4),
#  ('보잉 와도 논의', 4),
#  ('국토교통부 승인 필요하다 관련', 4),
#  ('길어지다 밸 리카 고', 4),
#  ('때문 국토교통부 승인 필요하다', 4),
#  ('라며 제 조 사', 4),
#  ('바꾸다 이기 때문 국토교통부', 4),
#  ('본사 지점 직접 협업', 4),
#  ('분기 이커머스 전자상거래 물량', 4),
#  ('사 보잉 와도 논의', 4),
#  ('이기 때문 국토교통부 승인', 4),
#  ('간소 의사 결정', 4),
#  ('경우 올해 분기', 4),
#  ('관계자 참관 가운데', 4),
#  ('국토교통부 관계자 참관', 4),
#  ('간소 의사 결정 체계', 4),
#  ('국토교통부 관계자 참관 가운데', 4),
#  ('부문 선방 억원 안팎', 4),
#  ('수요 급감 매출 하락', 4),
#  ('까다롭다 엄두 조차', 4),
#  ('성 일부 증대', 4),
#  ('수익 성 일부', 4),
#  ('슬 림화 자구', 4),
#  ('시간 여객운송 지', 4),
#  ('신속하다 간소 의사결정', 4),
#  ('까다롭다 엄두 조차 낼', 4),
#  ('시간 여객운송 지 원', 4),
#  ('신속하다 간소 의사결정 체계', 4),
#  ('여객운송 지 원 센터', 4),
#  ('이후 여객 수요 여전하다', 4),
#  ('자구 노력 박차 가하다', 4),
#  ('개선 기대다 나', 4),
#  ('구조 개선 기대다', 4),
#  ('구조 개선 기대다 나', 4),
#  ('재무 구조 개선 기대다', 4),
#  ('전 세계', 4),
#  ('거치다 분 배수로', 4),
#  ('건강 웰빙 참살이', 4),
#  ('경 영 지수', 4),
#  ('광동 제약 대웅제약', 4),
#  ('그린 푸드 해태', 4),
#  ('기간 마지막 날', 4),
#  ('기후 변화 지구', 4),
#  ('끌다 올해 내달', 4),
#  ('네 파 한섬', 4),
#  ('네슬레 비욘드 미트', 4),
#  ('거치다 분 배수로 최종', 4),
#  ('건강 웰빙 참살이 분야', 4),
#  ('경 영 지수 에도', 4),
#  ('광동 제약 대웅제약 한국전력', 4),
#  ('기후 변화 지구 온난화', 4),
#  ('네 파 한섬 세븐일레븐', 4),
#  ('녹십자 광동 제약 대웅제약', 4),
#  ('눈길 끌다 올해 내달', 4),
#  ('대리 바트 텔레콤 이랜드', 4),
#  ('두산매거진 신성 통상 에프', 4),
#  ('거치다 관련', 4),
#  ('관련 준비', 4),
#  ('예상 되다', 4),
#  ('같다 시도 코로나', 4),
#  ('거치다 관련 준비', 4),
#  ('계획 이라고 밝히다', 4),
#  ('관련 준비 진행', 4),
#  ('백 장 착하다', 4),
#  ('보잉사 허가 국토부', 4),
#  ('같다 시도 코로나 사태', 4),
#  ('거치다 관련 준비 진행', 4),
#  ('국토부 승인 거치다 관련', 4),
#  ('백 장 착하다 기내', 4),
#  ('보잉사 허가 국토부 승인', 4),
#  ('부문 선방 천억 원', 4),
#  ('선방 천억 원 안팎', 4),
#  ('가방 인', 4),
#  ('거치다 같다', 4),
#  ('견조 성장', 4),
#  ('가방 인 카', 4),
#  ('견조 성장 나타내다', 4),
#  ('급감 직격탄 맞다', 4),
#  ('나서다 신종 코로나바이러스', 4),
#  ('나타내다 만큼 수익', 4),
#  ('되다 별도 가방', 4),
#  ('라며 법률 적', 4),
#  ('가방 인 카 고', 4),
#  ('견조 성장 나타내다 만큼', 4),
#  ('급감 직격탄 맞다 항공사', 4),
#  ('나서다 신종 코로나바이러스 감염증', 4),
#  ('나타내다 만큼 수익 개선', 4),
#  ('되다 별도 가방 인', 4),
#  ('라며 법률 적 문', 4),
#  ('각 주름 제상', 4),
#  ('거래 일일 마감', 4),
#  ('결 정휴 온스', 4),
#  ('결의 취소 소송', 4),
#  ('경영 지배인 선임', 4),
#  ('경쟁 사 들보', 4),
#  ('고속 인터넷 수익', 4),
#  ('고용 자수 변동', 4),
#  ('공 시 현대차', 4),
#  ('글로벌 리즈 톡', 4),
#  ('결 정휴 온스 글로벌', 4),
#  ('결의 취소 소송 제', 4),
#  ('경영 지배인 선임 세미', 4),
#  ('경쟁 사 들보 다', 4),
#  ('고속 인터넷 수익 성', 4),
#  ('공 시 현대차 올해', 4),
#  ('글로벌 리즈 톡 스주', 4),
#  ('농업부 분 고용 자수', 4),
#  ('단위 외다 각 주름', 4),
#  ('라이트 엔 터 메이트', 4),
#  ('가다 국민은행', 4),
#  ('대해 채무', 4),
#  ('반도체 종', 4),
#  ('보증 결정', 4),
#  ('빌리다 억원', 4),
#  ('가다 국민은행 으로부터', 4),
#  ('대해 채무 보증', 4),
#  ('반도체 종 속', 4),
#  ('빌리다 억원 대해', 4),
#  ('속 회사 인', 4),
#  ('아이티 엠 반도체', 4),
#  ('억원 대해 채무', 4),
#  ('엠 반도체 종', 4),
#  ('으로부터 빌리다 억원', 4),
#  ('가다 국민은행 으로부터 빌리다', 4),
#  ('국민은행 으로부터 빌리다 억원', 4),
#  ('대해 채무 보증 결정', 4),
#  ('반도체 종 속 회사', 4),
#  ('빌리다 억원 대해 채무', 4),
#  ('속 회사 인 가다', 4),
#  ('아이티 엠 반도체 종', 4),
#  ('억원 대해 채무 보증', 4),
#  ('엠 반도체 종 속', 4),
#  ('으로부터 빌리다 억원 대해', 4),
#  ('간담 회 가지다', 4),
#  ('공감 대 하', 4),
#  ('기 놓이다 대형', 4),
#  ('노선 운항 사실', 4),
#  ('대상 간담 회', 4),
#  ('대유행 생사 기', 4),
#  ('발병 전 에도', 4),
#  ('비용 지급 보증', 4),
#  ('생사 기 놓이다', 4),
#  ('노선 운항 사실 상', 4),
#  ('대상 간담 회 가지다', 4),
#  ('대유행 생사 기 놓이다', 4),
#  ('발병 전 에도 감염병', 4),
#  ('비용 지급 보증 제', 4),
#  ('생사 기 놓이다 대형', 4),
#  ('생태계 전반 어려움 겪다', 4),
#  ('세계 적 대유행 생사', 4),
#  ('운항 사실 상 중단', 4),
#  ('적 대유행 생사 기', 4),
#  ('가치 상승 요인', 4),
#  ('게임콘솔 용 메모리', 4),
#  ('공동 도네페질 치매', 4),
#  ('기 대치 웃돌', 4),
#  ('기대 주목 이번', 4),
#  ('기술 장벽 바탕', 4),
#  ('기적 가치 상승', 4),
#  ('내 소비 심리', 4),
#  ('도네페질 치매 패치', 4),
#  ('매틱 스 매출', 4),
#  ('가치 상승 요인 작용', 4),
#  ('공동 도네페질 치매 패치', 4),
#  ('기대 주목 이번 주', 4),
#  ('기술 장벽 바탕 신규', 4),
#  ('기적 가치 상승 요인', 4),
#  ('내 소비 심리 살아나다', 4),
#  ('도네페질 치매 패치 제', 4),
#  ('받다 셀트리온 공동 도네페질', 4),
#  ('서버 게임콘솔 용 메모리', 4),
#  ('셀트리온 공동 도네페질 치매', 4),
#  ('거나 메탄 유출', 4),
#  ('경영 난 해', 4),
#  ('고 있다 점', 4),
#  ('공해 방지 나', 4),
#  ('국장 이번 통계', 4),
#  ('기후 국장 이번', 4),
#  ('난 해 소용', 4),
#  ('남 나라 얘기', 4),
#  ('달다 이지언 환경운동', 4),
#  ('거나 메탄 유출 줄이다', 4),
#  ('경영 난 해 소용', 4),
#  ('고 있다 점 분명하다', 4),
#  ('국장 이번 통계 액수', 4),
#  ('기후 국장 이번 통계', 4),
#  ('달다 이지언 환경운동 연합', 4),
#  ('대한항공 아시아나 항공 두산', 4),
#  ('메탄 유출 줄이다 요구', 4),
#  ('봉쇄 잠시 줄다 이산화탄소', 4),
#  ('석유 오염 제거 하', 4),
#  ('관계 인', 4),
#  ('경련 중소기업 중앙회', 4),
#  ('장 행동 주의 사모펀드', 4),
#  ('남용 막', 4),
#  ('같다 내용 담다', 4),
#  ('공동 의견서 지난', 4),
#  ('규합 해 본인', 4),
#  ('대표 사례 다', 4),
#  ('리스크 배 가량', 4),
#  ('규합 해 본인 원하다', 4),
#  ('리스크 배 가량 증가', 4),
#  ('분 분산 규합 해', 4),
#  ('분산 규합 해 본인', 4),
#  ('불구 하고 쟁점 사안', 4),
#  ('선 임시 주주총회 결의', 4),
#  ('마련 돼다 한다는 이다', 4),
#  ('적 협상', 4),
#  ('경쟁 입찰 거치', 4),
#  ('까지 추궁 하고', 4),
#  ('다수 유력하다 매수', 4),
#  ('떨치다 어렵다 만약', 4),
#  ('맞선 연합 중', 4),
#  ('매수 후보자 에게', 4),
#  ('모든 절차 합리', 4),
#  ('까지 추궁 하고 진상', 4),
#  ('끝 까지 추궁 하고', 4),
#  ('다수 유력하다 매수 후보자', 4),
#  ('맞선 연합 중 축', 4),
#  ('매수 후보자 에게 제안', 4),
#  ('연합 중 축 인', 4),
#  ('우선권 제공 통해 현', 4),
#  ('가족 합산', 4),
#  ('관계 없이', 4),
#  ('구매 불가능하다', 4),
#  ('기다 하나', 4),
#  ('기한 무제한', 4),
#  ('마일리 지는', 4),
#  ('가족 합산 제도', 4),
#  ('구매 불가능하다 소액', 4),
#  ('기한 무제한 두다', 4),
#  ('이다 항공권 구매', 4),
#  ('가족 합산 제도 제휴', 4),
#  ('이다 항공권 구매 불가능하다', 4),
#  ('일 밝히다 재판 불다', 4),
# ...
#  ('재 점화 하고 있다', 3),
#  ('점화 하고 있다 말', 3),
#  ('측 사이 또 다시', 3),
#  ('격화 사면초가', 3),
#  ('겪다 데', 3),
#  ('결론 에는', 3),
#  ('결합 주목', 3),
#  ('경쟁 벌', 3),
#  ('경제 달성', 3),
#  ('그리고 조현아', 3),
#  ('나선 조원태', 3),
#  ('다 고', 3),
#  ('대 금은', 3),
#  ('건설 공동', 3),
#  ('걸 맞다', 3),
#  ('겪다 전망', 3),
#  ('경우 조원태', 3),
#  ('공시 통해', 3),
#  ('기간 날', 3),
#  ('결실 거두다', 3),
#  ('고 주장', 3),
#  ('금은 티웨이', 3),
#  ('기 체결', 3),
#  ('그린 플러스', 3),
#  ('나오다 이번', 3),
#  ('대다 전국', 3),
#  ('또 두', 3),
#  ('혜택 제공', 3),
#  ('현대 카드', 3),
#  ('공동 담당', 3),
#  ('구축 해오다', 3),
#  ('국내 카셰어링', 3),
#  ('기반 업종', 3),
#  ('난 새', 3),
#  ('다빈 난', 3),
#  ('데이터 보다', 3),
#  ('들다 올해', 3),
#  ('라인업 기반', 3),
#  ('경제 기여', 3),
#  ('고용 승계', 3),
#  ('국제선 이다', 3),
#  ('그렇다 법적', 3),
#  ('노선 만들다', 3),
#  ('녹음 녹취', 3),
#  ('녹취 까지', 3),
#  ('안정 기금', 3),
#  ('모빌리티 플랫폼', 3),
#  ('방식 브랜드', 3),
#  ('납품 이고', 3),
#  ('가하다 볼', 3),
#  ('경쟁 벌이다', 3),
#  ('국내 에서는', 3),
#  ('그동안 없다', 3),
#  ('대표 주도하다', 3),
#  ('가량 치솟다', 3),
#  ('가로세로 좌표', 3),
#  ('각 보관장', 3),
#  ('간 나누다', 3),
#  ('개 합치다', 3),
#  ('경우 대다', 3),
#  ('고속버스 짐칸', 3),
#  ('고유 표', 3),
#  ('공급 줄', 3),
#  ('국 경유', 3),
#  ('유지 측 풍 불때', 3),
#  ('관련 기기', 3),
#  ('높이다 반면', 3),
#  ('늘다 송', 3),
#  ('대한항공 및', 3),
#  ('및 한진', 3),
#  ('반면 조선', 3),
#  ('보 유지', 3),
#  ('보유 상장', 3),
#  ('각국 강력하다', 3),
#  ('강력하다 경', 3),
#  ('강세 돌아서다', 3),
#  ('개 기관', 3),
#  ('검토 철회', 3),
#  ('경 기', 3),
#  ('경기 하강', 3),
#  ('관계자 그간', 3),
#  ('광물 자원', 3),
#  ('김온유 기자', 3),
#  ('높이다 제조업', 3),
#  ('다반 대로', 3),
#  ('달라지다 조사', 3),
#  ('더블유 게임', 3),
#  ('들다 확보', 3),
#  ('규정 준수', 3),
#  ('그 설명', 3),
#  ('내용 관해', 3),
#  ('년 대다', 3),
#  ('논란 전혀', 3),
#  ('농림부 바이오', 3),
#  ('다시 얻다', 3),
#  ('단 일', 3),
#  ('가량 급등', 3),
#  ('가시 화', 3),
#  ('각각 오다', 3),
#  ('계획 선회', 3),
#  ('공백 만회', 3),
#  ('비용 절감', 3),
#  ('계 가능하다', 3),
#  ('기점 약', 3),
#  ('기준 제시', 3),
#  ('크라콘스 플랫폼', 3),
#  ('예정 이다', 3),
#  ('멤버십 마켓', 3),
#  ('공업 전문대', 3),
#  ('극히 제한', 3),
#  ('기간 일이', 3),
#  ('까진 최소', 3),
#  ('가량 앞서다', 3),
#  ('각국 지점', 3),
#  ('급증 흑자', 3),
#  ('기 빠지다', 3),
#  ('유동성 위기', 3),
#  ('좌석 뜯다', 3),
#  ('가능성 배제', 3),
#  ('강화 조치', 3),
#  ('관계자 일단', 3),
#  ('기대 미치다', 3),
#  ('길이 열리다', 3),
#  ('김해 원', 3),
#  ('까지는 시간', 3),
#  ('날개 펴다', 3),
#  ('다시 시작', 3),
#  ('공동 제작', 3),
#  ('기내 안전', 3),
#  ('내놓다 데', 3),
#  ('내용 공동', 3),
#  ('노선도 포함', 3),
#  ('다양하다 혜택', 3),
#  ('대면 접촉', 3),
#  ('관람객 전', 3),
#  ('구매 하고', 3),
#  ('간접 종사', 3),
#  ('결정 짓다', 3),
#  ('경남 일대', 3),
#  ('공중 분해', 3),
#  ('구르다 찾다', 3),
#  ('객실 승무원', 3),
#  ('개선 흐름', 3),
#  ('결론 내', 3),
#  ('경기 불확실', 3),
#  ('관심 집중', 3),
#  ('그런대로 방어', 3),
#  ('글로벌 경기', 3),
#  ('가능성 높아지다', 3),
#  ('하향 조정', 3),
#  ('가격 바뀌다', 3),
#  ('각각 소속', 3),
#  ('간다 작년', 3),
#  ('개월 정도', 3),
#  ('거의 찾기', 3),
#  ('계속 유지', 3),
#  ('고개 끄덕이다', 3),
#  ('관심 부탁드리다', 3),
#  ('구성원 활동', 3),
#  ('비대 면', 3),
#  ('그 대신', 3),
#  ('글로벌 영업', 3),
#  ('기석 대의', 3),
#  ('계획 라며', 3),
#  ('곳 에서만', 3),
#  ('시트 백', 3),
#  ('기능 분리', 3),
#  ('기존 보다', 3),
#  ('국토부 간 협의 통해', 3),
#  ('강세 이어지다', 3),
#  ('개편 진행', 3),
#  ('국토부 협의', 3),
#  ('길어지다 밸', 3),
#  ('간소 의사', 3),
#  ('결정 체계', 3),
#  ('관계자 참관', 3),
#  ('기내 공간', 3),
#  ('까다롭다 엄두', 3),
#  ('당 달러', 3),
#  ('개선 기대다', 3),
#  ('기대다 나', 3),
#  ('나서다 여전하다 휴업 상태', 3),
#  ('낮아지다 점 오히려 투자', 3),
#  ('거치다 분', 3),
#  ('건강 웰빙', 3),
#  ('공 항공사', 3),
#  ('광동 제약', 3),
#  ('그린 푸드', 3),
#  ('급 정치', 3),
#  ('기간 마지막', 3),
#  ('개발 목표', 3),
#  ('급감 매출', 3),
#  ('매출 하락', 3),
#  ('방식 내부', 3),
#  ('급감 직격탄', 3),
#  ('나서다 신종', 3),
#  ('나타내다 만큼', 3),
#  ('각 주름', 3),
#  ('거래 일일', 3),
#  ('결 정휴', 3),
#  ('결의 취소', 3),
#  ('경영 지배인', 3),
#  ('고 무적', 3),
#  ('고속 인터넷', 3),
#  ('고용 자수', 3),
#  ('박지환 기자', 3),
#  ('간담 회', 3),
#  ('공감 대', 3),
#  ('기 놓이다', 3),
#  ('기자 정부', 3),
#  ('기초 체력', 3),
#  ('놓이다 대형', 3),
#  ('대 하', 3),
#  ('대상 간담', 3),
#  ('게임콘솔 용', 3),
#  ('공동 도네페질', 3),
#  ('관제 시스템', 3),
#  ('기 대치', 3),
#  ('기대 주목', 3),
#  ('기술 장벽', 3),
#  ('기적 가치', 3),
#  ('꼽히다 특히', 3),
#  ('내 소비', 3),
#  ('가스 줄', 3),
#  ('거나 메탄', 3),
#  ('공해 방지', 3),
#  ('국장 이번', 3),
#  ('그린 뉴딜', 3),
#  ('글로벌 환경', 3),
#  ('경련 중소기업', 3),
#  ('투기 자본', 3),
#  ('가량 증가', 3),
#  ('공동 의견서', 3),
#  ('관련 법안', 3),
#  ('검토 뒤', 3),
#  ('끝 까지', 3),
#  ('내 소진', 3),
#  ('가처분 소송', 3),
#  ('각자 대표', 3),
#  ('검토 하고', 3),
#  ('공개 경쟁', 3),
#  ('관련 자문', 3),
#  ('권부 무', 3),
#  ('경 찬', 3),
#  ('금융리스 형태', 3),
#  ('꼽히다 사안', 3),
#  ('다르다 않다', 3),
#  ('매입 대상', 3),
#  ('가을 께', 3),
#  ('오정민 한경닷컴 기자 기사', 3),
#  ('높다 코로나', 3),
#  ('대립 어가', 3),
#  ('글 래', 3),
#  ('여의도 글 래 드', 3),
#  ('위 주주 연합 기자간담회', 3),
#  ('관련 책임', 3),
#  ('구성 기자', 3),
#  ('개선 공표', 3),
#  ('고 당부', 3),
#  ('관계자 이해관계', 3),
#  ('구심 우려', 3),
#  ('따로 설명', 3),
#  ('라는 이유', 3),
#  ('라며 두', 3),
#  ('계 기관', 3),
#  ('관련 의사결정', 3),
#  ('구가 다음', 3),
#  ('규모 산업', 3),
#  ('금융 회사', 3),
#  ('금융통화위원회 열다', 3),
#  ('간사 통해', 3),
#  ('개선 나선', 3),
#  ('거치다 최적', 3),
#  ('검토 후', 3),
#  ('재무 구조 개선 나선', 3),
#  ('다그 문제', 3),
#  ('달 시간', 3),
#  ('대비 좋아지다', 3),
#  ('투자 증권', 3),
#  ('가다 넘다', 3),
#  ('가장 중요하다', 3),
#  ('가치 낮다', 3),
#  ('강북구 삼양동', 3),
#  ('개발 원', 3),
#  ('공병 단', 3),
#  ('공사 사옥', 3),
#  ('공산 크다', 3),
#  ('급격하다 늘', 3),
#  ('나 공공기관', 3),
#  ('날 화상', 3),
#  ('금액 치면', 3),
#  ('돈 몰리다', 3),
#  ('머니투데이 강민수', 3),
#  ('몰리다 앞서', 3),
#  ('예정 주식', 3),
#  ('예정일 달', 3),
#  ('경쟁 당국', 3),
#  ('공문 받다', 3),
#  ('관계자 여행', 3),
#  ('국내 빅', 3),
#  ('규모 알려지다', 3),
#  ('금은 약', 3),
#  ('체불 임금', 3),
#  ('가격 하락', 3),
#  ('가치 깊이', 3),
#  ('건 대해', 3),
#  ('공문 발송', 3),
#  ('공익 적', 3),
#  ('국내 증권', 3),
#  ('깊이 인식', 3),
#  ('깔다 족파', 3),
#  ('규모 다카', 3),
#  ('내 하나', 3),
#  ('넘어서다 후', 3),
#  ('넷마블 펄', 3),
#  ('늘어나다 특히', 3),
#  ('남코 반다이', 3),
#  ('공주 오랜', 3),
#  ('글로벌 경', 3),
#  ('급등 유류', 3),
#  ('나타내다 이외', 3),
#  ('내다 안다', 3),
#  ('대한 보고서', 3),
#  ('라며 타이트', 3),
#  ('령 해제', 3),
#  ('흑자 전환', 3),
#  ('기간 자금지원', 3),
#  ('기내 사업', 3),
#  ('단가 대응', 3),
#  ('대응 고정수', 3),
#  ('불거지다 분식회계', 3),
#  ('생산 설비', 3),
#  ('로서 위상', 3),
#  ('리지 않다', 3),
#  ('가다 걱정', 3),
#  ('가지 컨셉', 3),
#  ('간식 모', 3),
#  ('감자 튀김', 3),
#  ('강점 오전', 3),
#  ('거버 유기농', 3),
#  ('경적 음', 3),
#  ('구비 되어다', 3),
#  ('규모 욕조', 3),
#  ('일 까지', 3),
#  ('건 과는', 3),
#  ('경주 전주', 3),
#  ('계약서 기재', 3),
#  ('계열 화', 3),
#  ('계위 기', 3),
#  ('개월 동안', 3),
#  ('까지만 적용', 3),
#  ('꺼리다 사회', 3),
#  ('객 특별하다', 3),
#  ('경험 체험', 3),
#  ('고객 점차', 3),
#  ('그 가운데', 3),
#  ('금융 어떠하다', 3),
#  ('김동호 기자', 3),
#  ('구성 되어다', 3),
#  ('가능성 높이', 3),
#  ('가시 화하다', 3),
#  ('강보 합세', 3),
#  ('결국 많이', 3),
#  ('경향 보이', 3),
#  ('과열 양상', 3),
#  ('구조 변화', 3),
#  ('그 동안', 3),
#  ('근접하다 하이닉스', 3),
#  ('이라고 말', 3),
#  ('게 전혀', 3),
#  ('공 고안', 3),
#  ('관계 복잡하다', 3),
#  ('국내 소재', 3),
#  ('공적 주체', 3),
#  ('공통 투자', 3),
#  ('관계자 원칙', 3),
#  ('국내외 금융기관', 3),
#  ('결과 바탕', 3),
#  ('결제 수단', 3),
#  ('기간 늘어나다', 3),
#  ('김봉진 우아하다', 3),
#  ('나가다 계획', 3),
#  ('나누기 때문', 3),
#  ('과거 영광', 3),
#  ('관계자 강매', 3),
#  ('구매 파악', 3),
#  ('굳이 일반', 3),
#  ('거 죠', 3),
#  ('공지 통해', 3),
#  ('관계자 코로나', 3),
#  ('규모 억원', 3),
#  ('금액 최소', 3),
#  ('기내식 사업', 3),
#  ('곳 합의', 3),
#  ('공기 중', 3),
#  ('공항동 본사', 3),
#  ('관리 강화하다', 3),
#  ('구역 세분', 3),
#  ('기다리다 우리', 3),
#  ('내용 담기다', 3),
#  ('담기다 또', 3),
#  ('안전성 알리다 데 적극', 3),
#  ('갈릴 이라고', 3),
#  ('개발 주도', 3),
#  ('경쟁 이후', 3),
#  ('끌다 모으다', 3),
#  ('김효진 기자', 3),
#  ('규모 장비 공급', 3),
#  ('액 억원 대비 수준', 3),
#  ('억원 대비 수준 이다', 3),
#  ('드림 씨아이', 3),
#  ('랩 스주', 3),
#  ('맵 스리', 3),
#  ('가깝다 전', 3),
#  ('감소 악화', 3),
#  ('갑자기 회복', 3),
#  ('강도 높다', 3),
#  ('개 직영', 3),
#  ('개발 우선', 3),
#  ('개사 대상', 3),
#  ('경비 최대', 3),
#  ('골프장 클럽', 3),
#  ('계좌 필수', 3),
#  ('국내외 모든', 3),
#  ('극대 화하다', 3),
#  ('금액 설정', 3),
#  ('기아차 정유', 3),
#  ('가맹 점', 3),
#  ('간호학 물리치료', 3),
#  ('개인 희망', 3),
#  ('격납고 완공', 3),
#  ('경남 사천', 3),
#  ('경우 복수', 3),
#  ('경쟁률 기록', 3),
#  ('경험 쌓다', 3),
#  ('과대 이기', 3),
#  ('과정 개발', 3),
#  ('교사 진출', 3),
#  ('공항 경남 사천 국가', 3),
#  ('교환학생 프로그램 주로 진행', 3),
#  ('가지다 금융', 3),
#  ('단양 천안', 3),
#  ('달라 유의', 3),
#  ('웰리 힐리 파크 수영장', 3),
#  ('개선 따르다', 3),
#  ('그 주요', 3),
#  ('그래도 우호', 3),
#  ('나서다 조언', 3),
#  ('노선 재개', 3),
#  ('따르다 평가', 3),
#  ('라며 투자', 3),
#  ('대한항공 분기', 3),
#  ('라며 투자 의견 매수', 3),
#  ('급감 전체', 3),
#  ('노선 급감', 3),
#  ('리카 고', 3),
#  ('매수 목표', 3),
#  ('급감 전체 화물기 수용', 3),
#  ('년 동기 대비 줄', 3),
#  ('력 줄어들다 탓 이라는', 3),
#  ('강남구 논현동', 3),
#  ('강현 대표이사', 3),
#  ('경고 종목', 3),
#  ('경남 제약', 3),
#  ('경추 플레이', 3),
#  ('공 급사', 3),
#  ('공장 증설', 3),
#  ('계획 신청', 3),
#  ('거의 못', 3),
#  ('격리 입국', 3),
#  ('계세 요', 3),
#  ('곳 뿐', 3),
#  ('관련 커뮤니티', 3),
#  ('관행 상', 3),
#  ('국토교통부 조', 3),
#  ('그 사이', 3),
#  ('금융 라운지', 3),
#  ('그간 하늘', 3),
#  ('그치다 뿐', 3),
#  ('급량 한정', 3),
#  ('각각 하락', 3),
#  ('강하다 이라고', 3),
#  ('긍정 론', 3),
#  ('김지윤 대신', 3),
#  ('나 오르다', 3),
#  ('각국 빗장', 3),
#  ('감소 폭', 3),
#  ('건 쉬다', 3),
#  ('걸다 잠그다', 3),
#  ('구 분석', 3),
#  ('국가 늘다', 3),
#  ('국제선 노선도', 3),
#  ('귀국 시', 3),
#  ('김용훈 기자', 3),
#  ('간 강', 3),
#  ('값 등락', 3),
#  ('강 대강', 3),
#  ('강화 핵심', 3),
#  ('개정 필요하다', 3),
#  ('건 수억', 3),
#  ('걸 시작', 3),
#  ('격리 조치', 3),
#  ('운항 재개', 3),
#  ('국립 보건', 3),
#  ('국제 백', 3),
#  ('기대하다 말', 3),
#  ('김 사무', 3),
#  ('고착 화', 3),
#  ('공업 대한항공', 3),
#  ('관사 선정', 3),
#  ('그래도 지난해', 3),
#  ('구조 이기', 3),
#  ('급량 주다', 3),
#  ('나타나다 쉬다', 3),
#  ('낼 보이다', 3),
#  ('늘어나다 가능성', 3),
#  ('달리 전적', 3),
#  ('수요 회복', 3),
#  ('인천 국제공항', 3),
#  ('굽다 모', 3),
#  ('모 기자', 3),
#  ('기준 매출 액 규모', 3),
#  ('디 에스케이 억만원 규모', 3),
#  ('까지 주가', 3),
#  ('대상 유상증자 청약', 3),
#  ('개념 생소하다', 3),
#  ('게 가장', 3),
#  ('경우 대부분', 3),
#  ('경쟁력 인정받다', 3),
#  ('고객 소비', 3),
#  ('과의 협력', 3),
#  ('과감 결단', 3),
#  ('가깝다 경험', 3),
#  ('감다 만기', 3),
#  ('개선 기대하다', 3),
#  ('개정 통해', 3),
#  ('걸다 당시', 3),
#  ('결성 곳', 3),
#  ('가능 케', 3),
#  ('기업 구조조정', 3),
#  ('가능 이르다', 3),
#  ('검토 중', 3),
#  ('경우 에는', 3),
#  ('계 컨설팅', 3),
#  ('곳 중심', 3),
#  ('국면 변화', 3),
#  ('나타나다 측면', 3),
#  ('달 중순', 3),
#  ('롭 게 진행중 거나', 3),
#  ('가뭄 시달리다', 3),
#  ('가이드 증권사', 3),
#  ('가전 매장', 3),
#  ('개정 개악', 3),
#  ('건설 각각', 3),
#  ('경이 안', 3),
#  ('경제학 교수', 3),
#  ('관련 규제', 3),
#  ('구조조정 착수', 3),
#  ('선전 에어부산', 3),
#  ('송광섭 기자', 3),
#  ('시 분', 3),
#  ('같다 느낌', 3),
#  ('거치다 표면', 3),
#  ('겉 면', 3),
#  ('골프 업종', 3),
#  ('구리 합금', 3),
#  ('그린 대한항공', 3),
#  ('기간 지나', 3),
#  ('기존 매끈하다', 3),
#  ('나오다 시대', 3),
#  ('좋다 훼손 덜하다 때문', 3),
#  ('지나 폐기 되다 때', 3),
#  ('관리 최선', 3),
#  ('교민 유학생', 3),
#  ('경쟁 밀리', 3),
#  ('경제 새롭다', 3),
#  ('골든게이트 벤처스', 3),
#  ('공개 되다', 3),
#  ('과의 경쟁', 3),
#  ('관측 많다', 3),
#  ('그치다 최대', 3),
#  ('금액 대부분', 3),
#  ('갖다 사다', 3),
#  ('고위 관계자', 3),
#  ('곳 이기', 3),
#  ('관 특별', 3),
#  ('관계자 박원순', 3),
#  ('관리 관', 3),
#  ('다 항공기', 3),
#  ('다른 업', 3),
#  ('당국 엄격하다', 3),
#  ('대해 서', 3),
#  ('만 가입', 3),
#  ('맺다 특화', 3),
#  ('며 영업', 3),
#  ('가운데 확산', 3),
#  ('그 치고', 3),
#  ('다 아시아나', 3),
#  ('더 크다', 3),
#  ('두다 보다', 3),
#  ('률 여전하다', 3),
#  ('못 미치다', 3),
#  ('보다 그나마', 3),
#  ('보이다 가운데', 3),
#  ('불과하다 여름', 3),
#  ('김자현 기자', 3),
#  ('네이버 셀트리온', 3),
#  ('높이다 원', 3),
#  ('대 장주', 3),
#  ('대다 떨어지다', 3),
#  ('코로나 여파', 3),
#  ('개월 시간', 3),
#  ('경기 김포', 3),
#  ('계획 차차', 3),
#  ('개살구 라는', 3),
#  ('걸다 잠', 3),
#  ('경쟁 심화', 3),
#  ('고개 가로', 3),
#  ('근후 제주', 3),
#  ('급감 집계', 3),
#  ('국내선 보다', 3),
#  ('기다리다 사람', 3),
#  ('김병덕 기자', 3),
#  ('개다 비대', 3),
#  ('급락 올해', 3),
#  ('기업인 네이버', 3),
#  ('가가 부담', 3),
#  ('각 국가', 3),
#  ('각각 사이트', 3),
#  ('각종 특혜', 3),
#  ('간편하다 확인', 3),
#  ('강세 소', 3),
#  ('과의 거리', 3),
#  ('국가 법령', 3),
#  ('게임 금융', 3),
#  ('맥코 디엠', 3),
#  ('개점휴업 이라는', 3),
#  ('경제 고용', 3),
#  ('국가 안보', 3),
#  ('국민 경제', 3),
#  ('감소 경', 3),
#  ('부터 반 년 간', 3),
#  ('수가 인 상이 어', 3),
#  ('공주 빼다', 3),
#  ('국내 시가총액', 3),
#  ('금호 석유', 3),
#  ('급증 년도', 3),
#  ('게 그나마', 3),
#  ('경영 체제', 3),
#  ('국제 전', 3),
#  ('기다 커녕', 3),
#  ('가구 및', 3),
#  ('가파른 점', 3),
#  ('각각 내리다', 3),
#  ('갈등 최고', 3),
#  ('개 미만', 3),
#  ('개국 세계', 3),
#  ('경쟁력 떨어지다', 3),
#  ('계 위인', 3),
#  ('내다 밖에도', 3),
#  ('다년 스웨덴', 3),
#  ('단일 팀', 3),
#  ('대한항공 엑설런스', 3),
#  ('돼다 전날', 3),
#  ('때 까지', 3),
#  ('개발 추가', 3),
#  ('개월 걸리다', 3),
#  ('걸리다 이란', 3),
#  ('결국 매각', 3),
#  ('공사 집계', 3),
#  ('교 역량', 3),
#  ('금지 조치', 3),
#  ('만 주원', 3),
#  ('공원 입장권', 3),
#  ('관 파트너', 3),
#  ('글로벌 콘텐츠', 3),
#  ('네이티 브', 3),
#  ('놀이 공원', 3),
#  ('높다 나타나다', 3),
#  ('관심 모으다', 3),
#  ('근로자 고용', 3),
#  ('가능하다 따라서', 3),
#  ('가운데 늘다', 3),
#  ('게 시장', 3),
#  ('결의 가능하다', 3),
#  ('계 전망', 3),
#  ('관건 자연', 3),
#  ('관계자 추정', 3),
#  ('게 현실', 3),
#  ('경영 결과', 3),
#  ('고꾸라지다 가능성', 3),
#  ('공유 가격', 3),
#  ('다 이선아', 3),
#  ('가능하다 점', 3),
#  ('강도원 김민경', 3),
#  ('개발 아시아나', 3),
#  ('결과 이끌다', 3),
#  ('결정 물론', 3),
#  ('겹 치다', 3),
#  ('고민 프라이', 3),
#  ('구 조', 3),
#  ('구조 만들다', 3),
#  ('배정 기준', 3),
#  ('변경삼 호', 3),
#  ('건강 삼', 3),
#  ('건설업 운수', 3),
#  ('경기 회복', 3),
#  ('경찰 로부터', 3),
#  ('공세 밀리다', 3),
#  ('과의 보툴리눔톡신', 3),
#  ('광물 건설업', 3),
#  ('국제무역 위원회', 3),
#  ('균주 출처', 3),
#  ('계약 파기', 3),
#  ('관점 정부', 3),
#  ('교수 밉다', 3),
#  ('구독 이른바', 3),
#  ('글 써다', 3),
#  ('금융 전', 3),
#  ('금지 하고', 3),
#  ('간 경쟁', 3),
#  ('감소 수준', 3),
#  ('경쟁 운임', 3),
#  ('경제 오주연', 3),
#  ('고 유상증자', 3),
#  ('공백 메우다', 3),
#  ('가까이 비다', 3),
#  ('가다 논란', 3),
#  ('강력하다 후보', 3),
#  ('강행 처리', 3),
#  ('개인 일신', 3),
#  ('결정 이용', 3),
#  ('곳 넘기다', 3),
#  ('공시 의무', 3),
#  ('가해 지는', 3),
#  ('내리다 만원', 3),
#  ('단 지원', 3),
#  ('대비 원', 3),
#  ('되다 김현정', 3),
#  ('만원 거래', 3),
#  ('감성 담다', 3),
#  ('경제 기하', 3),
#  ('기간 파격', 3),
#  ('기존 에는', 3),
#  ('기하 영', 3),
#  ('담다 사용자', 3),
#  ('간 전화', 3),
#  ('강제 나', 3),
#  ('거 예요', 3),
#  ('계약 이행', 3),
#  ('계약서 상', 3),
#  ('고 미지', 3),
#  ('경전 벌이', 3),
#  ('계약 내용', 3),
#  ('공 방', 3),
#  ('구상 차질', 3),
#  ('식기 판', 3),
#  ('각별 관리', 3),
#  ('거치다 별도', 3),
#  ('건강 상의', 3),
#  ('결과 나오다', 3),
#  ('계 화두', 3),
#  ('공기 또한', 3),
#  ('공식 발표', 3),
#  ('관계없이 우선', 3),
#  ('가계약 항상', 3),
#  ('가인 당', 3),
#  ('거듭 강조', 3),
#  ('결국 국영', 3),
#  ('경쟁력 높이', 3),
#  ('고개 저었다', 3),
#  ('공 자로', 3),
#  ('공교 롭', 3),
#  ('검토 바', 3),
#  ('교육 센터', 3),
#  ('국민권익위 원', 3),
#  ('가다 사실', 3),
#  ('각 항공사', 3),
#  ('고사 직전', 3),
#  ('관계자 국토부', 3),
#  ('국토교통부 적극', 3),
#  ('국토부 범', 3),
#  ('규 모으다', 3),
#  ('기내식 면세점', 3),
#  ('기다리다 중이', 3),
#  ('국토교통부 적극 적 나서다', 3),
#  ('감축 고용', 3),
#  ('게재 의무', 3),
#  ('공유 방안', 3),
#  ('가능하다 연간', 3),
#  ('간의 분쟁', 3),
#  ('갈등 심화', 3),
#  ('강화 중국산', 3),
#  ('개다 긍정', 3),
#  ('개선 기회', 3),
#  ('객 급감', 3),
#  ('공 경창', 3),
#  ('다미 재무부', 3),
#  ('달러 알려지다', 3),
#  ('대선 후보', 3),
#  ('래퍼 카니', 3),
#  ('만만 달러', 3),
#  ('내리다 결정', 3),
#  ('대로 진행', 3),
#  ('백종 규', 3),
#  ('과정 필요하다', 3),
#  ('까지 합치', 3),
#  ('다른 핵심', 3),
#  ('구 주택', 3),
#  ('기금 에서도', 3),
#  ('기내식 기', 3),
#  ('가량 자금', 3),
#  ('기금 에서', 3),
#  ('까지는 구', 3),
#  ('우리 사 주 조합', 3),
#  ('거래 적기', 3),
#  ('국제공항 멈추다', 3),
#  ('군 에선', 3),
#  ('머니투데이 김', 3),
#  ('도윤 기자 대한항공 기내식', 3),
#  ('거래 물량뿐', 3),
#  ('그었다 하지만', 3),
#  ('급하다 불', 3),
#  ('경영 혁신', 3),
#  ('계획 지난달', 3),
#  ('과정 거치다', 3),
#  ('구가 시중', 3),
#  ('구비 서류', 3),
#  ('구상 밝히다', 3),
#  ('권 에서는', 3),
#  ('공고 내면', 3),
#  ('규제 때문', 3),
#  ('극적 늘다', 3),
#  ('글 텍', 3),
#  ('급등 하고', 3),
#  ('광주 고속', 3),
#  ('권 취득', 3),
#  ('기아차 현대차', 3),
#  ('가량 크게', 3),
#  ('거의 없다', 3),
#  ('경기 전북', 3),
#  ('고국 돌아가다', 3),
#  ('관리 업무', 3),
#  ('교통 관리', 3),
#  ('국제공항 제', 3),
#  ('금지 해제', 3),
#  ('기업 주', 3),
#  ('계약 연장', 3),
#  ('그만큼 새롭다', 3),
#  ('급격하다 얼어붙다', 3),
#  ('기간 남아', 3),
#  ('기관 부실', 3),
#  ('기단 축소', 3),
#  ('기재 조기', 3),
#  ('내 파다', 3),
#  ('넓다 금리', 3),
#  ('년물 전량', 3),
#  ('늘리다 의결', 3),
#  ('달라지다 이라고', 3),
#  ('대상 총', 3),
#  ('과는 달리', 3),
#  ('그 어느', 3),
#  ('그다지 매력', 3),
#  ('금은 대응', 3),
#  ('경영 애로', 3),
#  ('계약 단가', 3),
#  ('계열 사르다', 3),
#  ('근로 자수', 3),
#  ('및 차', 3),
#  ('방법 주주', 3),
#  ('거치다 확정', 3),
#  ('결론 내리다', 3),
#  ('경우 에만', 3),
#  ('국민 공유', 3),
#  ('반면 아시아나 항공 대해', 3),
#  ('배당 사주 매입 계', 3),
#  ('가치 평가', 3),
#  ('개발 지분매각', 3),
#  ('거위 불리다', 3),
#  ('결정 함께', 3),
#  ('관계자 나', 3),
#  ('국제 민간', 3),
#  ('내용 포함', 3),
#  ('대한항공 꼽히다', 3),
#  ('렬 기자', 3),
#  ('관 내용 포함 되다', 3),
#  ('기업 으로는 대한항공 꼽히다', 3),
#  ('어려움 겪다 있다 기업', 3),
#  ('개월 여', 3),
#  ('개인 만이', 3),
#  ('경제 지표', 3),
#  ('낮추다 확정', 3),
#  ('대다 지수', 3),
#  ('극복 위해', 3),
#  ('금액 약', 3),
#  ('가능성 생겨나다', 3),
#  ('게임 소프트웨어', 3),
#  ('경우 자칫', 3),
#  ('경제 달리', 3),
#  ('곳도 포함', 3),
#  ('개월 새', 3),
#  ('군 이름', 3),
#  ('글자 따다', 3),
#  ('향후 경영 실적 동반', 3),
#  ('회복하다 셈 이라고 설명', 3),
#  ('각각 원', 3),
#  ('강남 파크', 3),
#  ('거래처 사원', 3),
#  ('과자 유키', 3),
#  ('광고 자제', 3),
#  ('김 모씨', 3),
#  ('나 면세점', 3),
#  ('계획 인', 3),
#  ('기대하다 있다', 3),
#  ('낫다 여객운송', 3),
#  ('내놓다 직원', 3),
#  ('각 제안', 3),
#  ('감소 매출', 3),
#  ('검토 해오다', 3),
#  ('결정 하고', 3),
#  ('그룹 지주회사', 3),
#  ('간편하다 궁금증', 3),
#  ('계 혁신', 3),
#  ('과정 걸치다', 3),
#  ('권현수 기자', 3),
#  ('기반 각종', 3),
#  ('기술 단순', 3),
#  ('기자 인공', 3),
#  ('김지웅 대표', 3),
#  ('넘다 지속', 3),
#  ('구심 보이다', 3),
#  ('대해 공식', 3),
#  ('막바지 작업', 3),
#  ('물살 타다', 3),
#  ('내년 말', 3),
#  ('내다 전해지다', 3),
#  ('보유 왕산레제 개발 지', 3),
#  ('고수 해오다', 3),
#  ('관심 가져오다', 3),
#  ('교육 항공기', 3),
#  ('국내 식', 3),
#  ('꾸준하다 제기', 3),
#  ('내비 치다', 3),
#  ('높다 점', 3),
#  ('로는 사모펀드', 3),
#  ('마리나 보유', 3),
#  ('및 조원', 3),
#  ('그랜드 관광', 3),
#  ('기업 사이', 3),
#  ('난감하다 이라고', 3),
#  ('내리다 보이다', 3),
#  ('년 기준', 3),
#  ('대금 년', 3),
#  ('데 제동', 3),
#  ('대상 일 열리다 이사회', 3),
#  ('가능성 여전하다', 3),
#  ('가치 산정', 3),
#  ('거의 뜨다', 3),
#  ('걸리다 돌', 3),
#  ('고통 분담', 3),
#  ('가져오다 여기', 3),
#  ('강화하다 항공기', 3),
#  ('결과 란', 3),
#  ('국산 마스크', 3),
#  ('권리 옵션', 3),
#  ('높다 내다보다', 3),
#  ('늘다 분리', 3),
#  ('대한항공 부사', 3),
#  ('돼다 중', 3),
#  ('배정 주관 사의 재량', 3),
#  ('간 주요', 3),
#  ('간의 격차', 3),
#  ('강 원장', 3),
#  ('강용 규', 3),
#  ('개 상장', 3),
#  ('개월 무급', 3),
#  ('구조조정 마저', 3),
#  ('궁극 해결', 3),
#  ('걸리다 이라', 3),
#  ('그나마 버티다', 3),
#  ('노선 아예', 3),
#  ('다발 적', 3),
#  ('대감 추락', 3),
#  ('대규모 구조조정', 3),
#  ('가격 내려가다', 3),
#  ('가시 밭길', 3),
#  ('국가 많다', 3),
#  ('규탄 집회', 3),
#  ('그룹 본사', 3),
#  ('공급 늘리다', 3),
#  ('여객 수', 3),
#  ('낙폭 대', 3),
#  ('날 에는', 3),
#  ('가다 감염', 3),
#  ('감염 우려', 3),
#  ('걸리다 이라는', 3),
#  ('과반 넘어서다', 3),
#  ('기술 연구원', 3),
#  ('률 안팎', 3),
#  ('명보 다', 3),
#  ('부터 지난달', 3),
#  ('감소 인하다', 3),
#  ('개사 선급금', 3),
#  ('개척 전차', 3),
#  ('갯벌 로번', 3),
#  ('결의 핀', 3),
#  ('권리 행사', 3),
#  ('글로벌 김완섭', 3),
#  ('금 상환', 3),
#  ('금지 가처분', 3),
#  ('건설 못', 3),
#  ('검토 연장', 3),
#  ('계열 사의', 3),
#  ('구조도 어렵다', 3),
#  ('그룹 지주사', 3),
#  ('금 몰리다', 3),
#  ('기대다 면서', 3),
#  ('기업 비교', 3),
#  ('증거 금 몰리다 현대', 3),
#  ('각각 거의', 3),
#  ('거의 차이', 3),
#  ('고 조홍제', 3),
#  ('곧 머', 3),
#  ('그동안 형', 3),
#  ('그저 수긍', 3),
#  ('기대 밖', 3),
#  ('기존 보', 3),
#  ('넘기다 배경', 3)]

# %%
founds_from_4measure = []
for measure, finder in ngram:
        finder = finder.from_words(nouns[1])
        founds = finder.nbest(measure.pmi, 10)       # pmi - 상위 10개 추출
        founds += finder.nbest(measure.chi_sq, 10)   # chi_sq - 상위 10개 추출
        founds += finder.nbest(measure.mi_like, 10)  # mi_like - 상위 10개 추출
        founds += finder.nbest(measure.jaccard, 10)  # jaccard - 상위 10개 추출

        founds_from_4measure += founds

collocations = [' '.join(collocation) for collocation in founds_from_4measure]
collocations = [(w,f) for w,f in Counter(collocations).most_common() if f > 2]
pprint(collocations)
# Out:
# [('고사 직 전일', 4),
#  ('관련 업종 취급', 4),
#  ('기 저 비용', 4),
#  ('대거 줄 도산', 4),
#  ('도산 행 발생', 4),
#  ('모르다 터 라', 4),
#  ('부채 비율 훌쩍', 4),
#  ('불확실 성 제거', 4),
#  ('비율 훌쩍 넘기다', 4),
#  ('고사 직 전일 뿐', 4),
#  ('관련 업종 취급 제한', 4),
#  ('기 저 비용 항공사', 4),
#  ('대거 줄 도산 행', 4),
#  ('모르다 터 라 선뜻', 4),
#  ('부채 비율 훌쩍 넘기다', 4),
#  ('비율 훌쩍 넘기다 지난해', 4),
#  ('연 기 저 비용', 4),
#  ('전일 뿐 아니다 주요', 4),
#  ('줄 도산 행 발생', 4),
#  ('가량 연기', 3),
#  ('고사 직', 3),
#  ('관계자 대한항공', 3),
#  ('관련 업종', 3),
#  ('기 저', 3),
#  ('난항 겪다', 3),
#  ('넘기다 지난해', 3),
#  ('대거 줄', 3),
#  ('대주 주인', 3),
#  ('공모 방식', 3)]
